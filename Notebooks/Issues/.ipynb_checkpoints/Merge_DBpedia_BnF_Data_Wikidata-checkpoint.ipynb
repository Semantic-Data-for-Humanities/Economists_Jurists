# %%
from SPARQLWrapper import SPARQLWrapper, SPARQLWrapper2, JSON, TURTLE, XML, RDFXML
import pprint
import csv
# from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

from collections import Counter
from operator import itemgetter
import pandas as pd
from sqlalchemy import create_engine

# Calling the nltk package to merge the data of people without existing VIAF URI in the two datasets 
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder

from nltk.metrics import BigramAssocMeasures
from nltk.metrics import TrigramAssocMeasures
import numpy as np

# %%
query = """
PREFIX  egr:  <http://rdvocab.info/ElementsGr2/>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
PREFIX  skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>

SELECT DISTINCT  ?s ?name ?sName ?uri ?year ?bio
WHERE
  {   { ?s  egr:biographicalInformation  ?bio ;
            egr:dateOfBirth       ?bd
        BIND(strbefore(strafter(str(?bd), "http://data.bnf.fr/date/"), "/") AS ?year)
        FILTER ( ?year > "1770" )
        FILTER ( ( ( ( ( regex(?bio, "juriste", "i") || regex(?bio, "professeur de droit", "i") ) || regex(?bio, "docteur en droit", "i") ) || regex(?bio, "avocat", "i") ) || regex(?bio, "juge", "i") ) || regex(?bio, "magistrat", "i") )
        OPTIONAL
          { ?s  foaf:name  ?name }
        OPTIONAL
          { ?s  skos:prefLabel  ?sName }
        OPTIONAL
          { ?s  owl:sameAs  ?uri
            FILTER regex(?uri, "viaf.org", "i")
          }
      }
    UNION
      { ?s  egr:biographicalInformation  ?bio ;
            egr:dateOfBirth       ?bd
        BIND(strbefore(strafter(str(?bd), "http://data.bnf.fr/date/"), "/") AS ?year)
        FILTER ( ?year > "1770" )
        FILTER ( ( ( regex(?bio, "économiste") || regex(?bio, "Economiste") ) || regex(?bio, "professeur d'économie", "i") ) || regex(?bio, "docteur en économie", "i") )
        OPTIONAL
          { ?s  foaf:name  ?name }
        OPTIONAL
          { ?s  skos:prefLabel  ?sName }
        OPTIONAL
          { ?s  owl:sameAs  ?uri1
            FILTER regex(?uri1, "viaf.org", "i")
            BIND(strbefore(str(?uri1), "http://viaf.org/viaf/") AS ?uri)
          }
      }
  }
ORDER BY DESC(?uri)


"""

# %%
sparql = SPARQLWrapper("https://data.bnf.fr/sparql") ##, returnFormat=RDFXML)  [LOCALHOST]

# %%
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# %%
try:
    rc_bnf = sparql.queryAndConvert()
except Exception as e:
    print(e)

# %%
# Number of rows in the result
len(rc_bnf['results']['bindings'])
# Out:
# 11201

# %%
# Inspect the first three rows
i = 0
for l in rc_bnf['results']['bindings']:
    if i < 100:
        print(l)
        i += 1
# Out:
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12981404c#about'}, 'name': {'type': 'literal', 'value': 'Léon Garnier'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99996033'}, 'year': {'type': 'literal', 'value': '1836'}, 'bio': {'type': 'literal', 'value': "Juriste. - Administrateur et homme de lettres. - En poste à la Préfecture de la Seine. - Frère de l'explorateur Francis Garnier (1839-1873)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13484444m#about'}, 'name': {'type': 'literal', 'value': 'Gaston de Pawlowski'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9999219'}, 'year': {'type': 'literal', 'value': '1874'}, 'bio': {'type': 'literal', 'value': 'Docteur en droit. - Critique littéraire et théâtral. - Rédacteur en chef de "Comoedia"'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb134841632#about'}, 'name': {'type': 'literal', 'value': 'Jean-Michel Berton'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9999131'}, 'year': {'type': 'literal', 'value': '1794'}, 'bio': {'type': 'literal', 'value': 'Écrivain politique, avocat à la Cour de cassation. - Fut fondateur et directeur de la "Revue poétique française et étrangère"'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13379520q#about'}, 'name': {'type': 'literal', 'value': 'Emmanuel Mathieu'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9995247'}, 'year': {'type': 'literal', 'value': '1852'}, 'bio': {'type': 'literal', 'value': 'Docteur en droit (Paris, 1873)'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13338312g#about'}, 'name': {'type': 'literal', 'value': 'Josiah Henry Benton'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9994322'}, 'year': {'type': 'literal', 'value': '1843'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Bibliophile'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13322315v#about'}, 'name': {'type': 'literal', 'value': 'Paul Pic'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9991357'}, 'year': {'type': 'literal', 'value': '1862'}, 'bio': {'type': 'literal', 'value': "Juriste. - Professeur de droit à la Faculté de droit de Lyon et à l'École supérieure du commerce. - Docteur en droit (Lyon, 1885)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13193319k#about'}, 'name': {'type': 'literal', 'value': 'Gaston Ravisse'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9989230'}, 'year': {'type': 'literal', 'value': '1877'}, 'bio': {'type': 'literal', 'value': "Avocat. - Spécialiste du monde de l'entreprise à la Chambre syndicale d'organisation commerciale (en 1929). - Licencié en droit et docteur en sciences politiques"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb15042710d#about'}, 'name': {'type': 'literal', 'value': 'Cândido Jucá Filho'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99857689'}, 'year': {'type': 'literal', 'value': '1900'}, 'bio': {'type': 'literal', 'value': 'Avocat'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13169620f#about'}, 'name': {'type': 'literal', 'value': 'Joseph de Trémaudan'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9985289'}, 'year': {'type': 'literal', 'value': '1846'}, 'bio': {'type': 'literal', 'value': 'Juge à Paimboeuf. - Historien local'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13075767f#about'}, 'name': {'type': 'literal', 'value': 'Achille Villey-Desmeserets'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9982622'}, 'year': {'type': 'literal', 'value': '1878'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Préfet'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13073219q#about'}, 'name': {'type': 'literal', 'value': 'René Waldeck-Rousseau'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9982481'}, 'year': {'type': 'literal', 'value': '1809'}, 'bio': {'type': 'literal', 'value': "Avocat et homme politique. - Député de Loire-Inférieure à l'assemblée constituante (1848-1849). - Maire de Nantes (nommé en 1870). - Père de Pierre Waldeck-Rousseau (1846-1904)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13032523q#about'}, 'name': {'type': 'literal', 'value': 'Jean-Claude Peyre'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9981601'}, 'year': {'type': 'literal', 'value': '1926'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Conseiller à la Cour de Cassation'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13013616j#about'}, 'name': {'type': 'literal', 'value': 'Victor Hennequin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9980914'}, 'year': {'type': 'literal', 'value': '1816'}, 'bio': {'type': 'literal', 'value': 'Avocat, homme politique, fouriériste et spiritiste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13007474x#about'}, 'name': {'type': 'literal', 'value': 'Angelo Brofferio'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9980556'}, 'year': {'type': 'literal', 'value': '1802'}, 'bio': {'type': 'literal', 'value': 'Avocat, journaliste, homme politique, poète dialectal'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb130070546#about'}, 'name': {'type': 'literal', 'value': 'Amédée Baragnon'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9980539'}, 'year': {'type': 'literal', 'value': '1799'}, 'bio': {'type': 'literal', 'value': 'Avocat et avoué près la Cour royale de Nîmes'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12990838r#about'}, 'name': {'type': 'literal', 'value': 'Mileta S. Novaković'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9979908'}, 'year': {'type': 'literal', 'value': '1878'}, 'bio': {'type': 'literal', 'value': 'Juriste et diplômate'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb129579304#about'}, 'name': {'type': 'literal', 'value': 'François Bovesse'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9978840'}, 'year': {'type': 'literal', 'value': '1890'}, 'bio': {'type': 'literal', 'value': 'Poète, conteur, auteur dramatique. - Journaliste. - Avocat. - Homme politique, député et plusieurs fois ministre. - Fondateur de l\'hebdomadaire "Sambre et Meuse" (1912) et du mensuel "Les lettres mosannes" (1926)'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb103920570#about'}, 'name': {'type': 'literal', 'value': 'Henri Desplaces'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99775496'}, 'year': {'type': 'literal', 'value': '1866'}, 'bio': {'type': 'literal', 'value': "Avocat à Marseille. - Auteur d'essais politiques et juridiques, et d'oeuvres de fiction. - Membre de l'Académie de Marseille (élu en 1903). - Comte"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13026829c#about'}, 'name': {'type': 'literal', 'value': 'Rodolphe Rousseau'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99771428'}, 'year': {'type': 'literal', 'value': '1849'}, 'bio': {'type': 'literal', 'value': 'Avocat à la Cour de Paris'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10237062c#about'}, 'name': {'type': 'literal', 'value': 'Aexandre Dufrèche'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99768652'}, 'year': {'type': 'literal', 'value': '1864'}, 'bio': {'type': 'literal', 'value': 'Magistrat, procureur de la République'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12909377k#about'}, 'name': {'type': 'literal', 'value': 'Anita Augspurg'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9976800'}, 'year': {'type': 'literal', 'value': '1857'}, 'bio': {'type': 'literal', 'value': "Actrice, photographe, docteur en droit de l'Université de Zürich, journaliste et militante féministe. - Vécut à Zurich à partir de 1933"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12431562x#about'}, 'name': {'type': 'literal', 'value': 'Eduardo Jiménez de Aréchaga'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99767691'}, 'year': {'type': 'literal', 'value': '1918'}, 'bio': {'type': 'literal', 'value': "Juriste. - Professeur à l'École de droit de Montevideo"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12821123d#about'}, 'name': {'type': 'literal', 'value': 'Antoine Gérin-Lajoie'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9975120'}, 'year': {'type': 'literal', 'value': '1824'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Romancier et dramaturge'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12815470h#about'}, 'name': {'type': 'literal', 'value': 'Paul Durand-Lapie'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9974992'}, 'year': {'type': 'literal', 'value': '1845'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Professeur au Lycée Ingres, Montauban'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12807847c#about'}, 'name': {'type': 'literal', 'value': 'Joseph Ephraim Casely Hayford'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9974826'}, 'year': {'type': 'literal', 'value': '1866'}, 'bio': {'type': 'literal', 'value': 'Journaliste, écrivain. - Avocat. - Homme politique'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12786000r#about'}, 'name': {'type': 'literal', 'value': 'Robert Sinay'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9974391'}, 'year': {'type': 'literal', 'value': '1911'}, 'bio': {'type': 'literal', 'value': "Avocat honoraire, bâtonnier de l'ordre"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12773613t#about'}, 'name': {'type': 'literal', 'value': 'Luis Garrido'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9974050'}, 'year': {'type': 'literal', 'value': '1898'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Pédagogue. - A été en poste, Universidad nacional autónoma de México'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12675085b#about'}, 'name': {'type': 'literal', 'value': 'António Feijó'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9969998'}, 'year': {'type': 'literal', 'value': '1859'}, 'bio': {'type': 'literal', 'value': 'Poète. - Juriste, diplomate'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12667256k#about'}, 'name': {'type': 'literal', 'value': 'Paul Huot'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9969713'}, 'year': {'type': 'literal', 'value': '1816'}, 'bio': {'type': 'literal', 'value': "Juriste et historien. - Sous-bibliothécaire de la ville de Versailles, avocat puis conseiller à la Cour d'appel de Colmar"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12645770m#about'}, 'name': {'type': 'literal', 'value': 'Pierre Waline'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9969103'}, 'year': {'type': 'literal', 'value': '1894'}, 'bio': {'type': 'literal', 'value': "Délégué général à l'Union des industries métallurgiques et minières. - Professeur de droit social. - Ancien élève de l'Ecole normale supérieure. Agrégé d'histoire et de géographie"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12629678n#about'}, 'name': {'type': 'literal', 'value': 'Léon Palustre'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9968410'}, 'year': {'type': 'literal', 'value': '1838'}, 'bio': {'type': 'literal', 'value': "Archéologue, avocat et critique d'art. - Directeur de la Société française d'archéologie. - Docteur en droit (Paris, 1863)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb126036047#about'}, 'name': {'type': 'literal', 'value': 'Simone Duplan-Miellet'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9967571'}, 'year': {'type': 'literal', 'value': '1943'}, 'bio': {'type': 'literal', 'value': "Avocat au barreau de Paris et chargée d'enseignement à l'Université Paris I-Panthéon"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb125689526#about'}, 'name': {'type': 'literal', 'value': 'Josef Laurenz Kunz'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9965506'}, 'year': {'type': 'literal', 'value': '1890'}, 'bio': {'type': 'literal', 'value': 'Juriste international'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12635761f#about'}, 'name': {'type': 'literal', 'value': 'Louis Rolland'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99645449'}, 'year': {'type': 'literal', 'value': '1877'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Professeur à la Faculté de droit de Paris. - Docteur en droit (Faculté de Paris)'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb125473746#about'}, 'name': {'type': 'literal', 'value': '̓Aléxandros  ̓I. Svṓlos'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9961267'}, 'year': {'type': 'literal', 'value': '1892'}, 'bio': {'type': 'literal', 'value': 'Juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12534487w#about'}, 'name': {'type': 'literal', 'value': 'Yves Jouffa'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9958776'}, 'year': {'type': 'literal', 'value': '1920'}, 'bio': {'type': 'literal', 'value': "Avocat et haut fonctionnaire. - Président de la Ligue des droits de l'homme"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb104312039#about'}, 'name': {'type': 'literal', 'value': 'Théophile Crépon'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99556473'}, 'year': {'type': 'literal', 'value': '1825'}, 'bio': {'type': 'literal', 'value': "Magistrat. - A été procureur impérial à Marseille, Saint-Etienne, Montpellier et Laval. - Procureur général à Lyon. - Premier président de la Cour d'appel de Dijon. - Conseiller à la Cour de cassation"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12517142d#about'}, 'name': {'type': 'literal', 'value': 'Charles Jonnart'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9955560'}, 'year': {'type': 'literal', 'value': '1857'}, 'bio': {'type': 'literal', 'value': "Homme politique. - Député du Pas-de-Calais (1889-1914), gouverneur général de l'Algérie (1900-1911, puis en 1918). - Docteur en droit. - Membre de l'Académie des Sciences morales (élu en 1918) et de l'Académie française (élu en 1923)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12516305h#about'}, 'name': {'type': 'literal', 'value': 'Saoud Benichou'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9955458'}, 'year': {'type': 'literal', 'value': '1835'}, 'bio': {'type': 'literal', 'value': 'Rabbin et juge au tribunal rabbinique de la communauté juive de Tlemcen, Algérie. - Auteur de commentaires sur le Pentateuque et le Talmud'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb102309238#about'}, 'name': {'type': 'literal', 'value': 'Roger Allou'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99552213'}, 'year': {'type': 'literal', 'value': '1855'}, 'bio': {'type': 'literal', 'value': 'Avocat'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12494123w#about'}, 'name': {'type': 'literal', 'value': 'Manuel Rigoberto Paredes'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9951858'}, 'year': {'type': 'literal', 'value': '1870'}, 'bio': {'type': 'literal', 'value': "Juriste. - Titulaire d'une licence en droit (Université Mayor de San Andrés, La Paz, 1891)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb125294945#about'}, 'name': {'type': 'literal', 'value': 'Léonce Jore'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99517149'}, 'year': {'type': 'literal', 'value': '1882'}, 'bio': {'type': 'literal', 'value': "Gouverneur général  de la France d'Outre-Mer. - Docteur en droit (Paris, 1911). - Prénoms complets : Léonce, Alphonse, Noël, Henri"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb169736022#about'}, 'name': {'type': 'literal', 'value': 'Francisco Guilherme Gonçalves Pereira'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99509503'}, 'year': {'type': 'literal', 'value': '1949'}, 'bio': {'type': 'literal', 'value': 'Avocat'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12480510g#about'}, 'name': {'type': 'literal', 'value': 'Jens Christian Hauge'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9949676'}, 'year': {'type': 'literal', 'value': '1915'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Homme politique. - Industriel. - Chef de la résistance norvégienne pendant la 2e guerre mondiale'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb11661415z#about'}, 'name': {'type': 'literal', 'value': 'Armand Désiré de La Fontenelle de Vaudoré'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9949291'}, 'year': {'type': 'literal', 'value': '1784'}, 'bio': {'type': 'literal', 'value': 'Historien et archéologue. - Magistrat'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12449321x#about'}, 'name': {'type': 'literal', 'value': 'Paul Fromageot'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9942865'}, 'year': {'type': 'literal', 'value': '1837'}, 'bio': {'type': 'literal', 'value': "Avocat au barreau de Paris. - Membre du conseil de l'Ordre des avocats (1889-1893). - Historien, spécialiste de Versailles"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12256082f#about'}, 'name': {'type': 'literal', 'value': 'Georges Blondel'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99426611'}, 'year': {'type': 'literal', 'value': '1856'}, 'bio': {'type': 'literal', 'value': "Docteur en droit (1881), agrégé d'histoire (1883), puis agrégé ès lettres. - A été professeur à l'Ecole des sciences politiques et au Collège de France"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12443021n#about'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9941554'}, 'year': {'type': 'literal', 'value': '1849'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Romancier. - Critique musical'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12440167h#about'}, 'name': {'type': 'literal', 'value': 'Dinh Thao Trinh'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9941050'}, 'year': {'type': 'literal', 'value': '1901'}, 'bio': {'type': 'literal', 'value': "Président de l'Alliance des forces nationales de la démocratie et de la paix. - Docteur en droit (Aix-en-Provence, 1928)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12434150j#about'}, 'name': {'type': 'literal', 'value': 'Hugo Staub'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9940033'}, 'year': {'type': 'literal', 'value': '1885'}, 'bio': {'type': 'literal', 'value': 'Juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12428517k#about'}, 'name': {'type': 'literal', 'value': 'Paolo Ungari'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9938909'}, 'year': {'type': 'literal', 'value': '1933'}, 'bio': {'type': 'literal', 'value': 'Juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb124218736#about'}, 'name': {'type': 'literal', 'value': 'Edmond Hugues'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9937668'}, 'year': {'type': 'literal', 'value': '1849'}, 'bio': {'type': 'literal', 'value': "Avocat au Barreau de Gap (à partir de 1870). - Président de la Société d'études historiques, scientifiques et littéraires des Hautes-Alpes (1896-1903 et 1918-1925)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb16643874b#about'}, 'name': {'type': 'literal', 'value': 'Ernest-Germain Hoechster'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99370383'}, 'year': {'type': 'literal', 'value': '1810'}, 'bio': {'type': 'literal', 'value': "Avocat. - Docteur en droit. - Ancien professeur de droit à l'Université de Berne"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10565897w#about'}, 'name': {'type': 'literal', 'value': 'Pierre Philippe Cresp'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99370354'}, 'year': {'type': 'literal', 'value': '1788'}, 'bio': {'type': 'literal', 'value': 'Avocat'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb15051840k#about'}, 'name': {'type': 'literal', 'value': 'Alberto Eduardo Valado Navarro Trindade'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99356331'}, 'year': {'type': 'literal', 'value': '1891'}, 'bio': {'type': 'literal', 'value': 'Avocat et parlementaire. - Troisième vicomte de Trindade'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13211058p#about'}, 'name': {'type': 'literal', 'value': 'Louis Laget'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99351110'}, 'year': {'type': 'literal', 'value': '1821'}, 'bio': {'type': 'literal', 'value': "Avocat au barreau de Nîmes (1847). - Conseiller général (canton de Nîmes, 1865), député (1872-1876) puis sénateur du Gard (1876-1884). - A été sous-préfet d'Uzès, Gard (1848) et préfet du Gard (1870)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12403030s#about'}, 'name': {'type': 'literal', 'value': 'Eberhard Schmidt'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9934088'}, 'year': {'type': 'literal', 'value': '1891'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Ancien professeur de droit. - Spécialiste du droit pénal'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12818564k#about'}, 'name': {'type': 'literal', 'value': 'Félicien Cattier'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99340678'}, 'year': {'type': 'literal', 'value': '1869'}, 'bio': {'type': 'literal', 'value': "Docteur en droit, docteur en sciences politiques et administratives de l'Université libre de Bruxelles, ULB. - Professeur de droit public, droit colonial puis carrière de banquier, vice-président de la Société générale de Belgique, 1932-1939"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10226275t#about'}, 'name': {'type': 'literal', 'value': 'Henri Rozy'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99339431'}, 'year': {'type': 'literal', 'value': '1829'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Professeur de droit administratif à la faculté de droit de Toulouse'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12632484j#about'}, 'name': {'type': 'literal', 'value': 'Tudor Radu Popescu'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99330739'}, 'year': {'type': 'literal', 'value': '1913'}, 'bio': {'type': 'literal', 'value': 'Juriste et historien'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb105239359#about'}, 'name': {'type': 'literal', 'value': 'Louis Durat Lasalle'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99324051'}, 'year': {'type': 'literal', 'value': '1794'}, 'bio': {'type': 'literal', 'value': 'Avocat'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12774416j#about'}, 'name': {'type': 'literal', 'value': 'Charles Abrams'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99317358'}, 'year': {'type': 'literal', 'value': '1901'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Urbaniste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13010849b#about'}, 'name': {'type': 'literal', 'value': 'Camille Gérardin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99313700'}, 'year': {'type': 'literal', 'value': '1837'}, 'bio': {'type': 'literal', 'value': "Juriste spécialiste du droit romain et traducteur d'ouvrages juridiques. - Prénoms complets : Camille Joseph"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb129522858#about'}, 'name': {'type': 'literal', 'value': 'Victor Émion'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99311647'}, 'year': {'type': 'literal', 'value': '1826'}, 'bio': {'type': 'literal', 'value': "Avocat à la Cour d'appel de Paris. - Sous-préfet"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb105214719#about'}, 'name': {'type': 'literal', 'value': 'Rodolfo Calamandrei'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99310454'}, 'year': {'type': 'literal', 'value': '1857'}, 'bio': {'type': 'literal', 'value': 'Avocat, homme politique, écrivain'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb107478541#about'}, 'name': {'type': 'literal', 'value': 'Toussaint-Ange Cotelle'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99308468'}, 'year': {'type': 'literal', 'value': '1795'}, 'bio': {'type': 'literal', 'value': "Avocat. - Professeur de droit administratif à l'École des ponts et chaussées"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12384697f#about'}, 'name': {'type': 'literal', 'value': 'Auguste Dubois'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9930547'}, 'year': {'type': 'literal', 'value': '1866'}, 'bio': {'type': 'literal', 'value': "Docteur en droit. - Professeur d'économie politique à la Faculté de droit de Poitiers"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10431805n#about'}, 'name': {'type': 'literal', 'value': 'Georges Deloison'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99303643'}, 'year': {'type': 'literal', 'value': '1846'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Prénoms complets : Georges, Julien'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12382071m#about'}, 'name': {'type': 'literal', 'value': 'Francis James Gillen'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9929968'}, 'year': {'type': 'literal', 'value': '1856'}, 'bio': {'type': 'literal', 'value': 'Magistrat ayant participé aux Services officiels de protection des Aborigènes à Alice Springs, Australie du Sud (en 1927)'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10265020k#about'}, 'name': {'type': 'literal', 'value': 'Émile Cauvet'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99297743'}, 'year': {'type': 'literal', 'value': '1816'}, 'bio': {'type': 'literal', 'value': 'Avocat à Narbonne, puis magistrat. - Président du tribunal civil de Narbonne (en 1870). - Président de chambre à la cour de Montpellier (en 1872)'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10253080r#about'}, 'name': {'type': 'literal', 'value': 'Félix Rivet'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99291841'}, 'year': {'type': 'literal', 'value': '1818'}, 'bio': {'type': 'literal', 'value': 'Avocat général à la Martinique'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10497217p#about'}, 'name': {'type': 'literal', 'value': 'Emmanuel Delamarre'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99289187'}, 'year': {'type': 'literal', 'value': '1774'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Avocat, puis magistrat. - Conseiller à la cour de Rennes'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10746009r#about'}, 'name': {'type': 'literal', 'value': 'André-Paul Morillot'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99267487'}, 'year': {'type': 'literal', 'value': '1849'}, 'bio': {'type': 'literal', 'value': "Avocat général. - Avocat au Conseil d'État et à la Cour de cassation"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10268181s#about'}, 'name': {'type': 'literal', 'value': 'Léon Dubarle'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99262080'}, 'year': {'type': 'literal', 'value': '1845'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Prénoms complets : Léon, Auguste, François'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12356250j#about'}, 'name': {'type': 'literal', 'value': 'Félix Martin-Doisy'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9925152'}, 'year': {'type': 'literal', 'value': '1795'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Économiste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12361957w#about'}, 'name': {'type': 'literal', 'value': 'Mario Rotondi'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99250449'}, 'year': {'type': 'literal', 'value': '1900'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Professeur de droit privé'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb123473756#about'}, 'name': {'type': 'literal', 'value': 'Riccardo Orestano'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9923208'}, 'year': {'type': 'literal', 'value': '1909'}, 'bio': {'type': 'literal', 'value': "Juriste. - Membre de l'Académie des Lincei"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12334542v#about'}, 'name': {'type': 'literal', 'value': 'William Seal Carpenter'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9920438'}, 'year': {'type': 'literal', 'value': '1890'}, 'bio': {'type': 'literal', 'value': 'Juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb123279623#about'}, 'name': {'type': 'literal', 'value': 'Charles Pire'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9919130'}, 'year': {'type': 'literal', 'value': '1941'}, 'bio': {'type': 'literal', 'value': "Docteur en droit, à Liège (en 1993). - Expert numismate. - Homme politique belge d'extrême-droite qui, après avoir été membre du Parti social-chrétien, occupe différentes fonctions au sein du Front National de Belgique avant d'être désigné en avril 2011 comme président\u200f   (2011-2012)\u200f"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12319086w#about'}, 'name': {'type': 'literal', 'value': 'Jacob ter Meulen'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9917533'}, 'year': {'type': 'literal', 'value': '1884'}, 'bio': {'type': 'literal', 'value': 'Docteur en droit public'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12317808t#about'}, 'name': {'type': 'literal', 'value': 'John Chipman Gray'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9917270'}, 'year': {'type': 'literal', 'value': '1839'}, 'bio': {'type': 'literal', 'value': 'Juriste. - A été professeur de droit à la Harvard law school, Harvard university, USA'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb123152765#about'}, 'name': {'type': 'literal', 'value': 'Charles Cheney Hyde'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9916820'}, 'year': {'type': 'literal', 'value': '1873'}, 'bio': {'type': 'literal', 'value': 'Juriste. - A été professeur de droit à Northwestern university, Portland, USA'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12315211k#about'}, 'name': {'type': 'literal', 'value': 'Frederic Seebohm'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9916798'}, 'year': {'type': 'literal', 'value': '1833'}, 'bio': {'type': 'literal', 'value': 'Historien et juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12315170t#about'}, 'name': {'type': 'literal', 'value': 'Max Radin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9916779'}, 'year': {'type': 'literal', 'value': '1880'}, 'bio': {'type': 'literal', 'value': "Juriste. - Fut professeur à l'University of California, USA"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb123119106#about'}, 'name': {'type': 'literal', 'value': 'Edwin Montefiore Borchard'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9916221'}, 'year': {'type': 'literal', 'value': '1884'}, 'bio': {'type': 'literal', 'value': "Juriste. - A été expert de droit international auprès de la Cour d'arbitrage de La haye, Pays-bas (en 1915)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb123010784#about'}, 'name': {'type': 'literal', 'value': 'Vittorio Emanuele Orlando'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9914155'}, 'year': {'type': 'literal', 'value': '1860'}, 'bio': {'type': 'literal', 'value': 'Juriste, spécialiste de droit public. - Président du Conseil (octobre 1917), ministre de la Justice, chef de la délégation italienne à la Conférence de la Paix de Versailles'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb122990971#about'}, 'name': {'type': 'literal', 'value': 'Horace Émile Say'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9913739'}, 'year': {'type': 'literal', 'value': '1794'}, 'bio': {'type': 'literal', 'value': "Économiste. - A été professeur d'économie industrielle au Conservatoire des Arts et Métiers, Paris. - A été professeur d'économie politique au Collège de France, Paris. - Juge au Tribunal de commerce de la Seine (1831-)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb104998123#about'}, 'name': {'type': 'literal', 'value': 'Joseph Gautier'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/991150203812803250005'}, 'year': {'type': 'literal', 'value': '1858'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Poète'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb130833494#about'}, 'name': {'type': 'literal', 'value': 'Léon Cornil'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99114609'}, 'year': {'type': 'literal', 'value': '1882'}, 'bio': {'type': 'literal', 'value': "Juriste. - Procureur général à la Cour de Cassation. - Professeur à l'Université libre de Bruxelles"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb122844595#about'}, 'name': {'type': 'literal', 'value': 'Paul Bureau'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910915'}, 'year': {'type': 'literal', 'value': '1865'}, 'bio': {'type': 'literal', 'value': "Docteur en droit (Paris, 1890). - Juriste et sociologue. - A été professeur à la Faculté libre de droit, à l'Ecole des hautes études en sciences sociales et de droit international à l'Institut catholique, Paris"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb122843754#about'}, 'name': {'type': 'literal', 'value': 'Georg Jellinek'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910860'}, 'year': {'type': 'literal', 'value': '1851'}, 'bio': {'type': 'literal', 'value': 'Juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb122824570#about'}, 'name': {'type': 'literal', 'value': 'Élias Regnault'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910357'}, 'year': {'type': 'literal', 'value': '1801'}, 'bio': {'type': 'literal', 'value': 'Avocat. - Ministre des finances après 1848'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12281787h#about'}, 'name': {'type': 'literal', 'value': 'Helmut Coing'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910229'}, 'year': {'type': 'literal', 'value': '1912'}, 'bio': {'type': 'literal', 'value': "Juriste, spécialiste en droit privé. - A été professeur de droit. - Membre de l'Académie internationale de droit comparé, Paris (en 1987)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb122771335#about'}, 'name': {'type': 'literal', 'value': 'Edward Allan Farnsworth'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9908939'}, 'year': {'type': 'literal', 'value': '1928'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Professeur de droit, Columbia university, New York, N.Y.'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12276692t#about'}, 'name': {'type': 'literal', 'value': 'George Crispe Whiteley'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9908892'}, 'year': {'type': 'literal', 'value': '1845'}, 'bio': {'type': 'literal', 'value': 'Juriste'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12268336s#about'}, 'name': {'type': 'literal', 'value': 'Ferdinand Cassassoles'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9907443'}, 'year': {'type': 'literal', 'value': '1804'}, 'bio': {'type': 'literal', 'value': 'Juge à Condom puis à Agen. - Historien'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12211476k#about'}, 'name': {'type': 'literal', 'value': 'Roland Boscary-Monsservin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9897902'}, 'year': {'type': 'literal', 'value': '1904'}, 'bio': {'type': 'literal', 'value': "Avocat et homme politique. - Maire de Rodez, Aveyron (1965-1983). - Sénateur de l'Aveyron (1971-1983). - Prénoms complets : Roland, Marie, Joseph"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12207783x#about'}, 'name': {'type': 'literal', 'value': 'Paul de Geouffre de La Pradelle'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9897081'}, 'year': {'type': 'literal', 'value': '1902'}, 'bio': {'type': 'literal', 'value': "Universitaire. - Professeur à la Faculté de droit et de science politique, Université d'Aix-Marseille. - Directeur de l'Institut d'études politiques, Université d'Aix-Marseille. - Fils d'Albert de Geouffre de Lapradelle (1871-1955), juriste et frère de Raymond de Geouffre de La Pradelle (1910-....), avocat à la cour. - Prénoms complets : Paul, Marie, Albert, Raymond"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12206305s#about'}, 'name': {'type': 'literal', 'value': 'Louis Courcelle'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9896812'}, 'year': {'type': 'literal', 'value': '1862'}, 'bio': {'type': 'literal', 'value': 'Pseud. de Louis Pourcelle. - Avocat. - Attaché au cabinet du préfet de police'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb10730050j#about'}, 'name': {'type': 'literal', 'value': 'Jean Esprit Marie Pierre Lemoine de Villeneuve'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/98963345'}, 'year': {'type': 'literal', 'value': '1790'}, 'bio': {'type': 'literal', 'value': 'Jurisconsulte, avocat, spécialiste de législation commerciale'}}

# %%
result_bnf = []
for l in rc_bnf['results']['bindings']:
        try: 
            name = l['name']['value']
        except Exception as e:
            name = ''
        try: 
            sName = l['sName']['value']
        except Exception as e:
            sName = ''
        try: 
            uri = l['uri']['value']
        except Exception as e:
            uri = ''
        try: 
            bio = l['bio']['value']
        except Exception as e:
            bio = ''
        try: 
            year = l['year']['value']
        except Exception as e:
            year = ''
        result_bnf.append([l['s']['value'], uri, name, sName, year, bio])

# %%
print(len(result_bnf))
result_bnf[:2]
# Out:
# 11201
# [['http://data.bnf.fr/ark:/12148/cb12981404c#about',
#   'http://viaf.org/viaf/99996033',
#   'Léon Garnier',
#   '',
#   '1836',
#   "Juriste. - Administrateur et homme de lettres. - En poste à la Préfecture de la Seine. - Frère de l'explorateur Francis Garnier (1839-1873)"],
#  ['http://data.bnf.fr/ark:/12148/cb13484444m#about',
#   'http://viaf.org/viaf/9999219',
#   'Gaston de Pawlowski',
#   '',
#   '1874',
#   'Docteur en droit. - Critique littéraire et théâtral. - Rédacteur en chef de "Comoedia"']]

# %%
query_2= """
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbp:  <http://dbpedia.org/property/>
PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>

SELECT DISTINCT  ?s ?uri ?name (year(xsd:dateTime(?Birth_Date)) AS ?year) ?abstract
WHERE
  {   { ?s  a              dbo:Economist ;
          # "Economist" has a class function, he explains the use of the "a".
            dbp:birthDate  ?Birth_Date
        FILTER ( xsd:date(?Birth_Date) > "1770-01-01"^^xsd:date )
          # We use this filter to preserve only the persons born after 1800. 
          # Here, the method is a little different because we have a date and not a year. 
          # We convert above the date to a year to have the same format as BnF Data.
        OPTIONAL
          { ?s  owl:sameAs  ?uri
            FILTER regex(?uri, "viaf", "i")
          }
        OPTIONAL
          { ?s  dbp:name  ?name }
        FILTER ( xsd:string(?name) != "Samuel Bowles" )
     # We use this filter to remove the data concerning "Samuel Bowles" 
     # because there is mistakes in data i.e he is related to wrong people -eg. William Turner (cf. https://dbpedia.org/page/Samuel_Bowles_(economist)).
     # We will can fix this problem later, by entering data about him manually.
      }
    UNION
      { ?s  ?propriety  dbr:Economist
      # Here, "Economist" is a instance, we have as triplet "subject predicate object". 
      # In DBpedia, "Economist" is define as a instance and at the same time as a class. So we use both.
        FILTER ( xsd:date(?Birth_Date) > "1770-01-01"^^xsd:date )
        OPTIONAL
          { ?s  owl:sameAs  ?uri
            FILTER regex(?uri, "viaf", "i")
          }
        OPTIONAL
          { ?s  dbp:name  ?name
            FILTER ( xsd:string(?name) != "Samuel Bowles" )
          }    
      }
    UNION
      { ?s  ?p             dbr:Jurist ;
            dbp:birthDate  ?Birth_Date
        FILTER ( xsd:date(?Birth_Date) > "1770-01-01"^^xsd:date )
        OPTIONAL
          { ?s  dbp:name  ?name
            FILTER ( xsd:string(?name) != "Marcus Tullius Cicero" )
       # We use this filter to remove the data concerning "Cicero". 
       # He appears in results, certainly because his date of birth contains the sign "-" (cf. https://dbpedia.org/page/Cicero).
            FILTER ( xsd:string(?name) != "Samuel Bowles" )
          }
        OPTIONAL
          { ?s  owl:sameAs  ?uri
            FILTER regex(?uri, "viaf", "i")
          }
      }
    UNION
      { ?s  ?p             dbr:Lawyer ;
            dbp:birthDate  ?Birth_Date
        FILTER ( xsd:date(?Birth_Date) > "1770-01-01"^^xsd:date )
        OPTIONAL
          { ?s  dbp:name  ?name
            FILTER ( xsd:string(?name) != "Marcus Tullius Cicero" )
            FILTER ( xsd:string(?name) != "Samuel Bowles" )
          }
      }
    UNION
      { ?s  a              dbr:Professor ;
            dbp:birthDate  ?Birth_Date ;
            dbo:abstract   ?abstract
        FILTER ( ( ( ( regex(?abstract, "lawyer", "i") || regex(?abstract, "jurist", "i") ) || regex(?abstract, "juriste", "i") ) || regex(?abstract, "attorney", "i") ) || regex(?abstract, "legal professional", "i") )
        OPTIONAL
          { ?s  dbp:name  ?name
            FILTER ( xsd:string(?name) != "Marcus Tullius Cicero" )
            FILTER ( xsd:string(?name) != "Samuel Bowles" )
          }
        FILTER ( xsd:date(?Birth_Date) > "1770-01-01"^^xsd:date )
        OPTIONAL
          { ?s  owl:sameAs  ?uri
            FILTER regex(?uri, "viaf", "i")
          }
      }
  }
ORDER BY DESC(?uri)
"""

# %% [markdown]
# In this query, we have made the choice to aggregate, by a UNION clause, several queries to maximise the results' number. Also we request the "economists" and the "jurists" in only one query.
#
# Obviously, we chose classes and instances directly related to our population, but also the "professor" instance, because some "economists" or "jurists" are in this instance (we have tried with and without them, and there more result when we use them).
#
# Also, we excluse all classes because they don't add more result, except the "Economist" class (we keep it)
#
# For exemple, we exclude the resource "personFunction" and the resource "Jurists" because they add no more data. Additionally, we keep only the "Professor" instance for the jurists (it returns result only for the jurists).

# %%
sparql = SPARQLWrapper("https://dbpedia.org/sparql")  ## returnFormat=RDFXML)  [LOCALHOST]

# %%
sparql.setQuery(query_2)
sparql.setReturnFormat(JSON)

# %%
rc_db = sparql.queryAndConvert()

# %%
# Number of rows in the result
len(rc_db['results']['bindings'])
# Out:
# 8545

# %%
# Inspect the first three rows
i = 0
for l in rc_db['results']['bindings']:
    if i <100:
        print(l)
        i += 1
# Out:
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/António_de_Almeida_Santos'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99921066'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'António de Almeida Santos'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1926'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Anita_Augspurg'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9976800'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Anita Augspurg'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1857'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Mason_Gaffney'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9960617'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Mason Gaffney'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1923'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Hermann_Heinrich_Gossen'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9939728'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Hermann Heinrich Gossen'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1810'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Gottfried_Haberler'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99257315'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Gottfried Haberler'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1900'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Michael_C._Burda'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9922987'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Michael C. Burda'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1959'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Xavier_Vives'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9920331'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Xavier Vives'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1955'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Vittorio_Emanuele_Orlando'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9914155'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Vittorio Emanuele Orlando'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1860'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/James_M._Poterba'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910825'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'James M. Poterba'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1958'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/David_Laibman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910613'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'David Laibman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1942'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Claus_Roxin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9910548'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Claus Roxin'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1931'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Manuel_Monteiro'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99006932'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Manuel Monteiro'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1962'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Celso_Lafer'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9889585'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Celso Lafer'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1941'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Czesław_Znamierowski'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9887798'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Czesław Znamierowski'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1888'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Gaidis_Bērziņš'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9880150325560110090006'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Gaidis Bērziņš'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1970'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Irene_Tinker'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9859454'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Irene Tinker'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1927'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/José_Dias_Ferreira'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/98583992'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'José Dias Ferreira'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1837'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Michio_Morishima'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9850889'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Michio Morishima'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1923'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Thomas_Hodgskin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9847801'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Thomas Hodgskin'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1787'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Luigi_Amoroso'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9838425'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Luigi Amoroso'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1886'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Oskar_Morgenstern'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/98356107'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Oskar Morgenstern'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1902'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/L._Randall_Wray'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/98312857'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'L. Randall Wray'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1953'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Will_Hutton'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/97918723'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Will Hutton'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1950'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Green_Hackworth'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/97878678'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Green H. Hackworth'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1883'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Frank_de_Grave'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/973152451232506650009'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Frank de Grave'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1955'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Patrick_Gaines_Goode'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9708869'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Patrick Gaines Goode'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1798'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Russ_Roberts'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/96524'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Russ Roberts'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1954'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Carlo_M._Cipolla'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/960147665805060670004'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Carlo M. Cipolla'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1922'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Roy_Charles_Gamble'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/95891964'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1887'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Myron_Scholes'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/95629812'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Myron Scholes'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1941'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Stati_Statev'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/95573826'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Stati Statev'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1955'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/J._Bradford_DeLong'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/95318758'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'J. Bradford DeLong'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1960'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Francis_Lieber'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/95285806'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1798'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/John_B._Condliffe'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/95173767'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'John Bell Condliffe'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1891'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Peter_Howitt_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94948743'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Peter W. Howitt'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1946'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Alastair_Nicholson'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94863580'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Alastair Nicholson'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1938'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Sanford_J._Grossman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94786986'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sanford J. Grossman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1953'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Steven_N._S._Cheung'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94744688'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Steven Cheung'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1935'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/John_Luke_Gallup'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9474330'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'John Luke Gallup'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1962'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Peter_Morici'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94636801'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Peter Morici'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1948'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/James_Ball_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94591447'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'James Ball'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1933'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lawrence_H._White'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94588554'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Lawrence H. White'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1954'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/George_Loewenstein'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94551'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'George Loewenstein'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1955'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Roy_Harrod'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94499786'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sir Roy Harrod'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1900'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Johann_Heinrich_von_Thünen'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94496'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Johann Heinrich von Thünen'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1783'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Alfred_Eichner'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94384300'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Alfred S. Eichner'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1937'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/George_Judge'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94343568'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'George G. Judge'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1925'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/David_Kinley'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94294714'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'David Kinley'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1861'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Glenn_Loury'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/94011658'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Glenn Loury'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1948'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Cuno_Pümpin'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93983810'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Cuno Pümpin'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1939'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Charles_Horioka'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93855644'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Charles Horioka'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1956'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Jean_Tirole'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93736926'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Jean Tirole'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1953'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Athanasios_Asimakopulos'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93619789'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Athanasios Asimakopulos'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1930'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Anwar_Shaikh_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93352031'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Anwar Shaikh'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1945'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Jerry_A._Hausman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93289944'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Jerry A. Hausman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1946'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Francis_Burt'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93068031'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sir Francis Burt'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1918'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Percival_Halse_Rogers'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/93041480'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Percival Halse Rogers'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1883'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Sándor_Plósz'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9280942'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sándor Plósz'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1846'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Koichi_Hamada'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92666949'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Koichi Hamada'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1936'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lewis_Solmon'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92625592'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Lewis C. Solmon'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1942'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/William_Dickens'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92512572'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'William T. Dickens'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1953'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Bernard_Sugerman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92509214'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Bernard Sugerman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1904'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Richard_Ruggles'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92504818'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Richard F. Ruggles'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1916'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Arnold_Plant'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92387250'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sir Arnold Plant'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1898'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Michael_J._Piore'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92384646'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Michael J. Piore'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1940'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Richard_Russell_Sr.'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9236497'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Richard Russell Sr.'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1861'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/William_Vickrey'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92276341'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'William Vickrey'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1914'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/John_Doyle_(judge)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92261949'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'John Doyle'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1945'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Yves_Balasko'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92260192'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Yves Balasko'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1945'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Jan_Kregel'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92051573'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Jan Kregel'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1944'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/W._M._Gorman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/92016304'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'W. M. Gorman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1923'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Stephen_Hymer'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91930977'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Stephen Hymer'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1934'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Denis_Sargan'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91851877'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'J. Denis Sargan'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1924'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Stuart_Altman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91796877'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Stuart H. Altman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1937'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Eudine_Barriteau'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91729811'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Eudine Barriteau'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1954'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Boyan_Jovanovic'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91668796'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Boyan Jovanovic'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1951'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Rudolf_Winter-Ebmer'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91590790'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Rudolf Winter-Ebmer'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1961'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Susan_Himmelweit'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91548966'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Susan Himmelweit'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1948'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Robert_Eisner'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91384837'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Robert Eisner'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1922'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/W._Brian_Arthur'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91237168'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'William Brian Arthur'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1945'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Johannes_Andenæs'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91232250'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Johannes Andenæs'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1912'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ralph_Harris,_Baron_Harris_of_High_Cross'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91022284'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'The Lord Harris of High Cross'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1924'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Vincent_Cyril_Richard_Arthur_Charles_Crabbe'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9097469'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1923'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Frank_Hahn'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/90720045'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Frank Hahn'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1925'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Peter_Kenneth_Newman'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/90664217'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Peter Newman'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1928'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Marie_T._Mora'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/90454842'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Marie T. Mora'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1969'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Pietro_Balestra_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/90348872'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Pietro Balestra'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1935'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Giovanni_Maria_Flick'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/90131599'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Giovanni Maria Flick'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1940'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Christoph_M._Schmidt'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/89860971'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Christoph M. Schmidt'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1962'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/John_Hicks'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/89700672'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sir John Hicks'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1904'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tivadar_Pauler'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/89325697'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tivadar Pauler'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1816'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Francis_Hirst'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88920537'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Francis W. Hirst'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1873'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Edwin_Mills_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88575085'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Edwin S. Mills'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1928'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tomáš_Sedláček_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88569916'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tomáš Sedláček'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1977'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Emery_B._Denny'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88507182'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Emery B. Denny'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1892'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Edith_Kuiper'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88414700'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Edith Kuiper'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1960'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ali_Gomaa'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88345236'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Ali Gomaa'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1952'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/David_Gordon_(economist)'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88341444'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'David Gordon'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1944'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Stefano_Rodotà'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88145923'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Stefano Rodotà'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1933'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Branko_Milanović'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/88084937'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Branko Milanović'}, 'year': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '1953'}}

# %%
# Create a list with URI, VIAF URI, name, year
result_dbpedia = []
for l in rc_db['results']['bindings']:
        try: 
            name = l['name']['value']
        except Exception as e:
            name = ''
        try: 
            uri = l['uri']['value']
        except Exception as e:
            uri = ''
        try: 
            year = l['year']['value']
        except Exception as e:
            uri = ''
        result_dbpedia.append([l['s']['value'], uri, name, year])

# %%
# Inspect the first three of the list
result_dbpedia[:10]
# Out:
# [['http://dbpedia.org/resource/António_de_Almeida_Santos',
#   'http://viaf.org/viaf/99921066',
#   'António de Almeida Santos',
#   '1926'],
#  ['http://dbpedia.org/resource/Anita_Augspurg',
#   'http://viaf.org/viaf/9976800',
#   'Anita Augspurg',
#   '1857'],
#  ['http://dbpedia.org/resource/Mason_Gaffney',
#   'http://viaf.org/viaf/9960617',
#   'Mason Gaffney',
#   '1923'],
#  ['http://dbpedia.org/resource/Hermann_Heinrich_Gossen',
#   'http://viaf.org/viaf/9939728',
#   'Hermann Heinrich Gossen',
#   '1810'],
#  ['http://dbpedia.org/resource/Gottfried_Haberler',
#   'http://viaf.org/viaf/99257315',
#   'Gottfried Haberler',
#   '1900'],
#  ['http://dbpedia.org/resource/Michael_C._Burda',
#   'http://viaf.org/viaf/9922987',
#   'Michael C. Burda',
#   '1959'],
#  ['http://dbpedia.org/resource/Xavier_Vives',
#   'http://viaf.org/viaf/9920331',
#   'Xavier Vives',
#   '1955'],
#  ['http://dbpedia.org/resource/Vittorio_Emanuele_Orlando',
#   'http://viaf.org/viaf/9914155',
#   'Vittorio Emanuele Orlando',
#   '1860'],
#  ['http://dbpedia.org/resource/James_M._Poterba',
#   'http://viaf.org/viaf/9910825',
#   'James M. Poterba',
#   '1958'],
#  ['http://dbpedia.org/resource/David_Laibman',
#   'http://viaf.org/viaf/9910613',
#   'David Laibman',
#   '1942']]

# %%
query_3= """
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  wd:   <http://www.wikidata.org/entity/>
PREFIX  wdt:  <http://www.wikidata.org/prop/direct/>

SELECT DISTINCT  ?s ?uri ?name ?year
WHERE
  {   { ?s  wdt:P106  wd:Q188094 } # Economists
    UNION
      { ?s  wdt:P106  wd:Q185351 } # Jurists
    UNION
      { ?s  wdt:106  wd:Q40348 } # Lawyer
    OPTIONAL
      { ?s  wdt:P569  ?dob } # date of birth
    OPTIONAL
      { ?s  wdt:P214  ?oldURI
        BIND(uri(concat("http://viaf.org/viaf/", strafter(str(?oldURI), ""))) AS ?uri) # It's useful to have the URI VIAF in the same and merge data.
      }
    BIND(year(?dob) AS ?year)
    FILTER ( ?year > 1770 )
    OPTIONAL
      { ?s  rdfs:label  ?name
        FILTER ( lang(?name) = "en" )
      }
  }
"""

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")  ## returnFormat=RDFXML)  [LOCALHOST]

# %%
sparql.setQuery(query_3)
sparql.setReturnFormat(JSON)

# %%
rc_wk = sparql.queryAndConvert()

# %%
# Number of rows in the result
len(rc_wk['results']['bindings'])
# Out:
# 53707

# %%
# Create a list with URI, VIAF URI, name, year
result_wikidata = []
for l in rc_wk['results']['bindings']:
        try: 
            name = l['name']['value']
        except Exception as e:
            name = ''
        try: 
            uri = l['uri']['value']
        except Exception as e:
            uri = ''
        try: 
            year = l['year']['value']
        except Exception as e:
            uri = ''
        result_wikidata.append([l['s']['value'], uri, name, year])

# %%
result_wikidata[:10]
# Out:
# [['http://www.wikidata.org/entity/Q72628',
#   'http://viaf.org/viaf/54958174',
#   'Alfred von Kiderlen-Waechter',
#   '1852'],
#  ['http://www.wikidata.org/entity/Q72568',
#   'http://viaf.org/viaf/71423827',
#   'Alfred Lichtenstein',
#   '1889'],
#  ['http://www.wikidata.org/entity/Q72553',
#   'http://viaf.org/viaf/62342475',
#   'Heinrich von Bülow',
#   '1792'],
#  ['http://www.wikidata.org/entity/Q65539',
#   'http://viaf.org/viaf/4137633',
#   'Peter Altmaier',
#   '1958'],
#  ['http://www.wikidata.org/entity/Q65561',
#   'http://viaf.org/viaf/232142151',
#   'Hans Apel',
#   '1932'],
#  ['http://www.wikidata.org/entity/Q85944',
#   'http://viaf.org/viaf/3369267',
#   'Christoph Flügge',
#   '1947'],
#  ['http://www.wikidata.org/entity/Q86043',
#   'http://viaf.org/viaf/27864307',
#   'Hugo Sinzheimer',
#   '1875'],
#  ['http://www.wikidata.org/entity/Q85917',
#   'http://viaf.org/viaf/786495',
#   'Adolf Wermuth',
#   '1855'],
#  ['http://www.wikidata.org/entity/Q89698',
#   'http://viaf.org/viaf/108341042',
#   'Hans F. Zacher',
#   '1928'],
#  ['http://www.wikidata.org/entity/Q89713',
#   'http://viaf.org/viaf/25353475',
#   'Johann Friedrich Gottfried Eiselen',
#   '1785']]

# %%
engine = create_engine('sqlite:///database.sqlite_1', echo=False)

# %%
df_bnf = pd.DataFrame([f for f in result_bnf if len(f[1]) > 0], columns=['uri_bnf', 'viaf', 'name_bnf', 'sName', 'year_bnf', 'bio_bnf'])
print(len(df_bnf))
df_bnf.fillna('')

df_bnf.head()
# Out:
# 9147
#                                            uri_bnf  \
# 0  http://data.bnf.fr/ark:/12148/cb12981404c#about
# 1  http://data.bnf.fr/ark:/12148/cb13484444m#about
# 2  http://data.bnf.fr/ark:/12148/cb134841632#about
# 3  http://data.bnf.fr/ark:/12148/cb13379520q#about
# 4  http://data.bnf.fr/ark:/12148/cb13338312g#about
#
#                             viaf             name_bnf sName year_bnf  \
# 0  http://viaf.org/viaf/99996033         Léon Garnier           1836
# 1   http://viaf.org/viaf/9999219  Gaston de Pawlowski           1874
# 2   http://viaf.org/viaf/9999131   Jean-Michel Berton           1794
# 3   http://viaf.org/viaf/9995247     Emmanuel Mathieu           1852
# 4   http://viaf.org/viaf/9994322  Josiah Henry Benton           1843
#
#                                              bio_bnf
# 0  Juriste. - Administrateur et homme de lettres....
# 1  Docteur en droit. - Critique littéraire et thé...
# 2  Écrivain politique, avocat à la Cour de cassat...
# 3                     Docteur en droit (Paris, 1873)
# 4                             Juriste. - Bibliophile

# %%
df_bnf.to_sql('df_bnf', con=engine)

# %%
df_dbp = pd.DataFrame([p for p in result_dbpedia if len(p[1]) > 0], columns=['uri_dbp', 'viaf', 'name_dbp', 'date_dbp'])
print(len(df_dbp))
df_dbp.fillna('')
df_dbp[-10:]
# Out:
# 1747
#                                                 uri_dbp  \
# 1737          http://dbpedia.org/resource/Paul_A._Baran
# 1738          http://dbpedia.org/resource/Menachem_Elon
# 1739          http://dbpedia.org/resource/József_Antall
# 1740  http://dbpedia.org/resource/Luiz_Carlos_Bresse...
# 1741          http://dbpedia.org/resource/Michael_Kaser
# 1742          http://dbpedia.org/resource/Merton_Miller
# 1743  http://dbpedia.org/resource/Peter_J._Hammond_(...
# 1744   http://dbpedia.org/resource/José_Hermano_Saraiva
# 1745               http://dbpedia.org/resource/Alf_Ross
# 1746              http://dbpedia.org/resource/Max_Weber
#
#                                 viaf                     name_dbp date_dbp
# 1737  http://viaf.org/viaf/100304945         Paul Alexander Baran     1909
# 1738  http://viaf.org/viaf/100286138                Menachem Elon     1923
# 1739  http://viaf.org/viaf/100281452                József Antall     1932
# 1740  http://viaf.org/viaf/100278275  Luiz Carlos Bresser-Pereira     1934
# 1741  http://viaf.org/viaf/100274542                Michael Kaser     1926
# 1742  http://viaf.org/viaf/100258394                Merton Miller     1923
# 1743  http://viaf.org/viaf/100246974                Peter Hammond     1945
# 1744  http://viaf.org/viaf/100238197         José Hermano Saraiva     1919
# 1745  http://viaf.org/viaf/100233686                     Alf Ross     1899
# 1746  http://viaf.org/viaf/100180950                                  1864

# %%
df_dbp.to_sql('df_dbp', con=engine)

# %%
df_wk= pd.DataFrame([p for p in result_wikidata if len(p[1]) > 0], columns=['uri_wk', 'viaf', 'name_wk', 'date_wk'])
print(len(df_wk))
df_wk.fillna('')
df_wk.head()
# Out:
# 40626
#                                   uri_wk                            viaf  \
# 0  http://www.wikidata.org/entity/Q72628   http://viaf.org/viaf/54958174
# 1  http://www.wikidata.org/entity/Q72568   http://viaf.org/viaf/71423827
# 2  http://www.wikidata.org/entity/Q72553   http://viaf.org/viaf/62342475
# 3  http://www.wikidata.org/entity/Q65539    http://viaf.org/viaf/4137633
# 4  http://www.wikidata.org/entity/Q65561  http://viaf.org/viaf/232142151
#
#                         name_wk date_wk
# 0  Alfred von Kiderlen-Waechter    1852
# 1           Alfred Lichtenstein    1889
# 2            Heinrich von Bülow    1792
# 3                Peter Altmaier    1958
# 4                     Hans Apel    1932

# %%
df_wk.to_sql('df_wk', con=engine)

# %%
merged_df_1 = pd.merge( df_wk, df_dbp , on='viaf', how='inner', sort='date_dbp')

# %%
print("the number of merged data from DBpedia and Wikidata is ",len(merged_df_1), "rows.")
print("")
print("The proportion of the number of merged data from DBpedia with Wikidata is ",((len(merged_df_1))/(len(df_dbp))*100),"%")
print("")
print("proportion of the number of merged data from Wikidata with Wikidata is ",((len(merged_df_1))/(len(df_wk))*100),"%")
# Out:
# the number of merged data from DBpedia and Wikidata is 1154 rows.
#
# The proportion of the number of merged data from DBpedia with Wikidata is  66.05609616485404 %
#
# proportion of the number of merged data from Wikidata with Wikidata is  2.8405454634962832 %

# %%
merged_df_1[:5]
# Out:
#                                      uri_wk                            viaf  \
# 0      http://www.wikidata.org/entity/Q9387  http://viaf.org/viaf/100180950
# 1    http://www.wikidata.org/entity/Q510386  http://viaf.org/viaf/100238197
# 2  http://www.wikidata.org/entity/Q15999850  http://viaf.org/viaf/100246974
# 3    http://www.wikidata.org/entity/Q157255  http://viaf.org/viaf/100258394
# 4  http://www.wikidata.org/entity/Q15990097  http://viaf.org/viaf/100274542
#
#                 name_wk date_wk  \
# 0             Max Weber    1864
# 1  José Hermano Saraiva    1919
# 2      Peter J. Hammond    1945
# 3         Merton Miller    1923
# 4         Michael Kaser    1926
#
#                                              uri_dbp              name_dbp  \
# 0              http://dbpedia.org/resource/Max_Weber
# 1   http://dbpedia.org/resource/José_Hermano_Saraiva  José Hermano Saraiva
# 2  http://dbpedia.org/resource/Peter_J._Hammond_(...         Peter Hammond
# 3          http://dbpedia.org/resource/Merton_Miller         Merton Miller
# 4          http://dbpedia.org/resource/Michael_Kaser         Michael Kaser
#
#   date_dbp
# 0     1864
# 1     1919
# 2     1945
# 3     1923
# 4     1926

# %%
merged_df = pd.merge( merged_df_1, df_bnf , on='viaf', how='inner', sort='viaf')

# %%
print("he number of merged data from DBpedia, Wikidata and BnF Data is",len(merged_df),"rows.")

print("The proportion of the number of merged data from DBpedia, Wikidata and BnF Data is ",(len(merged_df))/(len(df_bnf))*100,"%" )
# Out:
# he number of merged data from DBpedia, Wikidata and BnF Data is 51 rows.
# The proportion of the number of merged data from DBpedia, Wikidata and BnF Data is  0.5575598556903902 %

# %%
merged_df
# Out:
#                                      uri_wk                            viaf  \
# 0    http://www.wikidata.org/entity/Q437403  http://viaf.org/viaf/100966624
# 1    http://www.wikidata.org/entity/Q230814  http://viaf.org/viaf/107536763
# 2    http://www.wikidata.org/entity/Q518859  http://viaf.org/viaf/108188941
# 3    http://www.wikidata.org/entity/Q652154  http://viaf.org/viaf/108587991
# 4   http://www.wikidata.org/entity/Q1730876  http://viaf.org/viaf/108794549
# 5   http://www.wikidata.org/entity/Q5258787   http://viaf.org/viaf/19719687
# 6    http://www.wikidata.org/entity/Q942703  http://viaf.org/viaf/204968982
# 7   http://www.wikidata.org/entity/Q3619732   http://viaf.org/viaf/20961289
# 8     http://www.wikidata.org/entity/Q90243   http://viaf.org/viaf/22222311
# 9    http://www.wikidata.org/entity/Q216872   http://viaf.org/viaf/24716169
# 10   http://www.wikidata.org/entity/Q478746   http://viaf.org/viaf/31990071
# 11  http://www.wikidata.org/entity/Q3085838   http://viaf.org/viaf/32062931
# 12  http://www.wikidata.org/entity/Q3076206   http://viaf.org/viaf/32063701
# 13   http://www.wikidata.org/entity/Q360574   http://viaf.org/viaf/34517870
# 14    http://www.wikidata.org/entity/Q61922   http://viaf.org/viaf/36942970
# 15  http://www.wikidata.org/entity/Q2278847   http://viaf.org/viaf/37722283
# 16  http://www.wikidata.org/entity/Q2278847   http://viaf.org/viaf/37722283
# 17  http://www.wikidata.org/entity/Q2037919   http://viaf.org/viaf/39383997
# 18    http://www.wikidata.org/entity/Q62966   http://viaf.org/viaf/41930305
# 19    http://www.wikidata.org/entity/Q61956   http://viaf.org/viaf/44308789
# 20   http://www.wikidata.org/entity/Q231690   http://viaf.org/viaf/44331988
# 21   http://www.wikidata.org/entity/Q112222   http://viaf.org/viaf/44360349
# 22   http://www.wikidata.org/entity/Q734884   http://viaf.org/viaf/46458745
# 23    http://www.wikidata.org/entity/Q77956   http://viaf.org/viaf/46846424
# 24    http://www.wikidata.org/entity/Q77956   http://viaf.org/viaf/46846424
# 25    http://www.wikidata.org/entity/Q57386   http://viaf.org/viaf/49232367
# 26    http://www.wikidata.org/entity/Q89188    http://viaf.org/viaf/4985009
# 27   http://www.wikidata.org/entity/Q274429    http://viaf.org/viaf/4992487
# 28   http://www.wikidata.org/entity/Q274429    http://viaf.org/viaf/4992487
# 29   http://www.wikidata.org/entity/Q215961   http://viaf.org/viaf/50021033
# 30   http://www.wikidata.org/entity/Q155860   http://viaf.org/viaf/54947815
# 31   http://www.wikidata.org/entity/Q155860   http://viaf.org/viaf/54947815
# 32   http://www.wikidata.org/entity/Q828360    http://viaf.org/viaf/5733552
# 33    http://www.wikidata.org/entity/Q71208   http://viaf.org/viaf/59146281
# 34  http://www.wikidata.org/entity/Q1381744   http://viaf.org/viaf/59201855
# 35    http://www.wikidata.org/entity/Q67005   http://viaf.org/viaf/60596223
# 36   http://www.wikidata.org/entity/Q359754   http://viaf.org/viaf/64179253
# 37   http://www.wikidata.org/entity/Q380297   http://viaf.org/viaf/68928573
# 38    http://www.wikidata.org/entity/Q77148   http://viaf.org/viaf/68946216
# 39    http://www.wikidata.org/entity/Q61613   http://viaf.org/viaf/68949059
# 40   http://www.wikidata.org/entity/Q334294   http://viaf.org/viaf/68982798
# 41  http://www.wikidata.org/entity/Q4893263   http://viaf.org/viaf/69263532
# 42    http://www.wikidata.org/entity/Q64856   http://viaf.org/viaf/69722536
# 43  http://www.wikidata.org/entity/Q7836141   http://viaf.org/viaf/73921034
# 44    http://www.wikidata.org/entity/Q25351    http://viaf.org/viaf/7402506
# 45    http://www.wikidata.org/entity/Q76892   http://viaf.org/viaf/76377829
# 46  http://www.wikidata.org/entity/Q2512563    http://viaf.org/viaf/8183826
# 47    http://www.wikidata.org/entity/Q62605   http://viaf.org/viaf/84101514
# 48  http://www.wikidata.org/entity/Q3972694   http://viaf.org/viaf/88145923
# 49  http://www.wikidata.org/entity/Q5202134    http://viaf.org/viaf/9887798
# 50   http://www.wikidata.org/entity/Q297793    http://viaf.org/viaf/9914155
#
#                             name_wk date_wk  \
# 0              John Peters Humphrey    1905
# 1                     Louis Renault    1843
# 2                    Gordon Tullock    1922
# 3                  Alexis Jacquemin    1938
# 4                      Karl Engisch    1899
# 5                    Tobias Barreto    1839
# 6                          Alf Ross    1899
# 7          Antonio Mario La Pergola    1931
# 8                        Otto Lenel    1849
# 9                      Tobias Asser    1838
# 10      Auguste Champetier de Ribes    1882
# 11                 François Simiand    1873
# 12               John Henry Wigmore    1863
# 13            Oliver Wendell Holmes    1841
# 14                  Gustav Radbruch    1878
# 15                 Contardo Ferrini    1859
# 16                 Contardo Ferrini    1859
# 17                  Salvatore Satta    1902
# 18              Bernhard Windscheid    1817
# 19                 Lorenz von Stein    1815
# 20                   B. R. Ambedkar    1891
# 21                       Hans Gross    1847
# 22                   Gyula Wlassics    1852
# 23               L. F. L. Oppenheim    1858
# 24               L. F. L. Oppenheim    1858
# 25                   Kurt Tucholsky    1890
# 26               Slobodan Jovanović    1869
# 27        Édouard René de Laboulaye    1811
# 28        Édouard René de Laboulaye    1811
# 29  Franz Hermann Schulze-Delitzsch    1808
# 30                 Andrey Vyshinsky    1883
# 31                 Andrey Vyshinsky    1883
# 32                    Eggert Reeder    1894
# 33                Heinrich Dernburg    1829
# 34       Pasquale Stanislao Mancini    1817
# 35                      Hans Litten    1903
# 36         Konstantin Pobedonostsev    1827
# 37                 Maurice Duverger    1917
# 38                     Carl Schmitt    1888
# 39    Helmuth James Graf von Moltke    1907
# 40                  Anatoly Sobchak    1937
# 41              Joan Sardà i Dexeus    1910
# 42                Eduard von Simson    1810
# 43                    Travers Twiss    1809
# 44                  Theodor Mommsen    1817
# 45       Friedrich Carl von Savigny    1779
# 46                    Edmond Picard    1836
# 47               Rudolf von Jhering    1818
# 48                   Stefano Rodotà    1933
# 49             Czesław Znamierowski    1888
# 50        Vittorio Emanuele Orlando    1860
#
#                                               uri_dbp  \
# 0    http://dbpedia.org/resource/John_Peters_Humphrey
# 1   http://dbpedia.org/resource/Louis_Renault_(jur...
# 2          http://dbpedia.org/resource/Gordon_Tullock
# 3        http://dbpedia.org/resource/Alexis_Jacquemin
# 4            http://dbpedia.org/resource/Karl_Engisch
# 5          http://dbpedia.org/resource/Tobias_Barreto
# 6                http://dbpedia.org/resource/Alf_Ross
# 7   http://dbpedia.org/resource/Antonio_Mario_La_P...
# 8              http://dbpedia.org/resource/Otto_Lenel
# 9            http://dbpedia.org/resource/Tobias_Asser
# 10  http://dbpedia.org/resource/Auguste_Champetier...
# 11       http://dbpedia.org/resource/François_Simiand
# 12     http://dbpedia.org/resource/John_Henry_Wigmore
# 13  http://dbpedia.org/resource/Oliver_Wendell_Hol...
# 14        http://dbpedia.org/resource/Gustav_Radbruch
# 15       http://dbpedia.org/resource/Contardo_Ferrini
# 16       http://dbpedia.org/resource/Contardo_Ferrini
# 17        http://dbpedia.org/resource/Salvatore_Satta
# 18    http://dbpedia.org/resource/Bernhard_Windscheid
# 19       http://dbpedia.org/resource/Lorenz_von_Stein
# 20         http://dbpedia.org/resource/B._R._Ambedkar
# 21             http://dbpedia.org/resource/Hans_Gross
# 22         http://dbpedia.org/resource/Gyula_Wlassics
# 23     http://dbpedia.org/resource/L._F._L._Oppenheim
# 24     http://dbpedia.org/resource/L._F._L._Oppenheim
# 25         http://dbpedia.org/resource/Kurt_Tucholsky
# 26     http://dbpedia.org/resource/Slobodan_Jovanović
# 27  http://dbpedia.org/resource/Édouard_René_de_La...
# 28  http://dbpedia.org/resource/Édouard_René_de_La...
# 29  http://dbpedia.org/resource/Franz_Hermann_Schu...
# 30       http://dbpedia.org/resource/Andrey_Vyshinsky
# 31       http://dbpedia.org/resource/Andrey_Vyshinsky
# 32          http://dbpedia.org/resource/Eggert_Reeder
# 33      http://dbpedia.org/resource/Heinrich_Dernburg
# 34  http://dbpedia.org/resource/Pasquale_Stanislao...
# 35            http://dbpedia.org/resource/Hans_Litten
# 36  http://dbpedia.org/resource/Konstantin_Pobedon...
# 37       http://dbpedia.org/resource/Maurice_Duverger
# 38           http://dbpedia.org/resource/Carl_Schmitt
# 39  http://dbpedia.org/resource/Helmuth_James_von_...
# 40        http://dbpedia.org/resource/Anatoly_Sobchak
# 41    http://dbpedia.org/resource/Joan_Sardà_i_Dexeus
# 42      http://dbpedia.org/resource/Eduard_von_Simson
# 43          http://dbpedia.org/resource/Travers_Twiss
# 44        http://dbpedia.org/resource/Theodor_Mommsen
# 45  http://dbpedia.org/resource/Friedrich_Carl_von...
# 46          http://dbpedia.org/resource/Edmond_Picard
# 47     http://dbpedia.org/resource/Rudolf_von_Jhering
# 48         http://dbpedia.org/resource/Stefano_Rodotà
# 49   http://dbpedia.org/resource/Czesław_Znamierowski
# 50  http://dbpedia.org/resource/Vittorio_Emanuele_...
#
#                             name_dbp date_dbp  \
# 0               John Peters Humphrey     1905
# 1                      Louis Renault     1843
# 2                     Gordon Tullock     1922
# 3                   Alexis Jacquemin     1938
# 4                       Karl Engisch     1899
# 5                     Tobias Barreto     1839
# 6                           Alf Ross     1899
# 7           Antonio Mario La Pergola     1931
# 8                          Otto Lene     1849
# 9                       Tobias Asser     1838
# 10       Auguste Champetier de Ribes     1882
# 11                  François Simiand     1873
# 12                John Henry Wigmore     1863
# 13                                       1841
# 14                   Gustav Radbruch     1878
# 15          Blessed Contardo Ferrini     1859
# 16                          T.O.S.F.     1859
# 17                   Salvatore Satta     1902
# 18               Bernhard Windscheid     1817
# 19                  Lorenz von Stein     1815
# 20            Bhimrao Ramji Ambedkar     1891
# 21                        Hans Gross     1847
# 22                    Gyula Wlassics     1852
# 23  Lassa Francis Lawrence Oppenheim     1858
# 24                   Lassa Oppenheim     1858
# 25                    Kurt Tucholsky     1890
# 26                Slobodan Jovanović     1869
# 27                 Édouard Laboulaye     1811
# 28         Édouard René de Laboulaye     1811
# 29         Hermann Schulze-Delitzsch     1808
# 30              (Андре́й Выши́нский)     1883
# 31                  Andrey Vyshinsky     1883
# 32                     Eggert Reeder     1894
# 33                 Heinrich Dernburg     1829
# 34                  Pasquale Mancini     1817
# 35                       Hans Litten     1903
# 36          Konstantin Pobedonostsev     1827
# 37                  Maurice Duverger     1917
# 38                      Carl Schmitt     1888
# 39     Helmuth James Graf von Moltke     1907
# 40                                       1937
# 41               Joan Sardà i Dexeus     1910
# 42                 Eduard von Simson     1810
# 43                     Travers Twiss     1809
# 44                   Theodor Mommsen     1817
# 45        Friedrich Carl von Savigny     1779
# 46                     Edmond Picard     1836
# 47                Rudolf von Jhering     1818
# 48                    Stefano Rodotà     1933
# 49              Czesław Znamierowski     1888
# 50         Vittorio Emanuele Orlando     1860
#
#                                             uri_bnf  \
# 0   http://data.bnf.fr/ark:/12148/cb122145877#about
# 1   http://data.bnf.fr/ark:/12148/cb12327654n#about
# 2   http://data.bnf.fr/ark:/12148/cb11927239j#about
# 3   http://data.bnf.fr/ark:/12148/cb119084288#about
# 4   http://data.bnf.fr/ark:/12148/cb12299375j#about
# 5   http://data.bnf.fr/ark:/12148/cb121737508#about
# 6   http://data.bnf.fr/ark:/12148/cb129377723#about
# 7   http://data.bnf.fr/ark:/12148/cb12343730c#about
# 8   http://data.bnf.fr/ark:/12148/cb12380018p#about
# 9   http://data.bnf.fr/ark:/12148/cb12551967b#about
# 10  http://data.bnf.fr/ark:/12148/cb11298933w#about
# 11  http://data.bnf.fr/ark:/12148/cb12301152q#about
# 12  http://data.bnf.fr/ark:/12148/cb12305232b#about
# 13  http://data.bnf.fr/ark:/12148/cb12277774d#about
# 14  http://data.bnf.fr/ark:/12148/cb120792656#about
# 15  http://data.bnf.fr/ark:/12148/cb10434037s#about
# 16  http://data.bnf.fr/ark:/12148/cb10434037s#about
# 17  http://data.bnf.fr/ark:/12148/cb11923750g#about
# 18  http://data.bnf.fr/ark:/12148/cb12425142z#about
# 19  http://data.bnf.fr/ark:/12148/cb12001622n#about
# 20  http://data.bnf.fr/ark:/12148/cb12126992f#about
# 21  http://data.bnf.fr/ark:/12148/cb12283356m#about
# 22  http://data.bnf.fr/ark:/12148/cb10562303m#about
# 23  http://data.bnf.fr/ark:/12148/cb12403156r#about
# 24  http://data.bnf.fr/ark:/12148/cb12403156r#about
# 25  http://data.bnf.fr/ark:/12148/cb119272204#about
# 26  http://data.bnf.fr/ark:/12148/cb122351733#about
# 27  http://data.bnf.fr/ark:/12148/cb12280806q#about
# 28  http://data.bnf.fr/ark:/12148/cb12280806q#about
# 29  http://data.bnf.fr/ark:/12148/cb12088660j#about
# 30  http://data.bnf.fr/ark:/12148/cb12206467m#about
# 31  http://data.bnf.fr/ark:/12148/cb12206467m#about
# 32  http://data.bnf.fr/ark:/12148/cb16593487f#about
# 33  http://data.bnf.fr/ark:/12148/cb12285087j#about
# 34  http://data.bnf.fr/ark:/12148/cb12568904b#about
# 35  http://data.bnf.fr/ark:/12148/cb16153188f#about
# 36  http://data.bnf.fr/ark:/12148/cb13607271c#about
# 37  http://data.bnf.fr/ark:/12148/cb11901480p#about
# 38  http://data.bnf.fr/ark:/12148/cb12036941k#about
# 39  http://data.bnf.fr/ark:/12148/cb12054658d#about
# 40  http://data.bnf.fr/ark:/12148/cb12236402n#about
# 41  http://data.bnf.fr/ark:/12148/cb158098327#about
# 42  http://data.bnf.fr/ark:/12148/cb14446156k#about
# 43  http://data.bnf.fr/ark:/12148/cb12314495r#about
# 44  http://data.bnf.fr/ark:/12148/cb12017932f#about
# 45  http://data.bnf.fr/ark:/12148/cb12278447x#about
# 46  http://data.bnf.fr/ark:/12148/cb12120233j#about
# 47  http://data.bnf.fr/ark:/12148/cb12182958j#about
# 48  http://data.bnf.fr/ark:/12148/cb12032003k#about
# 49  http://data.bnf.fr/ark:/12148/cb12165234x#about
# 50  http://data.bnf.fr/ark:/12148/cb123010784#about
#
#                             name_bnf sName year_bnf  \
# 0                      John Humphrey           1905
# 1                      Louis Renault           1843
# 2                     Gordon Tullock           1922
# 3                   Alexis Jacquemin           1938
# 4                       Karl Engisch           1899
# 5                     Tobias Barreto           1839
# 6                           Alf Ross           1899
# 7                 Antonio La Pergola           1931
# 8                         Otto Lenel           1849
# 9         Tobias-Michael-Carel Asser           1838
# 10       Auguste Champetier de Ribes           1882
# 11                  François Simiand           1873
# 12                John Henry Wigmore           1863
# 13             Oliver Wendell Holmes           1841
# 14                   Gustav Radbruch           1878
# 15                  Contardo Ferrini           1859
# 16                  Contardo Ferrini           1859
# 17                   Salvatore Satta           1902
# 18               Bernhard Windscheid           1817
# 19                  Lorenz von Stein           1815
# 20            Bhimrao Ramji Ambedkar           1891
# 21                        Hans Gross           1847
# 22                    Gyula Wlassics           1852
# 23                   Lassa Oppenheim           1858
# 24                   Lassa Oppenheim           1858
# 25                    Kurt Tucholsky           1890
# 26                Slobodan Jovanović           1869
# 27                 Édouard Laboulaye           1811
# 28                 Édouard Laboulaye           1811
# 29         Hermann Schulze-Delitzsch           1808
# 30       Andrej Ânuarʹevič Vyšinskij           1883
# 31       Andrej Ânuarʹevič Vyšinskij           1883
# 32                     Eggert Reeder           1894
# 33                 Heinrich Dernburg           1829
# 34        Pasquale Stanislao Mancini           1817
# 35                       Hans Litten           1903
# 36  Konstantin Petrovič Pobedonoscev           1827
# 37                  Maurice Duverger           1917
# 38                      Carl Schmitt           1888
# 39          Helmuth James von Moltke           1907
# 40     Anatolij Aleksandrovič Sobčak           1937
# 41                 Juan Sardá Dexeus           1910
# 42                 Eduard von Simson           1810
# 43                     Travers Twiss           1809
# 44                   Theodor Mommsen           1817
# 45        Friedrich Carl von Savigny           1779
# 46                     Edmond Picard           1836
# 47                Rudolf von Jhering           1818
# 48                    Stefano Rodotà           1933
# 49              Czesław Znamierowski           1888
# 50         Vittorio Emanuele Orlando           1860
#
#                                               bio_bnf
# 0   Juriste. - A été professeur de droit internati...
# 1   Juriste. - Professeur de droit international à...
# 2   Docteur en droit (University of Chicago, Ill.,...
# 3   Juriste et économiste. - Professeur à l'Univer...
# 4   Juriste. - Spécialiste de philosophie du droit...
# 5             Philosophe, juriste. - Poète, essayiste
# 6   Juriste, spécialisé en philosophie du droit, d...
# 7   Juriste. - Président de la Cour constitutionnelle
# 8   Juriste. - Spécialiste de droit romain. - Memb...
# 9   Juriste. - Fut l'un des fondateurs de l'Instit...
# 10  Homme politique. - Avocat près la cour d'appel...
# 11  Philosophe. - Agrégé de philosophie. - Docteur...
# 12  Juriste. - Spécialiste de droit de la preuve "...
# 13  Juriste et philosophe. - Spécialiste de l'hist...
# 14  Homme politique. - Philosophe du droit. - Juriste
# 15  Franciscain. - Historien du droit. - Professeu...
# 16  Franciscain. - Historien du droit. - Professeu...
# 17  Juriste. - Romancier. - Fut professeur de droi...
# 18                                            Juriste
# 19  Juriste et économiste. - Professeur à Kiel, Al...
# 20  Homme politique d'origine harijan mahar. - Étu...
# 21  Juriste. - Professeur de droit pénal à l'Unive...
# 22  Juriste. - Académicien. - Président de la Cham...
# 23  Juriste. - Spécialiste de droit international....
# 24  Juriste. - Spécialiste de droit international....
# 25  Docteur en droit. - Journaliste, essayiste, éc...
# 26  Historien et juriste. - Fut président du gouve...
# 27  Avocat. - Homme politique. - Fondateur de la "...
# 28  Avocat. - Homme politique. - Fondateur de la "...
# 29  Juriste, homme politique et économiste alleman...
# 30                         Homme politique et juriste
# 31                         Homme politique et juriste
# 32  Juriste. - Président du gouvernement de distri...
# 33  Juriste. - Fut professeur à Heidelberg, Berlin...
# 34                     Juriste. - Professeur de droit
# 35                         Avocat, militant anti-nazi
# 36                            Homme d'État et juriste
# 37  Juriste, politologue et professeur de droit. -...
# 38  Juriste et politologue, spécialiste de droit p...
# 39  Comte. - Juriste. - Militant actif de la résis...
# 40  Professeur de droit. - Maire de Saint-Pétersbo...
# 41                     Docteur en droit. - Économiste
# 42  Juriste. - Parlementaire. - Professeur d'unive...
# 43      Juriste. - Spécialiste de droit international
# 44  Historien, spécialiste de l'Antiquité romaine....
# 45  Juriste. - Spécialiste de droit romain. - Mini...
# 46  Avocat à la Cour de Cassation et sénateur. - H...
# 47  Juriste, spécialiste de droit romain. - Fut pr...
# 48  Juriste. - Parlementaire. - Professeur de droi...
# 49                  Juriste, philosophe et sociologue
# 50  Juriste, spécialiste de droit public. - Présid...

# %%
# Append DBpedia and BnF Data to the merged Dataframe who don't have viaf.org values in common.

# To achieve this, I am served on these pages: 
# https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html (en)
# https://jakevdp.github.io/PythonDataScienceHandbook/03.06-concat-and-append.html (en)
# http://www.python-simple.com/python-pandas/concatenations-joins-dataframe.php (fr)

result = merged_df.append([df_dbp, df_bnf, df_wk], sort=False)
print(len(result))
result[:150]
# Out:
# 51571
#                                      uri_wk                            viaf  \
# 0    http://www.wikidata.org/entity/Q437403  http://viaf.org/viaf/100966624
# 1    http://www.wikidata.org/entity/Q230814  http://viaf.org/viaf/107536763
# 2    http://www.wikidata.org/entity/Q518859  http://viaf.org/viaf/108188941
# 3    http://www.wikidata.org/entity/Q652154  http://viaf.org/viaf/108587991
# 4   http://www.wikidata.org/entity/Q1730876  http://viaf.org/viaf/108794549
# ..                                      ...                             ...
# 94                                      NaN   http://viaf.org/viaf/88507182
# 95                                      NaN   http://viaf.org/viaf/88414700
# 96                                      NaN   http://viaf.org/viaf/88345236
# 97                                      NaN   http://viaf.org/viaf/88341444
# 98                                      NaN   http://viaf.org/viaf/88145923
#
#                  name_wk date_wk  \
# 0   John Peters Humphrey    1905
# 1          Louis Renault    1843
# 2         Gordon Tullock    1922
# 3       Alexis Jacquemin    1938
# 4           Karl Engisch    1899
# ..                   ...     ...
# 94                   NaN     NaN
# 95                   NaN     NaN
# 96                   NaN     NaN
# 97                   NaN     NaN
# 98                   NaN     NaN
#
#                                               uri_dbp              name_dbp  \
# 0    http://dbpedia.org/resource/John_Peters_Humphrey  John Peters Humphrey
# 1   http://dbpedia.org/resource/Louis_Renault_(jur...         Louis Renault
# 2          http://dbpedia.org/resource/Gordon_Tullock        Gordon Tullock
# 3        http://dbpedia.org/resource/Alexis_Jacquemin      Alexis Jacquemin
# 4            http://dbpedia.org/resource/Karl_Engisch          Karl Engisch
# ..                                                ...                   ...
# 94         http://dbpedia.org/resource/Emery_B._Denny        Emery B. Denny
# 95           http://dbpedia.org/resource/Edith_Kuiper          Edith Kuiper
# 96              http://dbpedia.org/resource/Ali_Gomaa             Ali Gomaa
# 97  http://dbpedia.org/resource/David_Gordon_(econ...          David Gordon
# 98         http://dbpedia.org/resource/Stefano_Rodotà        Stefano Rodotà
#
#    date_dbp                                          uri_bnf  \
# 0      1905  http://data.bnf.fr/ark:/12148/cb122145877#about
# 1      1843  http://data.bnf.fr/ark:/12148/cb12327654n#about
# 2      1922  http://data.bnf.fr/ark:/12148/cb11927239j#about
# 3      1938  http://data.bnf.fr/ark:/12148/cb119084288#about
# 4      1899  http://data.bnf.fr/ark:/12148/cb12299375j#about
# ..      ...                                              ...
# 94     1892                                              NaN
# 95     1960                                              NaN
# 96     1952                                              NaN
# 97     1944                                              NaN
# 98     1933                                              NaN
#
#             name_bnf sName year_bnf  \
# 0      John Humphrey           1905
# 1      Louis Renault           1843
# 2     Gordon Tullock           1922
# 3   Alexis Jacquemin           1938
# 4       Karl Engisch           1899
# ..               ...   ...      ...
# 94               NaN   NaN      NaN
# 95               NaN   NaN      NaN
# 96               NaN   NaN      NaN
# 97               NaN   NaN      NaN
# 98               NaN   NaN      NaN
#
#                                               bio_bnf
# 0   Juriste. - A été professeur de droit internati...
# 1   Juriste. - Professeur de droit international à...
# 2   Docteur en droit (University of Chicago, Ill.,...
# 3   Juriste et économiste. - Professeur à l'Univer...
# 4   Juriste. - Spécialiste de philosophie du droit...
# ..                                                ...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
#
# [150 rows x 12 columns]

# %%
# Replace each null value with the value from the other database.
# Create a column with the fresh values.
# I used this page: https://kanoki.org/2019/08/17/pandas-coalesce-replace-value-from-another-column/ 
# particuliarly, the "Using Numpy" section

result_test=result

# Replace null value name

## BnF Data
result_test['name'] = np.where(result['name_bnf'].isnull(),result['name_dbp'],result['name_bnf'])
result_test['name'] = np.where(result['name_bnf'].isnull(),result['name_wk'],result['name_bnf'])
## DBpedia
result_test['name'] = np.where(result['name_dbp'].isnull(),result['name_bnf'],result['name_dbp'])
result_test['name'] = np.where(result['name_dbp'].isnull(),result['name_wk'],result['name_dbp'])
## Wikidata
result_test['name'] = np.where(result['name_wk'].isnull(),result['name_bnf'],result['name_wk'])
result_test['name'] = np.where(result['name_wk'].isnull(),result['name_dbp'],result['name_wk'])

# Replace null value year

## BnF Data
result_test['year'] = np.where(result['year_bnf'].isnull(),result['date_dbp'],result['year_bnf'])
result_test['year'] = np.where(result['year_bnf'].isnull(),result['date_wk'],result['year_bnf'])
## DBpedia
result_test['year'] = np.where(result['date_dbp'].isnull(),result['year_bnf'],result['date_dbp'])
result_test['year'] = np.where(result['date_dbp'].isnull(),result['date_wk'],result['date_dbp'])
## Wikidata
result_test['year'] = np.where(result['date_wk'].isnull(),result['year_bnf'],result['date_wk'])
result_test['year'] = np.where(result['date_wk'].isnull(),result['name_dbp'],result['date_wk'])

result_test=result_test.loc[:,['viaf','name','year','uri_dbp','uri_bnf', 'uri_wk']]
# Out:
#   File "<ipython-input-90-2816041e2c8b>", line 33
#     print(result_test["name"] == "NaN" = True)
#          ^
# SyntaxError: keyword can't be an expression

# %%
NaN_index = (result_test["name"] == "NaN")

NaN_result = result_test[NaN_index] 
NaN_result['name'].value_counts()
# Out:
# Series([], Name: name, dtype: int64)

# %%
# Extract only rows without VIAF uri from DBpeida
df_dbp_test = pd.DataFrame(result_dbpedia, columns=['uri_dbp', 'viaf', 'name_dbp', 'date_dbp'])

df_dbp_test_mask=df_dbp_test['viaf']==''
filtered_df_dbp_test = df_dbp_test[df_dbp_test_mask]
filtered_df_dbp_test[:10]
# Out:
#                                               uri_dbp viaf  \
# 1747  http://dbpedia.org/resource/Luc-Normand_Tellier
# 1748          http://dbpedia.org/resource/Madhu_Verma
# 1749         http://dbpedia.org/resource/Magda_Kandil
# 1750   http://dbpedia.org/resource/Magnus_Johannesson
# 1751     http://dbpedia.org/resource/Mahendra_P._Lama
# 1752         http://dbpedia.org/resource/Mainul_Islam
# 1753      http://dbpedia.org/resource/Urs_Meisterhans
# 1754      http://dbpedia.org/resource/Rosalind_Blauer
# 1755          http://dbpedia.org/resource/Makoto_Yano
# 1756     http://dbpedia.org/resource/Krzysztof_Zamasz
#
#                   name_dbp date_dbp
# 1747   Luc-Normand Tellier     1944
# 1748           Madhu Verma     1961
# 1749  Magda ElSayed Kandil     1958
# 1750    Magnus Johannesson     1964
# 1751      Mahendra P. Lama     1961
# 1752          Mainul Islam     1950
# 1753       Urs Meisterhans     1960
# 1754       Rosalind Blauer     1943
# 1755           Makoto Yano     1952
# 1756      Krzysztof Zamasz     1974

# %%
# Extract only rows without VIAF uri from BnF Data
df_bnf_test = pd.DataFrame(result_bnf, columns=['uri_bnf', 'viaf', 'name_bnf', 'sName','year_bnf','bio_bnf'])

df_bnf_test_mask=df_bnf_test['viaf']==''
filtered_df_bnf_test = df_bnf_test[df_bnf_test_mask]
len(filtered_df_bnf_test)
# Out:
# 2054

# %%
##### Extract only rows without VIAF uri from BnF Data
df_wk_test = pd.DataFrame(result_wikidata, columns=['uri_wk', 'viaf', 'name_wk','date_wk'])

df_wk_test_mask=df_wk_test['viaf']==''
filtered_df_wk_test = df_wk_test[df_wk_test_mask]
len(filtered_df_wk_test)
# Out:
# 13081

# %%
# merge the both dateframes 
filtered_dbp_bnf_test= filtered_df_dbp_test.append(filtered_df_bnf_test, sort=True)
len(filtered_dbp_bnf_test)
filtered_dbp_bnf_wk_test=filtered_dbp_bnf_test.append(filtered_df_wk_test, sort=True)
print(len(filtered_dbp_bnf_wk_test))
filtered_dbp_bnf_wk_test[:10]
# Out:
# 21933
#      bio_bnf date_dbp date_wk name_bnf              name_dbp name_wk sName  \
# 1747     NaN     1944     NaN      NaN   Luc-Normand Tellier     NaN   NaN
# 1748     NaN     1961     NaN      NaN           Madhu Verma     NaN   NaN
# 1749     NaN     1958     NaN      NaN  Magda ElSayed Kandil     NaN   NaN
# 1750     NaN     1964     NaN      NaN    Magnus Johannesson     NaN   NaN
# 1751     NaN     1961     NaN      NaN      Mahendra P. Lama     NaN   NaN
# 1752     NaN     1950     NaN      NaN          Mainul Islam     NaN   NaN
# 1753     NaN     1960     NaN      NaN       Urs Meisterhans     NaN   NaN
# 1754     NaN     1943     NaN      NaN       Rosalind Blauer     NaN   NaN
# 1755     NaN     1952     NaN      NaN           Makoto Yano     NaN   NaN
# 1756     NaN     1974     NaN      NaN      Krzysztof Zamasz     NaN   NaN
#
#      uri_bnf                                          uri_dbp uri_wk viaf  \
# 1747     NaN  http://dbpedia.org/resource/Luc-Normand_Tellier    NaN
# 1748     NaN          http://dbpedia.org/resource/Madhu_Verma    NaN
# 1749     NaN         http://dbpedia.org/resource/Magda_Kandil    NaN
# 1750     NaN   http://dbpedia.org/resource/Magnus_Johannesson    NaN
# 1751     NaN     http://dbpedia.org/resource/Mahendra_P._Lama    NaN
# 1752     NaN         http://dbpedia.org/resource/Mainul_Islam    NaN
# 1753     NaN      http://dbpedia.org/resource/Urs_Meisterhans    NaN
# 1754     NaN      http://dbpedia.org/resource/Rosalind_Blauer    NaN
# 1755     NaN          http://dbpedia.org/resource/Makoto_Yano    NaN
# 1756     NaN     http://dbpedia.org/resource/Krzysztof_Zamasz    NaN
#
#      year_bnf
# 1747      NaN
# 1748      NaN
# 1749      NaN
# 1750      NaN
# 1751      NaN
# 1752      NaN
# 1753      NaN
# 1754      NaN
# 1755      NaN
# 1756      NaN

# %%
# Replace each null value with the value from the other database.
# Create a column with the fresh values.
# I used this page: https://kanoki.org/2019/08/17/pandas-coalesce-replace-value-from-another-column/ 
# particuliarly, the "Using Numpy" section

result_f_test=filtered_dbp_bnf_wk_test

# Replace null value name

## BnF Data
result_f_test['name'] = np.where(filtered_dbp_bnf_wk_test['name_bnf'].isnull(),filtered_dbp_bnf_wk_test['name_dbp'],filtered_dbp_bnf_wk_test['name_bnf'])
result_f_test['name'] = np.where(filtered_dbp_bnf_wk_test['name_bnf'].isnull(),filtered_dbp_bnf_wk_test['name_wk'],filtered_dbp_bnf_wk_test['name_bnf'])
## DBpedia
result_f_test['name'] = np.where(filtered_dbp_bnf_wk_test['name_dbp'].isnull(),filtered_dbp_bnf_wk_test['name_bnf'],filtered_dbp_bnf_wk_test['name_dbp'])
result_f_test['name'] = np.where(filtered_dbp_bnf_wk_test['name_dbp'].isnull(),filtered_dbp_bnf_wk_test['name_wk'],filtered_dbp_bnf_wk_test['name_dbp'])
## Wikidata
result_f_test['name'] = np.where(filtered_dbp_bnf_wk_test['name_wk'].isnull(),filtered_dbp_bnf_wk_test['name_bnf'],filtered_dbp_bnf_wk_test['name_wk'])
result_f_test['name'] = np.where(filtered_dbp_bnf_wk_test['name_wk'].isnull(),filtered_dbp_bnf_wk_test['name_dbp'],filtered_dbp_bnf_wk_test['name_wk'])

# Replace null value year

## BnF Data
result_f_test['year'] = np.where(filtered_dbp_bnf_wk_test['year_bnf'].isnull(),filtered_dbp_bnf_wk_test['date_dbp'],filtered_dbp_bnf_wk_test['year_bnf'])
result_f_test['year'] = np.where(filtered_dbp_bnf_wk_test['year_bnf'].isnull(),filtered_dbp_bnf_wk_test['date_wk'],filtered_dbp_bnf_wk_test['year_bnf'])
## DBpedia
result_f_test['year'] = np.where(filtered_dbp_bnf_wk_test['date_dbp'].isnull(),filtered_dbp_bnf_wk_test['year_bnf'],filtered_dbp_bnf_wk_test['date_dbp'])
result_f_test['year'] = np.where(filtered_dbp_bnf_wk_test['date_dbp'].isnull(),filtered_dbp_bnf_wk_test['date_wk'],filtered_dbp_bnf_wk_test['date_dbp'])
## Wikidata
result_f_test['year'] = np.where(filtered_dbp_bnf_wk_test['date_wk'].isnull(),filtered_dbp_bnf_wk_test['year_bnf'],filtered_dbp_bnf_wk_test['date_wk'])
result_f_test['year'] = np.where(filtered_dbp_bnf_wk_test['date_wk'].isnull(),filtered_dbp_bnf_wk_test['name_dbp'],filtered_dbp_bnf_wk_test['date_wk'])


result_f_test=result_f_test.loc[:,['name','year','uri_dbp','uri_bnf', "uri_wk"]]
sort_rft=result_f_test.sort_values(by='name', ascending=False)
sort_rft
# Out:
#                     name               year  \
# 2961                 陳炯明                陳炯明
# 4218                 安井稔                安井稔
# 4057        ლევან ჭოლაძე       ლევან ჭოლაძე
# 2266      วิษณุ เครืองาม     วิษณุ เครืองาม
# 7024   พรเพชร วิชิตชลชัย  พรเพชร วิชิตชลชัย
# ...                  ...                ...
# 11196                NaN                NaN
# 11197                NaN                NaN
# 11198                NaN                NaN
# 11199                NaN                NaN
# 11200                NaN                NaN
#
#                                                  uri_dbp  \
# 2961          http://dbpedia.org/resource/Chen_Jiongming
# 4218            http://dbpedia.org/resource/Minoru_Yasui
# 4057          http://dbpedia.org/resource/Levan_Choladze
# 2266       http://dbpedia.org/resource/Wissanu_Krea-ngam
# 7024   http://dbpedia.org/resource/Pornpetch_Wichitch...
# ...                                                  ...
# 11196                                                NaN
# 11197                                                NaN
# 11198                                                NaN
# 11199                                                NaN
# 11200                                                NaN
#
#                                                uri_bnf uri_wk
# 2961                                               NaN    NaN
# 4218                                               NaN    NaN
# 4057                                               NaN    NaN
# 2266                                               NaN    NaN
# 7024                                               NaN    NaN
# ...                                                ...    ...
# 11196  http://data.bnf.fr/ark:/12148/cb11475627b#about    NaN
# 11197  http://data.bnf.fr/ark:/12148/cb10562770v#about    NaN
# 11198  http://data.bnf.fr/ark:/12148/cb17701366b#about    NaN
# 11199  http://data.bnf.fr/ark:/12148/cb17877820g#about    NaN
# 11200  http://data.bnf.fr/ark:/12148/cb17877063j#about    NaN
#
# [21933 rows x 5 columns]

# %%
length= len(sort_rft)
sort_rft.loc[1400]=[sort_rft["name"][440],
                  sort_rft["year"][440],
                  sort_rft["uri_dbp"][440],
                  sort_rft["uri_bnf"][440]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-270-f7d390810222> in <module>
#       1 length= len(sort_rft)
# ----> 2 sort_rft.loc[1400]=[sort_rft["name"][440],
#       3                   sort_rft["year"][440],
#       4                   sort_rft["uri_dbp"][440],
#       5                   sort_rft["uri_bnf"][440]]
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4721         k = self._convert_scalar_indexer(k, kind="getitem")
#    4722         try:
# -> 4723             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4724         except KeyError as e1:
#    4725             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 440

# %%
# Test to find similarities between the names BnF Data and DBpedia with collocation 


from nltk.corpus import stopwords
stopset = stopwords.words('english')
stopset = stopwords.words('french')
stopset = stopwords.words('russian')

result_f_test['tokenized_sents'] = result_f_test.apply(lambda row: nltk.word_tokenize(row['name']), axis=1)

bcf = TrigramCollocationFinder.from_documents(result_f_test['tokenized_sents'])
filter_stops = lambda w: w in stopset
bcf.apply_word_filter(filter_stops)
f= bcf.nbest(TrigramAssocMeasures., 50)
print(f)
# Out:
# [('Farkas', 'de', 'Boldogfa'), ('Faton', 'de', 'Favernay'), ('Hari', 'Singh', 'Gour'), ('Hassan', 'Raza', 'Ghadeeri'), ('Henríquez', 'y', 'Carvajal'), ('Jiménez', 'de', 'Aréchaga'), ("'", 'Antoine', 'de'), ("'", 'Argent', 'de'), ('(', 'Сергій', 'Льовочкін'), ('(', 'سعید', 'الزمان'), ('(', 'شیخ', 'انوار'), (',', 'Annie', 'Pommeray'), (',', 'Horace', 'Worth'), (',', 'Josué', 'Crémieux'), (',', 'Louis', ','), (',', 'Pierre', 'Gendre'), (',', 'Sr', '.'), ('A.', 'Boyd', 'Jr'), ('Abang', 'Iskandar', 'Abang'), ('Abbās', 'ibn', 'Ibrāhīm'), ('Adish', 'Chandra', 'Aggarwala'), ('Adnan', 'Iqbal', 'Chaudhry'), ('Adolphe', 'Leroy', 'de'), ('Adrien', 'de', 'Tourville'), ('Adrien', 'de', 'Valon'), ('Afonso', 'Pena', 'Júnior'), ('Agustín', 'Edwards', 'McClure'), ('Ahmed', 'Ali', 'M'), ('Alas', 'y', 'Argüelles'), ('Albert', 'Des', 'Méloizes'), ('Albert', 'E.', 'Ottinger'), ('Albert', 'Faton', 'de'), ('Albert', 'Geouffre', 'de'), ('Alberto', 'De', 'Mojana'), ('Alberto', 'Gómez', 'Jaramillo'), ('Alberto', 'López-Machuca', 'Tamayao'), ('Alejandro', 'Alvarado', 'Quirós'), ('Aleksej', 'Dmitrievič', 'Polenov'), ('Alexander', 'Karl', 'Neumeyer'), ('Alexandre', 'd', "'"), ('Alexandre', 'de', 'Bonneval'), ('Alexandre', 'de', 'Mazade'), ('Alexandre', 'de', 'Molènes'), ('Alexis', 'de', 'Reboul-Berville'), ('Alfred', 'Augustus', 'Akainyah'), ('Alfred', 'C.', 'Emery'), ('Alfred', 'Dubois', 'de'), ('Alfred', 'de', 'Clebsattel'), ('Ali', 'Baqar', 'Najafi'), ('Ali', 'Fuat', 'Başgil')]

# %%
# attempt to change the 'NaN' names from DBpedia to name from BnF and the same for the reverse 
# (cf.https://stackoverflow.com/questions/29177498/python-pandas-replace-nan-in-one-column-with-value-from-corresponding-row-of-sec)
import pandas as pd
import numpy as np

def fx(x):
    if np.isnan(x['date_dbp']):
        return x['year_bnf ']
    else:
        return x['date_dbp']
result_test=result.apply(lambda x : fx(x),axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-d6435fcff58e> in <module>
#       9     else:
#      10         return x['date_dbp']
# ---> 11 result_test=result.apply(lambda x : fx(x),axis=1)
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6904             kwds=kwds,
#    6905         )
# -> 6906         return op.get_result()
#    6907
#    6908     def applymap(self, func):
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-42-d6435fcff58e> in <lambda>(x)
#       9     else:
#      10         return x['date_dbp']
# ---> 11 result_test=result.apply(lambda x : fx(x),axis=1)
#
# <ipython-input-42-d6435fcff58e> in fx(x)
#       5
#       6 def fx(x):
# ----> 7     if np.isnan(x['date_dbp']):
#       8         return x['year_bnf ']
#       9     else:
#
# TypeError: ("ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''", 'occurred at index 0')

# %%
# Another method for trying to do it 
result.name_dbp.fillna(result.name_bnf, inplace=True)
del result['name_bnf']
result.columns = 'uri_dbp viaf name_dbp date_dbp uri_bnf sName year_bnf bio_bnf'.split()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b3754b2f35df> in <module>
#       2 result.name_dbp.fillna(result.name_bnf, inplace=True)
#       3 del result['name_bnf']
# ----> 4 result.columns = 'uri_dbp viaf name_dbp date_dbp uri_bnf sName year_bnf bio_bnf'.split()
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5191         try:
#    5192             object.__getattribute__(self, name)
# -> 5193             return object.__setattr__(self, name, value)
#    5194         except AttributeError:
#    5195             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     689
#     690     def _set_axis(self, axis, labels):
# --> 691         self._data.set_axis(axis, labels)
#     692         self._clear_item_cache()
#     693
#
# ~/anaconda3/envs/Github/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 10 elements, new values have 8 elements

# %%
df1 = pd.DataFrame({'user_id': ['id001', 'id002', 'id003', 'id004', 'id005', 'id006', 'id007'],
                    'first_name': ['Rivi', 'Wynnie', 'Kristos', 'Madalyn', 'Tobe', 'Regan', 'Kristin'],
                    'last_name': ['Valti', 'McMurty', 'Ivanets', 'Max', 'Riddich', 'Huyghe', 'Illis'],
                    'email': ['rvalti0@example.com', 'wmcmurty1@example.com', 'kivanets2@example.com',
                              'mmax3@example.com', 'triddich4@example.com', 'rhuyghe@example.com', 'killis4@example.com']
                    })

# %%
df2 = pd.DataFrame({'user_id': ['id001', 'id002', 'id003', 'id004', 'id005'],
                    'image_url': ['http://example.com/img/id001.png', 'http://example.com/img/id002.jpg',
                                  'http://example.com/img/id003.bmp', 'http://example.com/img/id004.jpg',
                                  'http://example.com/img/id005.png']
                    })

# %%
df3_merged = pd.merge(df1, df2)
df3_merged
# Out:
#   user_id first_name last_name                  email  \
# 0   id001       Rivi     Valti    rvalti0@example.com
# 1   id002     Wynnie   McMurty  wmcmurty1@example.com
# 2   id003    Kristos   Ivanets  kivanets2@example.com
# 3   id004    Madalyn       Max      mmax3@example.com
# 4   id005       Tobe   Riddich  triddich4@example.com
#
#                           image_url
# 0  http://example.com/img/id001.png
# 1  http://example.com/img/id002.jpg
# 2  http://example.com/img/id003.bmp
# 3  http://example.com/img/id004.jpg
# 4  http://example.com/img/id005.png
