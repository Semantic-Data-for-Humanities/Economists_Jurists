# %% [markdown]
# # Merge BnF DATA, DBpedia and Wikidata

# %% [markdown]
# In this notebook, we apply a method to merge three datasets (BnF, DBpedia and Wikidata)
#
# * First, we drop duplicates of each datasets.
#
# * Secondly, we merge the three datasets  by removing duplicate data. To realise that, we will use the Linkage toolkit who calculate the proximity (by giving a score) between to string from three dataframes.
#
# * Previously, we have to collect data about economists with SPARQL queries.

# %%
# Import libraries usefull

from SPARQLWrapper import SPARQLWrapper, SPARQLWrapper2, JSON, TURTLE, XML, RDFXML
import pprint
import csv
# from bs4 import BeautifulSoup

from collections import Counter
from operator import itemgetter
import pandas as pd

import sqlite3 as sql
import time

from importlib import reload
from shutil import copyfile

# %%
import sparql_functions as spqf # It's made-home fonctions created by Francesco Beretta
# so they must to be in the same folder as this file.

# %%
### La connextion à une base de données SQLite créé la base de données si elle n'est pas encore existante, 
#  et ce dans le dossier indiqué

cn = sql.connect('data/sparql_queries.db')

# %%
## Un curseur est un objet qui permet d'exécuter des requêtes sur la base des données en les isolant proprement
c = cn.cursor()

##  https://www.sqlite.org/lang_datefunc.html
# on vérifie ainsi qu'on est bien connecté à la base et on a l'heure locale actuelle
c.execute("SELECT datetime('now', 'localtime')")
print(c.fetchone())
# Out:
# ('2021-04-26 15:25:14',)

# %% [markdown]
# # Query economists and jurists from BnF Data

# %% [markdown]
# First step, we need datas about economists and jurists with theirs proprieties on 'BnF Data' so we realise a SPARQL query. We need proprieties to realise the merge between three datasets:
#   * Name
#
#   * Birth date
#
#   * Date of death
#
#   * Place of Birth
#
#   * Place of Death
#
# In addition, we add the biographie to filter the population we need.

# %%
### It's define the database ligne to use
pk_query = 1

# Connexion to the database
original_db = 'data/sparql_queries.db'
conn = sql.connect(original_db)

### It runs the query on the SQLite database to get the row values 
c.execute('SELECT * FROM query WHERE pk_query = ?', [pk_query]) ### a list around argument is needed for a string longer then one
#c.execute('SELECT * FROM query WHERE pk_query = 10')

rc = c.fetchone()

# close connexion
conn.close()

# %%
# print(rc[2] +  "\n-----\n" + rc[4] +  "\n-----\n" +   rc[7]+  "\n\n\n------------------\n" +  rc[5] + "\n\n\n------------------\n")

# %%
### Execute the SPARQL query wrapped in the function in the library _sparql_functions.py_
# The first setting correspond to SPARQL Endpoint, the seconde to the query
qr = spqf.get_json_sparql_result(rc[4],rc[5])
# Out:
# <class 'dict'>

# %%
# Number of rows in the result
len(qr['results']['bindings'])
# Out:
# 11132

# %%
# Inspect the first five rows
i = 0
for l in qr['results']['bindings']:
    if i < 5:
        print(l)
        i += 1
# Out:
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb12981404c#about'}, 'name': {'type': 'literal', 'value': 'Léon Garnier'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99996033'}, 'birthDate': {'type': 'literal', 'value': '1836-11-10'}, 'deathDate': {'type': 'literal', 'value': '1901-05-06'}, 'bio': {'type': 'literal', 'value': "Juriste. - Administrateur et homme de lettres. - En poste à la Préfecture de la Seine. - Frère de l'explorateur Francis Garnier (1839-1873)"}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13484444m#about'}, 'name': {'type': 'literal', 'value': 'Gaston de Pawlowski'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9999219'}, 'birthDate': {'type': 'literal', 'value': '1874-06-14'}, 'deathDate': {'type': 'literal', 'value': '1933-02-02'}, 'placeOfBirth': {'type': 'literal', 'value': 'Joigny (Yonne)'}, 'placeOfDeath': {'type': 'literal', 'value': 'Paris'}, 'bio': {'type': 'literal', 'value': 'Docteur en droit. - Critique littéraire et théâtral. - Rédacteur en chef de "Comoedia"'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb134841632#about'}, 'name': {'type': 'literal', 'value': 'Jean-Michel Berton'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9999131'}, 'birthDate': {'type': 'literal', 'value': '1794-07-03'}, 'deathDate': {'type': 'literal', 'value': '1845-10-20'}, 'placeOfBirth': {'type': 'literal', 'value': 'Cahors (Lot)'}, 'bio': {'type': 'literal', 'value': 'Écrivain politique, avocat à la Cour de cassation. - Fut fondateur et directeur de la "Revue poétique française et étrangère"'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13379520q#about'}, 'name': {'type': 'literal', 'value': 'Emmanuel Mathieu'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9995247'}, 'birthDate': {'type': 'literal', 'value': '1852-07-19'}, 'deathDate': {'type': 'literal', 'value': '19..'}, 'bio': {'type': 'literal', 'value': 'Docteur en droit (Paris, 1873)'}}
# {'s': {'type': 'uri', 'value': 'http://data.bnf.fr/ark:/12148/cb13338312g#about'}, 'name': {'type': 'literal', 'value': 'Josiah Henry Benton'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9994322'}, 'birthDate': {'type': 'literal', 'value': '1843'}, 'deathDate': {'type': 'literal', 'value': '1917'}, 'bio': {'type': 'literal', 'value': 'Juriste. - Bibliophile'}}

# %%
# Transform the result into a list with another fonction of the library
r_bnf = [l for l in spqf.sparql_result_to_list(qr)]
# r

# %%
# Inspect the first five of the list
#print(len(r_bnf))
#r_bnf[:5]

# %% [markdown]
# # Query economists and jurists from DBpedia

# %% [markdown]
# The query is the same as BnF Data, but we add the nationalities, who they don't on BnF Data.

# %%
### It's define the database ligne to use

### Query on the economists and jurists from DBpedia (expect the "lawyer recource")
pk_query = 2

# Connexion to the database
original_db = 'data/sparql_queries.db'
conn = sql.connect(original_db)

### It runs the query on the SQLite database to get the row values 
c.execute('SELECT * FROM query WHERE pk_query = ?', [pk_query]) ### a list around argument is needed for a string longer then one
#c.execute('SELECT * FROM query WHERE pk_query = 10')

rc = c.fetchone()

# close connexion
conn.close()

# %%
# Print the query
print(rc[2] +  "\n-----\n" + rc[4] +  "\n-----\n" +   rc[7]+  "\n\n\n------------------\n" +  rc[5] + "\n\n\n------------------\n")
# Out:
# This query takes informations about economists and jurists (except 'Lawyers') from DBpedia. The proprieties to take are the URI, the name, the birthdate, the deathdate, the place of birth and the place of death.
# -----
# https://dbpedia.org/sparql
# -----
# 2021-04-22 10:13:00
#
#
# ------------------
# PREFIX  dbo:  <http://dbpedia.org/ontology/>
# PREFIX  dbp:  <http://dbpedia.org/property/>
# PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
# PREFIX  dbr:  <http://dbpedia.org/resource/>
# PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
# PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
#
# SELECT DISTINCT  ?s ?uri ?name ?birthDate ?deathDate ?placeOfBirth ?placeOfDeath
# WHERE
#   {   { ?s  a              dbo:Economist ;
#             dbp:birthDate  ?birthDate
#         FILTER ( xsd:date(?birthDate) > "1770-01-01"^^xsd:dateTime )
#         OPTIONAL
#           { ?s  owl:sameAs  ?uri
#             FILTER regex(?uri, "viaf", "i")
#           }
#         OPTIONAL
#           { ?s  dbp:name  ?name }
#         OPTIONAL
#           { ?s  dbp:birthPlace  ?bp }
#         OPTIONAL
#           { ?s  dbp:deathPlace  ?dp }
#         OPTIONAL
#           { ?s  dbp:deathDate  ?deathDate }
#         OPTIONAL
#           { ?s dbp:deathDate  ?deathDate }
#         OPTIONAL
#           { ?s  dbp:nationality  ?nationality1 }
#
#       }
#     UNION
#       { ?s  ?propriety  dbr:Economist ;
#             dbp:birthDate  ?birthDate
#
#         FILTER ( xsd:date(?birthDate) > "1770-01-01"^^xsd:dateTime )
#         OPTIONAL
#           { ?s  owl:sameAs  ?uri
#             FILTER regex(?uri, "viaf", "i")
#           }
#         OPTIONAL
#           { ?s  dbp:name  ?name
#           }
#         OPTIONAL
#           { ?s  dbp:birthPlace  ?bp }
#         OPTIONAL
#           { ?s  dbp:deathPlace  ?dp }
#         OPTIONAL
#           { ?s dbp:deathDate  ?deathDate }
#         OPTIONAL
#           { ?s  dbp:nationality  ?nationality1 }
#       }
#     UNION
#       { ?s  ?p             dbr:Jurist ;
#             dbp:birthDate  ?birthDate
#         FILTER ( xsd:date(?birthDate) > "1770-01-01"^^xsd:dateTime )
#         OPTIONAL
#           { ?s  dbp:name  ?name
#           }
#         OPTIONAL
#           { ?s  owl:sameAs  ?uri
#             FILTER regex(?uri, "viaf", "i")
#           }
#         OPTIONAL
#           { ?s  dbp:birthPlace  ?bp }
#         OPTIONAL
#           { ?s  dbp:deathPlace  ?dp }
#         OPTIONAL
#           { ?s dbp:deathDate  ?deathDate }
#         OPTIONAL
#           { ?s  dbp:nationality  ?nationality1 }
#       }
#     UNION
#       { ?s  a              dbr:Professor ;
#             dbp:birthDate  ?birthDate ;
#             dbo:abstract   ?abstract
#         FILTER ( ( ( ( regex(?abstract, "lawyer", "i") || regex(?abstract, "jurist", "i") ) || regex(?abstract, "juriste", "i") ) || regex(?abstract, "attorney", "i") ) || regex(?abstract, "legal professional", "i") )
#         OPTIONAL
#           { ?s  dbp:name  ?name
#           }
#         OPTIONAL
#           { ?s  owl:sameAs  ?uri
#             FILTER regex(?uri, "viaf", "i")
#           }
#         OPTIONAL
#           { ?s  dbp:birthPlace  ?bp }
#         OPTIONAL
#           { ?s  dbp:deathPlace  ?dp }
#         OPTIONAL
#           { ?s dbp:deathDate  ?deathDate }
#         OPTIONAL
#           { ?s  dbp:nationality  ?nationality1 }
#       }
#     FILTER ( xsd:string(?name) != "Marcus Tullius Cicero" )
#     FILTER ( xsd:string(?name) != "Samuel Bowles" )
#     BIND(strafter(str(?bp), "http://dbpedia.org/resource/") AS ?bp1)
#     BIND(replace(str(?bp1), "[_]", " ") AS ?placeOfBirth)
#
#     BIND(strafter(str(?dp), "http://dbpedia.org/resource/") AS ?dp1)
#     BIND(replace(str(?dp1), "[_]", " ") AS ?placeOfDeath)
#
#     BIND(strafter(str(?nationality1), "http://dbpedia.org/resource/") AS ?nationality2)
#     BIND(replace(str(?nationality2), "[_]", " ") AS ?nationality)
#   }
# ORDER BY DESC(?uri)
#
#
# ------------------

# %% [markdown]
# In this query, we have made the choice to aggregate, by a UNION clause, several queries to maximise the results' number. Also we request the "economists" and the "jurists" in only one query.
#
# Obviously, we chose classes and instances directly related to our population, but also the "professor" instance, because some "economists" or "jurists" are in this instance (we have tried with and without them, and there more result when we use them).
#
# Also, we exclude all classes because they don't add more result, except the "Economist" class (we keep it)
#
# For exemple, we exclude the resource "personFunction" and the resource "Jurists" because they add no more data. Additionally, we keep only the "Professor" instance for the jurists (it returns result only for the jurists).

# %%
### Execute the SPARQL query wrapped in the function in the library _sparql_functions.py_
# The first setting correspond to SPARQL Endpoint, the seconde to the query
qr = spqf.get_json_sparql_result(rc[4],rc[5])
# Out:
# <class 'dict'>

# %%
# Number of rows in the result
len(qr['results']['bindings'])
# Unfortunately, DBpedia has set a row limit of 10,000, see https://wiki.dbpedia.org/public-sparql-endpoint.
# Out:
# 7026

# %%
# Inspect the first five rows
i = 0
for l in qr['results']['bindings']:
    if i < 5:
        print(l)
        i += 1
# Out:
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/António_de_Almeida_Santos'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99921066'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'António de Almeida Santos'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1926-02-15'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '2016-01-18'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Carlos_Carvalhas'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99826658'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Carlos Carvalhas'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1941-11-09'}, 'placeOfBirth': {'type': 'literal', 'value': 'São Pedro do Sul, Portugal'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Anita_Augspurg'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9976800'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Anita Augspurg'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1857-09-22'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1943-12-20'}, 'placeOfBirth': {'type': 'literal', 'value': ''}, 'placeOfDeath': {'type': 'literal', 'value': ''}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Mason_Gaffney'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/9960617'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Mason Gaffney'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1923-10-18'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '2020-07-16'}, 'placeOfBirth': {'type': 'literal', 'value': ''}, 'placeOfDeath': {'type': 'literal', 'value': ''}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Paulo_Portas'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/99455673'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Paulo Portas'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1962-09-12'}, 'placeOfBirth': {'type': 'literal', 'value': 'Lisbon'}}

# %%
# Transform the result into a list with another fonction of the library
r_dbp = [l for l in spqf.sparql_result_to_list(qr)]
# r

# %%
# Inspect the first five of the list
#print(len(r_dbp))
#r_dbp[:5]

# %% [markdown]
# ####  "lawyer recource" from DBpedia

# %%
### It's define the database ligne to use

### Query on the "lawyer recource" from DBpedia

pk_query = 5

# Connexion to the database
original_db = 'data/sparql_queries.db'
conn = sql.connect(original_db)

### It runs the query on the SQLite database to get the row values 
c.execute('SELECT * FROM query WHERE pk_query = ?', [pk_query]) ### a list around argument is needed for a string longer then one
#c.execute('SELECT * FROM query WHERE pk_query = 10')

rc = c.fetchone()

# close connexion
conn.close()

# %%
# Print the query
print(rc[2] +  "\n-----\n" + rc[4] +  "\n-----\n" + rc[6]+  "\n-----\n" +  rc[7]+  "\n\n\n------------------\n" +  rc[5] + "\n\n\n------------------\n")
# Out:
# This query takes informations about 'lawyers' from DBpedia. The proprieties to take are the URI, the name, the birthdate, the deathdate, the place of birth and the place of death.
# -----
# https://dbpedia.org/sparql
# -----
# We set the 'lawyer' resource apart because it exceeds the 10,000 rows allowed by DBpedia. Therefore we treat it differently from the others
# -----
# 2021-04-26 11:54:11
#
#
# ------------------
# PREFIX  dbo:  <http://dbpedia.org/ontology/>
# PREFIX  dbp:  <http://dbpedia.org/property/>
# PREFIX  owl:  <http://www.w3.org/2002/07/owl#>
# PREFIX  dbr:  <http://dbpedia.org/resource/>
# PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
# PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
#
# SELECT DISTINCT  ?s (SAMPLE(?uri1) AS ?uri) ?name ?birthDate ?deathDate (SAMPLE(?pb2) AS ?placeOfBirth) (SAMPLE(?pd2) AS ?placeOfDeath)
# WHERE
#   { ?s  ?p             dbr:Lawyer ;
#         dbo:birthDate  ?birthDate
#     FILTER ( xsd:date(?birthDate) > "1770-01-01"^^xsd:dateTime )
#     FILTER ( xsd:date(?birthDate) != "-106-01-03"^^xsd:date )
#     OPTIONAL
#       { ?s  dbp:name  ?name }
#     OPTIONAL
#       { ?s  dbo:birthPlace  ?pb }
#     OPTIONAL
#       { ?s  dbo:deathPlace  ?pd }
#     OPTIONAL
#       { ?s  dbo:deathDate  ?deathDate }
#     OPTIONAL
#       { ?s  owl:sameAs  ?uri1
#         FILTER regex(?uri1, "viaf", "i")
#       }
#     FILTER ( ! regex(str(?s), "football") )
#     FILTER ( ! regex(str(?name), "football") )
#     FILTER ( xsd:string(?name) != "Marcus Tullius Cicero" )
#     FILTER ( xsd:string(?name) != "Samuel Bowles" )
#     BIND(strafter(str(?pb), "http://dbpedia.org/resource/") AS ?pb1)
#     BIND(replace(str(?pb1), "[_]", " ") AS ?pb2)
#     BIND(strafter(str(?pd), "http://dbpedia.org/resource/") AS ?pd1)
#     BIND(replace(str(?pd1), "[_]", " ") AS ?pd2)
#   }
# GROUP BY ?s ?name ?birthDate ?deathDate
#
#
#
# ------------------

# %%
### Execute the SPARQL query wrapped in the function in the library _sparql_functions.py_
# The first setting correspond to SPARQL Endpoint, the seconde to the query
qr = spqf.get_json_sparql_result(rc[4],rc[5])
# Out:
# <class 'dict'>

# %%
# Number of rows in the result
len(qr['results']['bindings'])
# Out:
# 8533

# %%
# Inspect the first five rows
i = 0
for l in qr['results']['bindings']:
    if i < 5:
        print(l)
        i += 1
# Out:
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lucjan_Wolanowski'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/54672620'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Lucjan Wolanowski'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1920-02-26'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '2006-02-20'}, 'placeOfBirth': {'type': 'literal', 'value': 'Poland'}, 'placeOfDeath': {'type': 'literal', 'value': 'Poland'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Henry_Rogers_Seager'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/41905280'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Henry Rogers Seager'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1870-07-21'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1930-08-23'}, 'placeOfBirth': {'type': 'literal', 'value': 'Lansing, Michigan'}, 'placeOfDeath': {'type': 'literal', 'value': 'Kiev'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Joseph_George_Rosengarten'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/49981696'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Joseph George Rosengarten'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1835-07-14'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1921-01-14'}, 'placeOfBirth': {'type': 'literal', 'value': 'Philadelphia'}, 'placeOfDeath': {'type': 'literal', 'value': 'Philadelphia'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Dirk_Ballendorf'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/12443042'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Dirk Ballendorf'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1939-04-22'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '2013-02-04'}, 'placeOfBirth': {'type': 'literal', 'value': 'Pennsylvania'}, 'placeOfDeath': {'type': 'literal', 'value': 'Guam'}}
# {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Konstantin_Rodzaevsky'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/8190795'}, 'name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Konstantin Rodzaevsky'}, 'birthDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1907-08-11'}, 'deathDate': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#date', 'value': '1946-08-30'}, 'placeOfBirth': {'type': 'literal', 'value': 'Blagoveshchensk'}, 'placeOfDeath': {'type': 'literal', 'value': 'Russian Soviet Federative Socialist Republic'}}

# %%
# Transform the result into a list with another fonction of the library
r_dbp_l = [l for l in spqf.sparql_result_to_list(qr)]
# r

# %%
# Inspect the first five of the list
#print(len(r_dbp))
#r_dbp[:5]

# %% [markdown]
# # Query economists and jurists from Wikidata

# %% [markdown]
# The query is the same as the two others, but we add the BnF URI propriety. This propriety exists on Wikidata , we use it to realize in a simpler way the merge below.

# %%
### It's define the database ligne to use (here there correspond to the query from Wikidata)
pk_query = 3

# Connexion to the database
original_db = 'data/sparql_queries.db'
conn = sql.connect(original_db)

### It runs the query on the SQLite database to get the row values 
c.execute('SELECT * FROM query WHERE pk_query = ?', [pk_query]) ### a list around argument is needed for a string longer then one
#c.execute('SELECT * FROM query WHERE pk_query = 10')

rc = c.fetchone()

# close connexion
conn.close()

# %%
# Print the query
#print(rc[2] +  "\n-----\n" + rc[4] +  "\n-----\n" +   rc[7]+  "\n\n\n------------------\n" +  rc[5] + "\n\n\n------------------\n")

# %% [markdown]
# **SERVICE clause**
#
# The use of the SERVICE clause is very important to display the property label. Also, in the SELECT, It must have "Label" used to work.
#
# **BnF Propriety**
#
# We get the BnF propriety to merge easier but it returns only this URI (ex: 134841632) but we need the complete URL (ex:http://data.bnf.fr/ark:/12148/cb134841632#about') to realise the merge so we use the concatenation.

# %%
### Execute the SPARQL query wrapped in the function in the library _sparql_functions.py_
# The first setting correspond to SPARQL Endpoint, the seconde to the query
qr = spqf.get_json_sparql_result(rc[4],rc[5])
# Out:
# <class 'dict'>

# %%
# Number of rows in the result
len(qr['results']['bindings'])
# Out:
# 56524

# %%
# Inspect the first five rows
i = 0
for l in qr['results']['bindings']:
    if i < 5:
        print(l)
        i += 1
# Out:
# {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q72568'}, 'name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Alfred Lichtenstein'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/71423827'}, 'birthPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Berlin'}, 'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1889-08-23T00:00:00Z'}, 'deathPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Somme'}, 'deathDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1914-09-25T00:00:00Z'}, 'uri_bnf': {'type': 'literal', 'value': 'http://data.bnf.fr/ark:/12148/cb12123568r#about'}}
# {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q72553'}, 'name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Heinrich von Bülow'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/62342475'}, 'birthPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Schwerin'}, 'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1792-09-16T00:00:00Z'}, 'deathPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Berlin'}, 'deathDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1846-02-06T00:00:00Z'}}
# {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q72628'}, 'name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Alfred von Kiderlen-Waechter'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/54958174'}, 'birthPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Stuttgart'}, 'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1852-07-10T00:00:00Z'}, 'deathPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Stuttgart'}, 'deathDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1912-12-30T00:00:00Z'}, 'uri_bnf': {'type': 'literal', 'value': 'http://data.bnf.fr/ark:/12148/cb135097503#about'}}
# {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q72535'}, 'name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Rainer Rupp'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/15698197'}, 'birthPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Saarlouis'}, 'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1945-09-21T00:00:00Z'}}
# {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q77404'}, 'name': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ingeborg Schwenzer'}, 'uri': {'type': 'uri', 'value': 'http://viaf.org/viaf/91748910'}, 'birthPlaceLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Stuttgart'}, 'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime', 'type': 'literal', 'value': '1951-10-25T00:00:00Z'}, 'uri_bnf': {'type': 'literal', 'value': 'http://data.bnf.fr/ark:/12148/cb15067859n#about'}}

# %%
# Transform the result into a list with another fonction of the library
r_wk = [l for l in spqf.sparql_result_to_list(qr)]
# r

# %%
# Inspect the first five of the list
print(len(r_wk))
r_wk[:5]
# Out:
# 56524
# [['http://www.wikidata.org/entity/Q72568',
#   'Alfred Lichtenstein',
#   '1889-08-23T00:00:00Z',
#   '1914-09-25T00:00:00Z',
#   'Berlin',
#   'Somme',
#   'http://viaf.org/viaf/71423827',
#   'http://data.bnf.fr/ark:/12148/cb12123568r#about'],
#  ['http://www.wikidata.org/entity/Q72553',
#   'Heinrich von Bülow',
#   '1792-09-16T00:00:00Z',
#   '1846-02-06T00:00:00Z',
#   'Schwerin',
#   'Berlin',
#   'http://viaf.org/viaf/62342475',
#   ''],
#  ['http://www.wikidata.org/entity/Q72628',
#   'Alfred von Kiderlen-Waechter',
#   '1852-07-10T00:00:00Z',
#   '1912-12-30T00:00:00Z',
#   'Stuttgart',
#   'Stuttgart',
#   'http://viaf.org/viaf/54958174',
#   'http://data.bnf.fr/ark:/12148/cb135097503#about'],
#  ['http://www.wikidata.org/entity/Q72535',
#   'Rainer Rupp',
#   '1945-09-21T00:00:00Z',
#   '',
#   'Saarlouis',
#   '',
#   'http://viaf.org/viaf/15698197',
#   ''],
#  ['http://www.wikidata.org/entity/Q77404',
#   'Ingeborg Schwenzer',
#   '1951-10-25T00:00:00Z',
#   '',
#   'Stuttgart',
#   '',
#   'http://viaf.org/viaf/91748910',
#   'http://data.bnf.fr/ark:/12148/cb15067859n#about']]

# %% [markdown]
# -------------------------------

# %% [markdown]
# # Dataframes

# %% [markdown]
# The script below serves to change lists into a dataframe.
# First,

# %% [markdown]
# ### BnF

# %%
df_bnf = pd.DataFrame(r_bnf, columns=['uri','name','viaf','birthDate','deathDate' , 'placeOfBirth','placeOfDeath','bio'])
print(len(df_bnf))
df_bnf.fillna('')

df_bnf[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-e601ad9b9898> in <module>
# ----> 1 df_bnf = pd.DataFrame(r_bnf, columns=['uri','name','viaf','birthDate','deathDate' , 'placeOfBirth','placeOfDeath','bio'])
#       2 print(len(df_bnf))
#       3 df_bnf.fillna('')
#       4
#       5 df_bnf[:10]
#
# NameError: name 'r_bnf' is not defined

# %%
df_bnf.set_index("uri")
# Out:
#                                                                     name  \
# uri
# http://data.bnf.fr/ark:/12148/cb12981404c#about             Léon Garnier
# http://data.bnf.fr/ark:/12148/cb13484444m#about      Gaston de Pawlowski
# http://data.bnf.fr/ark:/12148/cb134841632#about       Jean-Michel Berton
# http://data.bnf.fr/ark:/12148/cb13379520q#about         Emmanuel Mathieu
# http://data.bnf.fr/ark:/12148/cb13338312g#about      Josiah Henry Benton
# ...                                                                  ...
# http://data.bnf.fr/ark:/12148/cb11475627b#about            Joan Mitchell
# http://data.bnf.fr/ark:/12148/cb10562770v#about     Kazimierz Zimmermann
# http://data.bnf.fr/ark:/12148/cb17701366b#about              ʿUmar ʿAzīz
# http://data.bnf.fr/ark:/12148/cb17877820g#about           John Davenport
# http://data.bnf.fr/ark:/12148/cb17877063j#about  Ricardo Martinez Vargas
#
#                                                                           viaf  \
# uri
# http://data.bnf.fr/ark:/12148/cb12981404c#about  http://viaf.org/viaf/99996033
# http://data.bnf.fr/ark:/12148/cb13484444m#about   http://viaf.org/viaf/9999219
# http://data.bnf.fr/ark:/12148/cb134841632#about   http://viaf.org/viaf/9999131
# http://data.bnf.fr/ark:/12148/cb13379520q#about   http://viaf.org/viaf/9995247
# http://data.bnf.fr/ark:/12148/cb13338312g#about   http://viaf.org/viaf/9994322
# ...                                                                        ...
# http://data.bnf.fr/ark:/12148/cb11475627b#about
# http://data.bnf.fr/ark:/12148/cb10562770v#about
# http://data.bnf.fr/ark:/12148/cb17701366b#about
# http://data.bnf.fr/ark:/12148/cb17877820g#about
# http://data.bnf.fr/ark:/12148/cb17877063j#about
#
#                                                   birthDate   deathDate  \
# uri
# http://data.bnf.fr/ark:/12148/cb12981404c#about  1836-11-10  1901-05-06
# http://data.bnf.fr/ark:/12148/cb13484444m#about  1874-06-14  1933-02-02
# http://data.bnf.fr/ark:/12148/cb134841632#about  1794-07-03  1845-10-20
# http://data.bnf.fr/ark:/12148/cb13379520q#about  1852-07-19        19..
# http://data.bnf.fr/ark:/12148/cb13338312g#about        1843        1917
# ...                                                     ...         ...
# http://data.bnf.fr/ark:/12148/cb11475627b#about  1920-03-15  2014-02-13
# http://data.bnf.fr/ark:/12148/cb10562770v#about        1874        1925
# http://data.bnf.fr/ark:/12148/cb17701366b#about  1949-02-18  2013-02-16
# http://data.bnf.fr/ark:/12148/cb17877820g#about  1904-09-11  1987-06-08
# http://data.bnf.fr/ark:/12148/cb17877063j#about  1885-03-13        19..
#
#                                                                             placeOfBirth  \
# uri
# http://data.bnf.fr/ark:/12148/cb12981404c#about
# http://data.bnf.fr/ark:/12148/cb13484444m#about                           Joigny (Yonne)
# http://data.bnf.fr/ark:/12148/cb134841632#about                             Cahors (Lot)
# http://data.bnf.fr/ark:/12148/cb13379520q#about
# http://data.bnf.fr/ark:/12148/cb13338312g#about
# ...                                                                                  ...
# http://data.bnf.fr/ark:/12148/cb11475627b#about
# http://data.bnf.fr/ark:/12148/cb10562770v#about                     Trzemeszno (Pologne)
# http://data.bnf.fr/ark:/12148/cb17701366b#about
# http://data.bnf.fr/ark:/12148/cb17877820g#about  Philadelphie (Pennsylvanie, États-Unis)
# http://data.bnf.fr/ark:/12148/cb17877063j#about
#
#                                                                       placeOfDeath  \
# uri
# http://data.bnf.fr/ark:/12148/cb12981404c#about
# http://data.bnf.fr/ark:/12148/cb13484444m#about                              Paris
# http://data.bnf.fr/ark:/12148/cb134841632#about
# http://data.bnf.fr/ark:/12148/cb13379520q#about
# http://data.bnf.fr/ark:/12148/cb13338312g#about
# ...                                                                            ...
# http://data.bnf.fr/ark:/12148/cb11475627b#about
# http://data.bnf.fr/ark:/12148/cb10562770v#about                 Cracovie (Pologne)
# http://data.bnf.fr/ark:/12148/cb17701366b#about
# http://data.bnf.fr/ark:/12148/cb17877820g#about  Red Bank (New Jersey, États-Unis)
# http://data.bnf.fr/ark:/12148/cb17877063j#about
#
#                                                                                                bio
# uri
# http://data.bnf.fr/ark:/12148/cb12981404c#about  Juriste. - Administrateur et homme de lettres....
# http://data.bnf.fr/ark:/12148/cb13484444m#about  Docteur en droit. - Critique littéraire et thé...
# http://data.bnf.fr/ark:/12148/cb134841632#about  Écrivain politique, avocat à la Cour de cassat...
# http://data.bnf.fr/ark:/12148/cb13379520q#about                     Docteur en droit (Paris, 1873)
# http://data.bnf.fr/ark:/12148/cb13338312g#about                             Juriste. - Bibliophile
# ...                                                                                            ...
# http://data.bnf.fr/ark:/12148/cb11475627b#about  Économiste. - Professeur d'économie de l'unive...
# http://data.bnf.fr/ark:/12148/cb10562770v#about  Chanoine. - Economiste. - Recteur de l'Univers...
# http://data.bnf.fr/ark:/12148/cb17701366b#about  Chercheur et professeur d'économie. - Militant...
# http://data.bnf.fr/ark:/12148/cb17877820g#about  Journaliste économiste. - Journaliste à : "For...
# http://data.bnf.fr/ark:/12148/cb17877063j#about                              Diplomate, économiste
#
# [11132 rows x 7 columns]

# %%
#count the number of similar URIs
gb_bnf=df_bnf.groupby(['uri_bnf']).size()
print(gb_bnf)
# Out:
# uri_bnf
# http://data.bnf.fr/ark:/12148/cb10002423d#about    1
# http://data.bnf.fr/ark:/12148/cb10011983m#about    1
# http://data.bnf.fr/ark:/12148/cb10012188c#about    1
# http://data.bnf.fr/ark:/12148/cb10023428s#about    1
# http://data.bnf.fr/ark:/12148/cb10028057g#about    1
#                                                   ..
# http://data.bnf.fr/ark:/12148/cb17915446h#about    1
# http://data.bnf.fr/ark:/12148/cb17915558s#about    1
# http://data.bnf.fr/ark:/12148/cb17916121k#about    1
# http://data.bnf.fr/ark:/12148/cb179164907#about    1
# http://data.bnf.fr/ark:/12148/cb179165043#about    1
# Length: 11039, dtype: int64

# %%
# count the number of similar URIs greater than one
sort_bnf=gb_bnf.sort_values(ascending=False) > 1
sum(sort_bnf)
# Out:
# 93

# %% [markdown]
# ### DBpedia

# %%
df_dbp = pd.DataFrame(r_dbp, columns=['uri_dbp', 'viaf_dbp', 'name_dbp','birthDate_dbp','deathDate_dbp', 'placeOfBirth_dbp','placeOfDeath_dbp'])
print(len(df_dbp))
df_dbp.head(20)
# Out:
# 7026
#                                               uri_dbp  \
# 0   http://dbpedia.org/resource/António_de_Almeida...
# 1        http://dbpedia.org/resource/Carlos_Carvalhas
# 2          http://dbpedia.org/resource/Anita_Augspurg
# 3           http://dbpedia.org/resource/Mason_Gaffney
# 4            http://dbpedia.org/resource/Paulo_Portas
# 5            http://dbpedia.org/resource/Paulo_Portas
# 6   http://dbpedia.org/resource/Hermann_Heinrich_G...
# 7   http://dbpedia.org/resource/Fernando_Teixeira_...
# 8   http://dbpedia.org/resource/Fernando_Teixeira_...
# 9      http://dbpedia.org/resource/Gottfried_Haberler
# 10     http://dbpedia.org/resource/Gottfried_Haberler
# 11       http://dbpedia.org/resource/Michael_C._Burda
# 12           http://dbpedia.org/resource/Xavier_Vives
# 13  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 14  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 15  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 16  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 17       http://dbpedia.org/resource/James_M._Poterba
# 18          http://dbpedia.org/resource/David_Laibman
# 19            http://dbpedia.org/resource/Claus_Roxin
#
#                          viaf_dbp                      name_dbp birthDate_dbp  \
# 0   http://viaf.org/viaf/99921066     António de Almeida Santos    1926-02-15
# 1   http://viaf.org/viaf/99826658              Carlos Carvalhas    1941-11-09
# 2    http://viaf.org/viaf/9976800                Anita Augspurg    1857-09-22
# 3    http://viaf.org/viaf/9960617                 Mason Gaffney    1923-10-18
# 4   http://viaf.org/viaf/99455673                  Paulo Portas    1962-09-12
# 5   http://viaf.org/viaf/99455673                  Paulo Portas    1962-09-12
# 6    http://viaf.org/viaf/9939728       Hermann Heinrich Gossen    1810-09-07
# 7   http://viaf.org/viaf/99275725  Fernando Teixeira dos Santos    1951-09-13
# 8   http://viaf.org/viaf/99275725  Fernando Teixeira dos Santos    1951-09-13
# 9   http://viaf.org/viaf/99257315            Gottfried Haberler    1900-07-20
# 10  http://viaf.org/viaf/99257315            Gottfried Haberler    1900-07-20
# 11   http://viaf.org/viaf/9922987              Michael C. Burda    1959-04-04
# 12   http://viaf.org/viaf/9920331                  Xavier Vives    1955-01-23
# 13   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 14   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 15   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 16   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 17   http://viaf.org/viaf/9910825              James M. Poterba    1958-07-13
# 18   http://viaf.org/viaf/9910613                 David Laibman    1942-12-25
# 19   http://viaf.org/viaf/9910548                   Claus Roxin    1931-05-15
#
#    deathDate_dbp             placeOfBirth_dbp  placeOfDeath_dbp
# 0     2016-01-18
# 1                  São Pedro do Sul, Portugal
# 2     1943-12-20
# 3     2020-07-16
# 4                                      Lisbon
# 5                                    Portugal
# 6     1858-02-13                        Düren           Cologne
# 7                              Maia, Portugal
# 8                                    Portugal
# 9     1995-05-06                  Purkersdorf  Washington, D.C.
# 10    1995-05-06              Austria-Hungary  Washington, D.C.
# 11
# 12
# 13    1952-12-01  Kingdom of the Two Sicilies             Italy
# 14    1952-12-01                      Palermo             Italy
# 15    1952-12-01  Kingdom of the Two Sicilies              Rome
# 16    1952-12-01                      Palermo              Rome
# 17
# 18
# 19

# %%
# The script below is used to concatenate the DBpedia data, adding the resource 'lawyer' to the rest of the data 
df_dbp_l = pd.DataFrame(r_dbp_l, columns=['uri_dbp','viaf_dbp', 'name_dbp','birthDate_dbp','deathDate_dbp', 'placeOfBirth_dbp','placeOfDeath_dbp'])
print(len(df_dbp_l))
df_dbp_l[:10]
# Out:
# 8533
#                                              uri_dbp  \
# 0      http://dbpedia.org/resource/Lucjan_Wolanowski
# 1    http://dbpedia.org/resource/Henry_Rogers_Seager
# 2  http://dbpedia.org/resource/Joseph_George_Rose...
# 3        http://dbpedia.org/resource/Dirk_Ballendorf
# 4  http://dbpedia.org/resource/Konstantin_Rodzaevsky
# 5       http://dbpedia.org/resource/Presley_T._Glass
# 6       http://dbpedia.org/resource/Price_Daniel_Jr.
# 7     http://dbpedia.org/resource/Rafael_Uribe_Uribe
# 8             http://dbpedia.org/resource/Lyman_Duff
# 9        http://dbpedia.org/resource/Denison_Kitchel
#
#                         viaf_dbp                   name_dbp birthDate_dbp  \
# 0  http://viaf.org/viaf/54672620          Lucjan Wolanowski    1920-02-26
# 1  http://viaf.org/viaf/41905280        Henry Rogers Seager    1870-07-21
# 2  http://viaf.org/viaf/49981696  Joseph George Rosengarten    1835-07-14
# 3  http://viaf.org/viaf/12443042            Dirk Ballendorf    1939-04-22
# 4   http://viaf.org/viaf/8190795      Konstantin Rodzaevsky    1907-08-11
# 5  http://viaf.org/viaf/43885263     Presley Thornton Glass    1824-10-18
# 6  http://viaf.org/viaf/63003481           Price Daniel Jr.    1941-06-08
# 7  http://viaf.org/viaf/29567121         Rafael Uribe Uribe    1859-04-12
# 8                                            Sir Lyman Duff    1865-01-07
# 9                                           Denison Kitchel    1908-03-01
#
#   deathDate_dbp          placeOfBirth_dbp  \
# 0    2006-02-20                    Poland
# 1    1930-08-23         Lansing, Michigan
# 2    1921-01-14              Philadelphia
# 3    2013-02-04              Pennsylvania
# 4    1946-08-30           Blagoveshchensk
# 5    2018-10-02  Halifax County, Virginia
# 6    1981-01-19                    Austin
# 7    1914-10-15     Valparaíso, Antioquia
# 8    1955-04-26                   Ontario
# 9    2002-10-10      Bronxville, New York
#
#                                placeOfDeath_dbp
# 0                                        Poland
# 1                                          Kiev
# 2                                  Philadelphia
# 3                                          Guam
# 4  Russian Soviet Federative Socialist Republic
# 5                                     Tennessee
# 6                         Liberty County, Texas
# 7                                  Bogotá, D.C.
# 8                                       Ontario
# 9                                       Arizona

# %%
frames=[df_dbp, df_dbp_l]

# %%
df_dbpc=  pd.concat(frames)
print(len(df_dbp))
df_dbpc[:20]
# Out:
# 15559
#                                               uri_dbp  \
# 0   http://dbpedia.org/resource/António_de_Almeida...
# 1        http://dbpedia.org/resource/Carlos_Carvalhas
# 2          http://dbpedia.org/resource/Anita_Augspurg
# 3           http://dbpedia.org/resource/Mason_Gaffney
# 4            http://dbpedia.org/resource/Paulo_Portas
# 5            http://dbpedia.org/resource/Paulo_Portas
# 6   http://dbpedia.org/resource/Hermann_Heinrich_G...
# 7   http://dbpedia.org/resource/Fernando_Teixeira_...
# 8   http://dbpedia.org/resource/Fernando_Teixeira_...
# 9      http://dbpedia.org/resource/Gottfried_Haberler
# 10     http://dbpedia.org/resource/Gottfried_Haberler
# 11       http://dbpedia.org/resource/Michael_C._Burda
# 12           http://dbpedia.org/resource/Xavier_Vives
# 13  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 14  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 15  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 16  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 17       http://dbpedia.org/resource/James_M._Poterba
# 18          http://dbpedia.org/resource/David_Laibman
# 19            http://dbpedia.org/resource/Claus_Roxin
#
#                          viaf_dbp                      name_dbp birthDate_dbp  \
# 0   http://viaf.org/viaf/99921066     António de Almeida Santos    1926-02-15
# 1   http://viaf.org/viaf/99826658              Carlos Carvalhas    1941-11-09
# 2    http://viaf.org/viaf/9976800                Anita Augspurg    1857-09-22
# 3    http://viaf.org/viaf/9960617                 Mason Gaffney    1923-10-18
# 4   http://viaf.org/viaf/99455673                  Paulo Portas    1962-09-12
# 5   http://viaf.org/viaf/99455673                  Paulo Portas    1962-09-12
# 6    http://viaf.org/viaf/9939728       Hermann Heinrich Gossen    1810-09-07
# 7   http://viaf.org/viaf/99275725  Fernando Teixeira dos Santos    1951-09-13
# 8   http://viaf.org/viaf/99275725  Fernando Teixeira dos Santos    1951-09-13
# 9   http://viaf.org/viaf/99257315            Gottfried Haberler    1900-07-20
# 10  http://viaf.org/viaf/99257315            Gottfried Haberler    1900-07-20
# 11   http://viaf.org/viaf/9922987              Michael C. Burda    1959-04-04
# 12   http://viaf.org/viaf/9920331                  Xavier Vives    1955-01-23
# 13   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 14   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 15   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 16   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 17   http://viaf.org/viaf/9910825              James M. Poterba    1958-07-13
# 18   http://viaf.org/viaf/9910613                 David Laibman    1942-12-25
# 19   http://viaf.org/viaf/9910548                   Claus Roxin    1931-05-15
#
#    deathDate_dbp             placeOfBirth_dbp  placeOfDeath_dbp
# 0     2016-01-18
# 1                  São Pedro do Sul, Portugal
# 2     1943-12-20
# 3     2020-07-16
# 4                                      Lisbon
# 5                                    Portugal
# 6     1858-02-13                        Düren           Cologne
# 7                              Maia, Portugal
# 8                                    Portugal
# 9     1995-05-06                  Purkersdorf  Washington, D.C.
# 10    1995-05-06              Austria-Hungary  Washington, D.C.
# 11
# 12
# 13    1952-12-01  Kingdom of the Two Sicilies             Italy
# 14    1952-12-01                      Palermo             Italy
# 15    1952-12-01  Kingdom of the Two Sicilies              Rome
# 16    1952-12-01                      Palermo              Rome
# 17
# 18
# 19

# %%
# Out:
#                                                                          viaf_dbp  \
# uri_dbp
# http://dbpedia.org/resource/António_de_Almeida_...  http://viaf.org/viaf/99921066
# http://dbpedia.org/resource/Carlos_Carvalhas        http://viaf.org/viaf/99826658
# http://dbpedia.org/resource/Anita_Augspurg           http://viaf.org/viaf/9976800
# http://dbpedia.org/resource/Mason_Gaffney            http://viaf.org/viaf/9960617
# http://dbpedia.org/resource/Paulo_Portas            http://viaf.org/viaf/99455673
# ...                                                                           ...
# http://dbpedia.org/resource/Thomas_Reilly
# http://dbpedia.org/resource/Todd_McKenney_(poli...
# http://dbpedia.org/resource/Yaël_Braun-Pivet
# http://dbpedia.org/resource/Medard_Kalemani
# http://dbpedia.org/resource/Melanie_George_Smith
#
#                                                                      name_dbp  \
# uri_dbp
# http://dbpedia.org/resource/António_de_Almeida_...  António de Almeida Santos
# http://dbpedia.org/resource/Carlos_Carvalhas                 Carlos Carvalhas
# http://dbpedia.org/resource/Anita_Augspurg                     Anita Augspurg
# http://dbpedia.org/resource/Mason_Gaffney                       Mason Gaffney
# http://dbpedia.org/resource/Paulo_Portas                         Paulo Portas
# ...                                                                       ...
# http://dbpedia.org/resource/Thomas_Reilly                    Thomas F. Reilly
# http://dbpedia.org/resource/Todd_McKenney_(poli...              Todd McKenney
# http://dbpedia.org/resource/Yaël_Braun-Pivet                 Yaël Braun-Pivet
# http://dbpedia.org/resource/Medard_Kalemani         Dr. Medard M. C. Kalemani
# http://dbpedia.org/resource/Melanie_George_Smith         Melanie George Smith
#
#                                                    birthDate_dbp  \
# uri_dbp
# http://dbpedia.org/resource/António_de_Almeida_...    1926-02-15
# http://dbpedia.org/resource/Carlos_Carvalhas          1941-11-09
# http://dbpedia.org/resource/Anita_Augspurg            1857-09-22
# http://dbpedia.org/resource/Mason_Gaffney             1923-10-18
# http://dbpedia.org/resource/Paulo_Portas              1962-09-12
# ...                                                          ...
# http://dbpedia.org/resource/Thomas_Reilly             1942-02-14
# http://dbpedia.org/resource/Todd_McKenney_(poli...    1963-10-11
# http://dbpedia.org/resource/Yaël_Braun-Pivet          1970-12-07
# http://dbpedia.org/resource/Medard_Kalemani           1968-03-15
# http://dbpedia.org/resource/Melanie_George_Smith      1972-11-07
#
#                                                    deathDate_dbp  \
# uri_dbp
# http://dbpedia.org/resource/António_de_Almeida_...    2016-01-18
# http://dbpedia.org/resource/Carlos_Carvalhas
# http://dbpedia.org/resource/Anita_Augspurg            1943-12-20
# http://dbpedia.org/resource/Mason_Gaffney             2020-07-16
# http://dbpedia.org/resource/Paulo_Portas
# ...                                                          ...
# http://dbpedia.org/resource/Thomas_Reilly
# http://dbpedia.org/resource/Todd_McKenney_(poli...
# http://dbpedia.org/resource/Yaël_Braun-Pivet
# http://dbpedia.org/resource/Medard_Kalemani
# http://dbpedia.org/resource/Melanie_George_Smith
#
#                                                               placeOfBirth_dbp  \
# uri_dbp
# http://dbpedia.org/resource/António_de_Almeida_...
# http://dbpedia.org/resource/Carlos_Carvalhas        São Pedro do Sul, Portugal
# http://dbpedia.org/resource/Anita_Augspurg
# http://dbpedia.org/resource/Mason_Gaffney
# http://dbpedia.org/resource/Paulo_Portas                                Lisbon
# ...                                                                        ...
# http://dbpedia.org/resource/Thomas_Reilly           Springfield, Massachusetts
# http://dbpedia.org/resource/Todd_McKenney_(poli...                 Akron, Ohio
# http://dbpedia.org/resource/Yaël_Braun-Pivet                     Nancy, France
# http://dbpedia.org/resource/Medard_Kalemani
# http://dbpedia.org/resource/Melanie_George_Smith
#
#                                                    placeOfDeath_dbp
# uri_dbp
# http://dbpedia.org/resource/António_de_Almeida_...
# http://dbpedia.org/resource/Carlos_Carvalhas
# http://dbpedia.org/resource/Anita_Augspurg
# http://dbpedia.org/resource/Mason_Gaffney
# http://dbpedia.org/resource/Paulo_Portas
# ...                                                             ...
# http://dbpedia.org/resource/Thomas_Reilly
# http://dbpedia.org/resource/Todd_McKenney_(poli...
# http://dbpedia.org/resource/Yaël_Braun-Pivet
# http://dbpedia.org/resource/Medard_Kalemani
# http://dbpedia.org/resource/Melanie_George_Smith
#
# [15559 rows x 6 columns]

# %%
#count the number of similar URIs
gb_dbp=df_dbp.groupby(['uri_dbp']).size()
print(gb_dbp)
# Out:
# uri_dbp
# http://dbpedia.org/resource/A._Arthur_Giddon     1
# http://dbpedia.org/resource/A._Brown_Moore       3
# http://dbpedia.org/resource/A._Bruce_Bielaski    1
# http://dbpedia.org/resource/A._C._Gibbs          1
# http://dbpedia.org/resource/A._D._Roy            1
#                                                 ..
# http://dbpedia.org/resource/Şirin_Tekeli         1
# http://dbpedia.org/resource/Štefan_Osuský        1
# http://dbpedia.org/resource/Štefan_Tiso          1
# http://dbpedia.org/resource/Željko_Komšić        3
# http://dbpedia.org/resource/Željko_Rohatinski    3
# Length: 8575, dtype: int64

# %%
# count the number of similar URIs greater than one
sort_dbp=gb_dbp.sort_values(ascending=False) > 1
sum(sort_dbp)
# Out:
# 3391

# %% [markdown]
# ### Wikidata

# %%
df_wk= pd.DataFrame(r_wk, columns=['uri_wk', 'name_wk', 'birthDate_wk', "deathDate_wk", "placeOfBirth_wk", "placeOfDeath_wk",'viaf_wk', "uri_bnf_wk"])
print(len(df_wk))
df_wk.fillna('')
df_wk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-871b65c79e96> in <module>
# ----> 1 df_wk= pd.DataFrame(r_wk, columns=['uri_wk', 'name_wk', 'birthDate_wk', "deathDate_wk", "placeOfBirth_wk", "placeOfDeath_wk",'viaf_wk', "uri_bnf_wk"])
#       2 print(len(df_wk))
#       3 df_wk.fillna('')
#       4 df_wk
#
# NameError: name 'pd' is not defined

# %%
df_wk.set_index('uri_wk')
# Out:
#                                                                name_wk  \
# uri_wk
# http://www.wikidata.org/entity/Q72568              Alfred Lichtenstein
# http://www.wikidata.org/entity/Q72553               Heinrich von Bülow
# http://www.wikidata.org/entity/Q72628     Alfred von Kiderlen-Waechter
# http://www.wikidata.org/entity/Q72535                      Rainer Rupp
# http://www.wikidata.org/entity/Q77404               Ingeborg Schwenzer
# ...                                                                ...
# http://www.wikidata.org/entity/Q96449608
# http://www.wikidata.org/entity/Q85322288
# http://www.wikidata.org/entity/Q85884950
# http://www.wikidata.org/entity/Q92295431
# http://www.wikidata.org/entity/Q96032574
#
#                                                   birthDate_wk  \
# uri_wk
# http://www.wikidata.org/entity/Q72568     1889-08-23T00:00:00Z
# http://www.wikidata.org/entity/Q72553     1792-09-16T00:00:00Z
# http://www.wikidata.org/entity/Q72628     1852-07-10T00:00:00Z
# http://www.wikidata.org/entity/Q72535     1945-09-21T00:00:00Z
# http://www.wikidata.org/entity/Q77404     1951-10-25T00:00:00Z
# ...                                                        ...
# http://www.wikidata.org/entity/Q96449608  1942-03-21T00:00:00Z
# http://www.wikidata.org/entity/Q85322288  1977-10-09T00:00:00Z
# http://www.wikidata.org/entity/Q85884950  1923-01-01T00:00:00Z
# http://www.wikidata.org/entity/Q92295431  1876-12-01T00:00:00Z
# http://www.wikidata.org/entity/Q96032574  1871-07-29T00:00:00Z
#
#                                                   deathDate_wk  \
# uri_wk
# http://www.wikidata.org/entity/Q72568     1914-09-25T00:00:00Z
# http://www.wikidata.org/entity/Q72553     1846-02-06T00:00:00Z
# http://www.wikidata.org/entity/Q72628     1912-12-30T00:00:00Z
# http://www.wikidata.org/entity/Q72535
# http://www.wikidata.org/entity/Q77404
# ...                                                        ...
# http://www.wikidata.org/entity/Q96449608
# http://www.wikidata.org/entity/Q85322288
# http://www.wikidata.org/entity/Q85884950
# http://www.wikidata.org/entity/Q92295431  1967-04-10T00:00:00Z
# http://www.wikidata.org/entity/Q96032574  1930-10-13T00:00:00Z
#
#                                            placeOfBirth_wk placeOfDeath_wk  \
# uri_wk
# http://www.wikidata.org/entity/Q72568               Berlin           Somme
# http://www.wikidata.org/entity/Q72553             Schwerin          Berlin
# http://www.wikidata.org/entity/Q72628            Stuttgart       Stuttgart
# http://www.wikidata.org/entity/Q72535            Saarlouis
# http://www.wikidata.org/entity/Q77404            Stuttgart
# ...                                                    ...             ...
# http://www.wikidata.org/entity/Q96449608            Hebron
# http://www.wikidata.org/entity/Q85322288           Pryluky
# http://www.wikidata.org/entity/Q85884950
# http://www.wikidata.org/entity/Q92295431  Saint Petersburg         Kharkiv
# http://www.wikidata.org/entity/Q96032574         Szelevény        Budapest
#
#                                                                 viaf_wk  \
# uri_wk
# http://www.wikidata.org/entity/Q72568     http://viaf.org/viaf/71423827
# http://www.wikidata.org/entity/Q72553     http://viaf.org/viaf/62342475
# http://www.wikidata.org/entity/Q72628     http://viaf.org/viaf/54958174
# http://www.wikidata.org/entity/Q72535     http://viaf.org/viaf/15698197
# http://www.wikidata.org/entity/Q77404     http://viaf.org/viaf/91748910
# ...                                                                 ...
# http://www.wikidata.org/entity/Q96449608
# http://www.wikidata.org/entity/Q85322288
# http://www.wikidata.org/entity/Q85884950
# http://www.wikidata.org/entity/Q92295431
# http://www.wikidata.org/entity/Q96032574
#
#                                                                                uri_bnf_wk
# uri_wk
# http://www.wikidata.org/entity/Q72568     http://data.bnf.fr/ark:/12148/cb12123568r#about
# http://www.wikidata.org/entity/Q72553
# http://www.wikidata.org/entity/Q72628     http://data.bnf.fr/ark:/12148/cb135097503#about
# http://www.wikidata.org/entity/Q72535
# http://www.wikidata.org/entity/Q77404     http://data.bnf.fr/ark:/12148/cb15067859n#about
# ...                                                                                   ...
# http://www.wikidata.org/entity/Q96449608
# http://www.wikidata.org/entity/Q85322288
# http://www.wikidata.org/entity/Q85884950
# http://www.wikidata.org/entity/Q92295431
# http://www.wikidata.org/entity/Q96032574
#
# [56524 rows x 7 columns]

# %%
# We drop 'T00:00:00Z' to have the format 'YYYY-MM-DD' and improve the merge below.
df_wk["birthDate_wk"] = df_wk["birthDate_wk"].str.replace("T00:00:00Z", "")
df_wk["deathDate_wk"] = df_wk["deathDate_wk"].str.replace("T00:00:00Z", "")

#print(df_wk)

# %%
#count the number of similar URIs
gb_wk=df_wk.groupby(['uri_wk']).size()
print(gb_wk)
# Out:
# uri_wk
# http://www.wikidata.org/entity/Q1000023     1
# http://www.wikidata.org/entity/Q1000061     1
# http://www.wikidata.org/entity/Q1000228     1
# http://www.wikidata.org/entity/Q1000324     1
# http://www.wikidata.org/entity/Q1000392     1
#                                            ..
# http://www.wikidata.org/entity/Q999600      1
# http://www.wikidata.org/entity/Q99968375    1
# http://www.wikidata.org/entity/Q99980497    1
# http://www.wikidata.org/entity/Q999844      1
# http://www.wikidata.org/entity/Q999985      1
# Length: 53361, dtype: int64

# %%
# count the number of similar URIs greater than one
sort_wk=gb_wk.sort_values(ascending=False) > 1
sum(sort_wk)
# Out:
# 2114

# %%
# Drop duplicates lines and keep first
#df_wk.drop_duplicates(subset ='uri_wk', keep = 'first', inplace=True)
#df_wk.fillna('')
#print(len(df_wk))
#df_wk.head()

# %%
# We use the dataframes in csv to don't run again requests
df_bnf.to_csv("df_bnf.csv")
df_dbp.to_csv("df_dbp.csv")

# %%
BnF_Data = pd.read_csv('df_bnf.csv')
Wikidata = pd.read_csv('df_wk.csv')
DBpedia = pd.read_csv('df_dbp.csv')

# %% [markdown]
# # Merge

# %% [markdown]
# ## 1- Between Wikidata and BnF Data

# %% [markdown]
# First, we realize a merge between Wikidata and BnF Data using the BnF URIs in common.

# %%
merged_bnf_wk = pd.merge(df_bnf, df_wk , on='uri_bnf', how='inner', sort='uri_bnf')
print("")
print("This method merge", len(merged_bnf_wk), "mentions.")
print("")
merged_bnf_wk[:10]
merged_bnf_wk.loc[:,"uri_bnf","name_bnf","via_bnf","birthDate_bnf","deathDate_bnf","placeOfBirth_bnf","placeOfDeath_bnf","bio_bnf","uri_wk","name_wk","via_wk","birthDate_wk","deathDate_wk","placeOfBirth_wk","placeOfDeath_wk"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-491-d10ec1abba95> in <module>
#       1 # First, we realize a merge between Wikidata and BnF Data using the BnF URIs in common.
# ----> 2 merged_bnf_wk = pd.merge(df_bnf, df_wk , on='uri_bnf', how='inner', sort='uri_bnf')
#       3 print("")
#       4 print("This method merge", len(merged_bnf_wk), "mentions.")
#       5 print("")
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1044                         right_keys.append(rk)
#    1045                     if lk is not None:
# -> 1046                         left_keys.append(left._get_label_or_level_values(lk))
#    1047                         join_names.append(lk)
#    1048                     else:
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'uri_bnf'

# %%
df_bnf[df_bnf.uri_bnf.isin(df_dbp.uri_bnf)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-476-d70fafff2fe5> in <module>
# ----> 1 df_bnf[df_bnf.uri_bnf.isin(df_dbp.uri_bnf)]
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'uri_bnf'

# %%
frames =[df_bnf, df_wk]
result = pd.concat(frames, keys=["x", "y"])
result
# Out:
#                                                      uri                 name  \
# x 0      http://data.bnf.fr/ark:/12148/cb12981404c#about         Léon Garnier
#   1      http://data.bnf.fr/ark:/12148/cb13484444m#about  Gaston de Pawlowski
#   2      http://data.bnf.fr/ark:/12148/cb134841632#about   Jean-Michel Berton
#   3      http://data.bnf.fr/ark:/12148/cb13379520q#about     Emmanuel Mathieu
#   4      http://data.bnf.fr/ark:/12148/cb13338312g#about  Josiah Henry Benton
# ...                                                  ...                  ...
# y 56519         http://www.wikidata.org/entity/Q96449608
#   56520         http://www.wikidata.org/entity/Q85322288
#   56521         http://www.wikidata.org/entity/Q85884950
#   56522         http://www.wikidata.org/entity/Q92295431
#   56523         http://www.wikidata.org/entity/Q96032574
#
#                                   viaf   birthDate   deathDate  \
# x 0      http://viaf.org/viaf/99996033  1836-11-10  1901-05-06
#   1       http://viaf.org/viaf/9999219  1874-06-14  1933-02-02
#   2       http://viaf.org/viaf/9999131  1794-07-03  1845-10-20
#   3       http://viaf.org/viaf/9995247  1852-07-19        19..
#   4       http://viaf.org/viaf/9994322        1843        1917
# ...                                ...         ...         ...
# y 56519                                 1942-03-21
#   56520                                 1977-10-09
#   56521                                 1923-01-01
#   56522                                 1876-12-01  1967-04-10
#   56523                                 1871-07-29  1930-10-13
#
#              placeOfBirth placeOfDeath  \
# x 0
#   1        Joigny (Yonne)        Paris
#   2          Cahors (Lot)
#   3
#   4
# ...                   ...          ...
# y 56519            Hebron
#   56520           Pryluky
#   56521
#   56522  Saint Petersburg      Kharkiv
#   56523         Szelevény     Budapest
#
#                                                        bio uri_bnf
# x 0      Juriste. - Administrateur et homme de lettres....     NaN
#   1      Docteur en droit. - Critique littéraire et thé...     NaN
#   2      Écrivain politique, avocat à la Cour de cassat...     NaN
#   3                         Docteur en droit (Paris, 1873)     NaN
#   4                                 Juriste. - Bibliophile     NaN
# ...                                                    ...     ...
# y 56519                                                NaN
#   56520                                                NaN
#   56521                                                NaN
#   56522                                                NaN
#   56523                                                NaN
#
# [67656 rows x 9 columns]

# %%
# Create an id to Bnf Data dataframe
# We felt it was necessary to create new id to realise the comparaisons between dataframes (cf. below for understand).
df_bnf["id_bnf"] = df_bnf.index + 0
df_bnf= pd.DataFrame(df_bnf, columns=['uri_bnf', 'viaf_bnf', 'name_bnf', 'Sname','birthDate_bnf','deathDate_bnf' , 'placeOfBirth_bnf','placeOfDeath_bnf','bio_bnf'],index=df_bnf["id_bnf"])
df_bnf[-20:]

# %%
# Create an id to DBpedia dataframe
df_dbp["id_dbp"] = df_dbp.index + 0
df_dbp= pd.DataFrame(df_dbp, columns=['uri_dbp', 'viaf_dbp', 'name_dbp','birthDate_dbp','deathDate_dbp' , 'placeOfBirth_dbp','placeOfDeath_dbp'],index=df_dbp["id_dbp"])
print(len(df_dbp))
df_dbp[-20:]
# Out:
# 10000
#                                                   uri_dbp viaf_dbp  \
# id_dbp
# 9980            http://dbpedia.org/resource/Terry_Haskins
# 9981      http://dbpedia.org/resource/Bernard_M._L._Ernst
# 9982                http://dbpedia.org/resource/Miha_Krek
# 9983             http://dbpedia.org/resource/Leon_Despres
# 9984    http://dbpedia.org/resource/Benito_Pabón_y_Suá...
# 9985    http://dbpedia.org/resource/John_McCarthy_(Aus...
# 9986    http://dbpedia.org/resource/John_McCarthy_(Aus...
# 9987       http://dbpedia.org/resource/Dominique_Warluzel
# 9988            http://dbpedia.org/resource/Hauwa_Ibrahim
# 9989         http://dbpedia.org/resource/Beatriz_Corredor
# 9990         http://dbpedia.org/resource/Beatriz_Corredor
# 9991             http://dbpedia.org/resource/Beau_Correll
# 9992             http://dbpedia.org/resource/Bekir_Bozdağ
# 9993             http://dbpedia.org/resource/Bekir_Bozdağ
# 9994             http://dbpedia.org/resource/Bekir_Bozdağ
# 9995        http://dbpedia.org/resource/Bernard_Cazeneuve
# 9996        http://dbpedia.org/resource/Bernard_Cazeneuve
# 9997              http://dbpedia.org/resource/Betty_Korir
# 9998    http://dbpedia.org/resource/Bikash_Ranjan_Bhat...
# 9999    http://dbpedia.org/resource/Bikash_Ranjan_Bhat...
#
#                                name_dbp birthDate_dbp deathDate_dbp  \
# id_dbp
# 9980                                       1955-01-31    2000-10-24
# 9981                Bernard M. L. Ernst    1879-03-17       --11-28
# 9982                          Miha Krek    1897-09-28    1969-11-18
# 9983                                       1908-02-02    2009-05-06
# 9984    Benito Pabón y Suárez de Urbina    1895-03-25
# 9985                      John McCarthy    1942-11-29
# 9986                      John McCarthy    1942-11-29
# 9987                 Dominique Warluzel    1957-05-29
# 9988                      Hauwa Ibrahim    1968-01-20
# 9989                   Beatriz Corredor    1968-07-01
# 9990                   Beatriz Corredor    1968-07-01
# 9991                       Beau Correll    1982-07-20
# 9992                       Bekir Bozdağ    1965-04-01
# 9993                       Bekir Bozdağ    1965-04-01
# 9994                       Bekir Bozdağ    1965-04-01
# 9995                  Bernard Cazeneuve    1963-06-02
# 9996                  Bernard Cazeneuve    1963-06-02
# 9997                        Betty Korir    1977-07-01
# 9998         Bikash Ranjan Bhattacharya    1951-11-27
# 9999             বিকাশ রঞ্জন ভট্টাচার্য    1951-11-27
#
#                  placeOfBirth_dbp placeOfDeath_dbp
# id_dbp
# 9980
# 9981
# 9982
# 9983
# 9984                      Seville    Colón, Panama
# 9985                United States
# 9986             Washington, D.C.
# 9987    Pau, Pyrénées-Atlantiques
# 9988                 Gombe, Gombe
# 9989                       Madrid
# 9990                        Spain
# 9991
# 9992                  Akdağmadeni
# 9993                       Turkey
# 9994              Yozgat Province
# 9995                       France
# 9996                       Senlis
# 9997                        Kenya
# 9998                      Kolkata
# 9999                      Kolkata

# %% [markdown]
#  ## Recordlinkage

# %%
import recordlinkage

# %% [markdown]
# To have more details and settings, you can read the documentation of the library: https://recordlinkage.readthedocs.io/en/latest/about.html .
#
# And this article, https://pbpython.com/record-linking.html, explains how the library works and compare this method with a another, Fuzzymatcher. Unfortunalty, he doesn't explain how he does after comparing to merge the two dataframes.

# %% [markdown]
# ### Dataframe of DBpedia with itself

# %%
# This first step is essential because it indexes the dataframes (or a dataframe with itself) to then compare them 
# Here, we choose the method 'sortedneighbourhood' for this speed of execution and the number of indexed values
# We use the dataframe with itself to spot duplicates who don't have the same URI.
indexer = recordlinkage.Index()
indexer.sortedneighbourhood(left_on='name_dbp')
candidates = indexer.index(df_dbpc)
print(len(candidates))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-9235433b4b67> in <module>
#       4 indexer = recordlinkage.Index()
#       5 indexer.sortedneighbourhood(left_on='name_dbp')
# ----> 6 candidates = indexer.index(df_dbpc)
#       7 print(len(candidates))
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/recordlinkage/base.py in index(self, x, x_link)
#     122         pairs = None
#     123         for cl_alg in self.algorithms:
# --> 124             pairs_i = cl_alg.index(x, x_link)
#     125
#     126             if pairs is None:
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/recordlinkage/base.py in index(self, x, x_link)
#     338
#     339             for df in x:
# --> 340                 self._verify_integrety(df)
#     341
#     342         # linking
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/recordlinkage/base.py in _verify_integrety(self, x)
#     235
#     236             if not x.index.is_unique:
# --> 237                 raise ValueError('index of DataFrame is not unique')
#     238
#     239         elif isinstance(x.index, pandas.MultiIndex):
#
# ValueError: index of DataFrame is not unique

# %%
# The step is the most important, we compare the values of the variables with the other values of the same variable.
# We choose to compare the variable 'birthDate', 'deathDate' because it is a strict format.
# Also, we add 'name' to match date variables and check more easily.
# Finally, the "uri" variable to check if the other variables match a "uri".
compare = recordlinkage.Compare()
compare.exact('birthDate_dbp',
            'birthDate_dbp',
            label='birthDate_dbp')
compare.exact('deathDate_dbp',
            'deathDate_dbp',
            label='deathDate_dbp')
compare.string('name_dbp',
            'name_dbp',
            label='name_dbp')
compare.exact('uri_dbp',
            'uri_dbp',
            label='uri_dbp')
features = compare.compute(candidates, df_dbp)

# %%
# display scores for matchings
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 4.000000    12076
# 3.986667        1
# 3.966667       16
# 3.950000        9
# 3.923077       36
#             ...
# 0.052632        1
# 0.045455        4
# 0.037037        3
# 0.030303       12
# 0.000000      336
# Length: 421, dtype: int64

# %%
# display scores for matchings only if they are superior to '1.9'
potential_matches = features[features.sum(axis=1) >1.9].reset_index()

# %%
# Dataframes of scores of each variables with the cumulative score
# It displays only the score inferior to '1' (it means no matches between both URIs)
potential_matches['Score'] = potential_matches.loc[:, 'birthDate_dbp':'uri_dbp'].sum(axis=1)
rslt_df = potential_matches[potential_matches['uri_dbp'] < 1]
rslt_df
# It seems none person doesn't have many mentions 
# because if we compare the three first variables with the 'uri' (with a score superior at '2'), no result arises.
# Out:
#       level_0  level_1  birthDate_dbp  deathDate_dbp  name_dbp  uri_dbp  \
# 61       5984     2326              0              1  0.909091        0
# 62       5984     2327              0              1  0.909091        0
# 2922     1842     1754              0              1  1.000000        0
# 2923     3467     1754              0              1  1.000000        0
# 2924     3467     1842              0              1  1.000000        0
# 2925     3831     1754              0              1  1.000000        0
# 2926     3831     1842              0              1  1.000000        0
# 2927     3831     3467              0              1  1.000000        0
#
#          Score
# 61    1.909091
# 62    1.909091
# 2922  2.000000
# 2923  2.000000
# 2924  2.000000
# 2925  2.000000
# 2926  2.000000
# 2927  2.000000

# %%
df_dbp.loc[7750,:]
# Out:
# uri_dbp             http://dbpedia.org/resource/Luís_Marques_Mendes
# viaf_dbp
# name_dbp                                        Luís Marques Mendes
# birthDate_dbp                                            1957-11-05
# deathDate_dbp
# placeOfBirth_dbp                                           Portugal
# placeOfDeath_dbp
# nationality_dbp
# Name: 7750, dtype: object

# %%
df_dbp.loc[7748,:]
# Out:
# uri_dbp             http://dbpedia.org/resource/Luís_Marques_Guedes
# viaf_dbp
# name_dbp                                        Luís Marques Guedes
# birthDate_dbp                                            1957-08-25
# deathDate_dbp
# placeOfBirth_dbp                                           Portugal
# placeOfDeath_dbp
# nationality_dbp
# Name: 7748, dtype: object

# %%
### !!!!! It doesn't works for the moment !!!!! ###


#df_dbp['dbp1_Name_Lookup'] = df_dbp[[
#   'name_dbp', 'birthDate_dbp','deathDate_dbp','placeOfBirth_dbp' ,'placeOfDeath_dbp' 
#]].apply(lambda x: '|'.join(x), axis=1)
#
#df_dbp['dbp2_Name_Lookup'] = df_dbp[[
#  'name_dbp', 'birthDate_dbp','deathDate_dbp','placeOfBirth_dbp' ,'placeOfDeath_dbp' 
#]].apply(lambda x: '|'.join(x), axis=1)

#df_dbp = df_dbp[['dbp1_Name_Lookup']].reset_index()
#df_dbp = df_dbp[['dbp2_Name_Lookup']].reset_index()

# %% [markdown]
# ### Dataframe of Wikidata with itself

# %%
# Create an id to Wikidata dataframe
df_wk["id_wk"] = df_wk.index + 0
df_wk= pd.DataFrame(df_wk, columns=['uri_wk', 'viaf_wk', 'name_wk','birthDate_wk','deathDate_wk' , 'placeOfBirth_wk','placeOfDeath_wk'],index=df_wk["id_wk"])
print(len(df_wk))
df_dbp[-20:]
# Out:
# 56524
#                                                uri_dbp viaf_dbp  \
# 9980     http://dbpedia.org/resource/Bautista_Saavedra
# 9981     http://dbpedia.org/resource/Bautista_Saavedra
# 9982     http://dbpedia.org/resource/Bautista_Saavedra
# 9983    http://dbpedia.org/resource/Belisario_Betancur
# 9984         http://dbpedia.org/resource/Benito_Juárez
# 9985         http://dbpedia.org/resource/Benito_Juárez
# 9986         http://dbpedia.org/resource/Benito_Juárez
# 9987         http://dbpedia.org/resource/Benito_Juárez
# 9988         http://dbpedia.org/resource/Benito_Juárez
# 9989         http://dbpedia.org/resource/Benito_Juárez
# 9990  http://dbpedia.org/resource/Benjamin_Ogle_Tayloe
# 9991  http://dbpedia.org/resource/Benjamin_Ogle_Tayloe
# 9992        http://dbpedia.org/resource/Benjamin_Swift
# 9993        http://dbpedia.org/resource/Benjamin_Swift
# 9994        http://dbpedia.org/resource/Benjamin_Swift
# 9995        http://dbpedia.org/resource/Benjamin_Swift
# 9996     http://dbpedia.org/resource/Benjamin_V._Cohen
# 9997      http://dbpedia.org/resource/Benjamín_Zeledón
# 9998     http://dbpedia.org/resource/Bernard_Bernstein
# 9999        http://dbpedia.org/resource/Bernard_Bosson
#
#                           name_dbp birthDate_dbp deathDate_dbp  \
# 9980             Bautista Saavedra    1870-08-30    1939-05-01
# 9981             Bautista Saavedra    1870-08-30    1939-05-01
# 9982             Bautista Saavedra    1870-08-30    1939-05-01
# 9983    Belisario Betancur Cuartas    1923-02-04    2018-12-07
# 9984                 Benito Juárez    1806-03-21    1872-07-18
# 9985                 Benito Juárez    1806-03-21    1872-07-18
# 9986                 Benito Juárez    1806-03-21    1872-07-18
# 9987                 Benito Juárez    1806-03-21    1872-07-18
# 9988                 Benito Juárez    1806-03-21    1872-07-18
# 9989                 Benito Juárez    1806-03-21    1872-07-18
# 9990        Benjamin "Ogle" Tayloe    1796-05-21    1868-02-25
# 9991        Benjamin "Ogle" Tayloe    1796-05-21    1868-02-25
# 9992                Benjamin Swift    1781-04-03    1847-11-11
# 9993                Benjamin Swift    1781-04-03    1847-11-11
# 9994                Benjamin Swift    1781-04-03    1847-11-11
# 9995                Benjamin Swift    1781-04-03    1847-11-11
# 9996             Benjamin V. Cohen    1894-09-23    1983-08-15
# 9997  Benjamín Francisco Alexander    1879-10-04    1912-10-04
# 9998             Bernard Bernstein    1908-11-30    1990-02-06
# 9999                Bernard Bosson    1948-02-25    2017-05-13
#
#                  placeOfBirth_dbp            placeOfDeath_dbp  \
# 9980                      Bolivia                    Santiago
# 9981                       Sorata                    Santiago
# 9982  La Paz Department (Bolivia)                    Santiago
# 9983
# 9984                       Oaxaca                      Mexico
# 9985           San Pablo Guelatao                      Mexico
# 9986                    New Spain                      Mexico
# 9987                       Oaxaca                 Mexico City
# 9988           San Pablo Guelatao                 Mexico City
# 9989                    New Spain                 Mexico City
# 9990                                                    Italy
# 9991                                                     Rome
# 9992                United States               United States
# 9993      Amenia (town), New York               United States
# 9994                United States  St. Albans (town), Vermont
# 9995      Amenia (town), New York  St. Albans (town), Vermont
# 9996              Muncie, Indiana            Washington, D.C.
# 9997
# 9998                New York City               New York City
# 9999                       France
#
#               nationality_dbp
# 9980                Bolivians
# 9981                Bolivians
# 9982                Bolivians
# 9983
# 9984  Mexican nationality law
# 9985  Mexican nationality law
# 9986  Mexican nationality law
# 9987  Mexican nationality law
# 9988  Mexican nationality law
# 9989  Mexican nationality law
# 9990
# 9991
# 9992
# 9993
# 9994
# 9995
# 9996            United States
# 9997
# 9998            United States
# 9999                   France

# %%
indexer = recordlinkage.Index()
indexer.sortedneighbourhood(left_on='name_wk')
candidates = indexer.index(df_wk)
print(len(candidates))
# Out:
# 3677385

# %%
compare = recordlinkage.Compare()
compare.exact('birthDate_wk',
            'birthDate_wk',
            label='birthDate_wk')
compare.exact('deathDate_wk',
            'deathDate_wk',
            label='deathDate_wk')
compare.string('name_wk',
            'name_wk',
            label='name_wk')
compare.exact('uri_wk',
            'uri_wk',
            label='uri_wk')
features = compare.compute(candidates, df_wk)

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 4.000000       1286
# 3.000000       3103
# 2.956522          1
# 2.954545          1
# 2.947368          1
#              ...
# 0.058824          3
# 0.055556          1
# 0.052632          2
# 0.047619          1
# 0.000000    2513444
# Length: 783, dtype: int64

# %%
potential_matches = features[features.sum(axis=1) >=2.9].reset_index()

# %%
potential_matches['Score'] = potential_matches.loc[:, 'birthDate_wk':'uri_wk'].sum(axis=1)
rslt_df = potential_matches[potential_matches['uri_wk'] < 1]
print(len(rslt_df),"mentions of the same persons don't have the same URI.")
print("")
rslt_df.sort_values(by='Score')
# Out:
# 12 mentions of the same persons don't have the same URI.
#       id_wk_1  id_wk_2  birthDate_wk  deathDate_wk   name_wk  uri_wk     Score
# 4393    45716    25511             1             1  0.900000       0  2.900000
# 2       44371    42312             1             1  0.931034       0  2.931034
# 1       44369    42300             1             1  0.933333       0  2.933333
# 3       53177    46361             1             1  0.941176       0  2.941176
# 4395    52254    48210             1             1  0.947368       0  2.947368
# 4394    51804    44349             1             1  0.954545       0  2.954545
# 0       19619    19618             1             1  0.956522       0  2.956522
# 1872    37257    18254             1             1  1.000000       0  3.000000
# 1984    37921    20048             1             1  1.000000       0  3.000000
# 2236    23067    23063             1             1  1.000000       0  3.000000
# 3405    43371    43370             1             1  1.000000       0  3.000000
# 3719    42291    42081             1             1  1.000000       0  3.000000

# %% [markdown]
# We find twelve mentions of people who don't have the same URI.
#
# To check, we displays two lines below corresponding to the same person but with a different URI.

# %%
df_wk.loc[45716,:]
# Out:
# uri_wk             http://www.wikidata.org/entity/Q94808707
# viaf_wk                       http://viaf.org/viaf/17974557
# name_wk                                Konstantinos Rhalles
# birthDate_wk                                     1867-01-01
# deathDate_wk                                     1942-01-01
# placeOfBirth_wk
# placeOfDeath_wk
# Name: 45716, dtype: object

# %%
df_wk.loc[25511,:]
# Out:
# uri_wk             http://www.wikidata.org/entity/Q12879698
# viaf_wk                       http://viaf.org/viaf/64413539
# name_wk                                 Konstantinos Rallis
# birthDate_wk                                     1867-01-01
# deathDate_wk                                     1942-01-01
# placeOfBirth_wk                                      Athens
# placeOfDeath_wk                                      Athens
# Name: 25511, dtype: object

# %% [markdown]
# ### Dataframe of BnF Data with itself

# %%
indexer = recordlinkage.Index()
indexer.sortedneighbourhood(left_on='name_bnf')
candidates = indexer.index(df_bnf)
print(len(candidates))
# Out:
# 13011

# %%
compare = recordlinkage.Compare()
compare.exact('birthDate_bnf',
            'birthDate_bnf',
            label='birthDate_bnf')
compare.exact('deathDate_bnf',
            'deathDate_bnf',
            label='deathDate_bnf')
compare.string('name_bnf',
            'name_bnf',
            label='name_bnf')
compare.exact('uri_bnf',
            'uri_bnf',
            label='uri_bnf')
features = compare.compute(candidates, df_bnf)

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 4.000000      92
# 3.000000       4
# 2.950000       1
# 2.944444       1
# 2.928571       1
#             ...
# 0.066667       3
# 0.062500       1
# 0.058824       2
# 0.050000       1
# 0.000000    1595
# Length: 395, dtype: int64

# %%
potential_matches = features[features.sum(axis=1) >=2.8].reset_index()

# %%
potential_matches['Score'] = potential_matches.loc[:, 'birthDate_bnf':'deathDate_bnf'].sum(axis=1)
rslt_df = potential_matches[potential_matches['uri_bnf'] < 1]
print(len(rslt_df),"mentions of the same persons don't have the same URI.")
rslt_df.sort_values(by='name_bnf')
# Out:
# 8 mentions of the same persons don't have the same URI.
#      level_0  level_1  birthDate_bnf  deathDate_bnf  name_bnf  uri_bnf  Score
# 2       7900     4417              1              1  0.800000        0      2
# 99      3606     2288              1              1  0.882353        0      2
# 0       4876     1693              1              1  0.928571        0      2
# 1       4909     2744              1              1  0.944444        0      2
# 100    10626     1741              1              1  0.950000        0      2
# 15     10954     1166              1              1  1.000000        0      2
# 35     10232     3140              1              1  1.000000        0      2
# 83     11079     8022              1              1  1.000000        0      2

# %% [markdown]
# We find eight mentions of people who don't have the same URI.
#
# To check, we displays two lines below corresponding to the same person but with a different URI (this is an exemple).

# %%
df_bnf.loc[1741,:]
# Out:
# uri_bnf             http://data.bnf.fr/ark:/12148/cb149780599#about
# name_bnf                                       Eugenio Montero Rios
# viaf_bnf                              http://viaf.org/viaf/66720534
# birthDate_bnf                                            1832-11-13
# deathDate_bnf                                            1914-05-12
# placeOfBirth_bnf
# placeOfDeath_bnf
# bio_bnf                                  Homme politique et juriste
# Name: 1741, dtype: object

# %%
df_bnf.loc[10626,:]
# Out:
# uri_bnf             http://data.bnf.fr/ark:/12148/cb14623832q#about
# name_bnf                                       Eugenio Montero Ríos
# viaf_bnf
# birthDate_bnf                                            1832-11-13
# deathDate_bnf                                            1914-05-12
# placeOfBirth_bnf
# placeOfDeath_bnf
# bio_bnf                                  Homme politique. - Juriste
# Name: 10626, dtype: object

# %%
df_bnf_merge = potential_matches.merge(df_bnf, how='left')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-341-030e7f1cb713> in <module>
# ----> 1 df_bnf_merge = pd.concat(potential_matches, df_bnf)
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     293         verify_integrity=verify_integrity,
#     294         copy=copy,
# --> 295         sort=sort,
#     296     )
#     297
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     320             raise TypeError(
# --> 321                 "first argument must be an iterable of pandas "
#     322                 f'objects, you passed an object of type "{type(objs).__name__}"'
#     323             )
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %% [markdown]
# --------------------
# ## Matched between BnF Data and Wikidata

# %% [markdown]
# After performing it between a dataframe and itself, we can realise the same thing between two dataframes.
#
# With this method, we can find out if the same person records are found in two different databases.

# %%
indexer = recordlinkage.Index()
indexer.sortedneighbourhood(left_on='name_bnf', right_on='name_wk')
candidates = indexer.index(df_bnf, df_wk)
print(len(candidates))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-212-0a6a61cb9210> in <module>
#       1 indexer = recordlinkage.Index()
#       2 indexer.sortedneighbourhood(left_on='name_bnf', right_on='name_wk')
# ----> 3 candidates = indexer.index(df_bnf, df_wk)
#       4 print(len(candidates))
#
# NameError: name 'df_wk' is not defined

# %% [markdown]
# indexer = recordlinkage.Index()
# indexer.block(left_on=['name_bnf', 'uri_bnf'],
#               right_on=['name_dbp', 'uri_dbp'])
# pairs = indexer.index(df_bnf, df_dbp)

# %% [markdown]
# candidates = indexer.index(BnF_Data, DBpedia)
# print(len(candidates))

# %%
# We choose the compare the 'name', the 'birthDate' and deathDate' for the same reasons mentioned above
compare = recordlinkage.Compare()
compare.string('name_bnf',
            'name_wk',
            method='jarowinkler',
            threshold=0.85,
            label='name_bnf_wk')
compare.exact('birthDate_bnf',
            'birthDate_wk',
            label='birthDate_bnf_wk')
compare.exact('deathDate_bnf',
            'deathDate_wk',
            label='deathDate_bnf_wk')
features = compare.compute(candidates, df_bnf, df_wk)

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 3.0     813
# 2.0     424
# 1.0    7382
# 0.0    6889
# dtype: int64

# %%
potential_matches = features[features.sum(axis=1) >1].reset_index()
potential_matches['Score'] = potential_matches.loc[:, 'name_bnf_wk':'deathDate_bnf_wk'].sum(axis=1)
potential_matches
# Out:
#       level_0  level_1  name_bnf_wk  birthDate_bnf_wk  deathDate_bnf_wk  Score
# 0         274     6770          1.0                 1                 1    3.0
# 1         529    13944          1.0                 1                 1    3.0
# 2         529    13947          1.0                 1                 0    2.0
# 3         529    13952          1.0                 0                 1    2.0
# 4         696      802          1.0                 1                 1    3.0
# ...       ...      ...          ...               ...               ...    ...
# 1232    10220    14340          1.0                 1                 0    2.0
# 1233    10373    44984          1.0                 1                 1    3.0
# 1234    11083    16132          1.0                 1                 1    3.0
# 1235    11116    53736          1.0                 1                 1    3.0
# 1236    11123    18691          1.0                 0                 1    2.0
#
# [1237 rows x 6 columns]

# %%
df_wk.loc[274,:]
# Out:
# index                                                274
# uri_wk             http://www.wikidata.org/entity/Q88014
# name_wk                                   Gustav Rümelin
# dateBirth_wk                                  1848-05-01
# dateDeath_wk                                  1907-01-11
# placeOfBirth_wk                                Nürtingen
# placeOfDeath_wk                     Freiburg im Breisgau
# viaf                       http://viaf.org/viaf/95543689
# uri_bnf                                              NaN
# Name: 274, dtype: object

# %%
df_bnf.loc[6770,:]
# Out:
# uri_bnf               http://data.bnf.fr/ark:/12148/cb12163133t#about
# Unnamed: 0                                                       6770
# name_bnf                                        Edmond Eugène Moeller
# viaf                                    http://viaf.org/viaf/22181280
# dateBirth_bnf                                                    1909
# dateDeath_bnf                                              1991-04-03
# placeOfBirth_bnf                                                  NaN
# placeOfDeath_bnf                                                  NaN
# bio_bnf             Bénédictin de l'Abbaye du Mont-César (Louvain)...
# Name: 6770, dtype: object

# %%
# We don't understand why, but to work, the script below must have all variables as strings.
# And this is the only way, we can do it.
df_wk['name_wk']=df_wk['name_wk'].astype(str)
df_bnf['name_bnf']=df_bnf['name_bnf'].astype(str)

Wikidata['viaf']=Wikidata['viaf'].astype(str)
df_bnf['viaf']=df_bnf['viaf'].astype(str)

df_wk['uri_wk']=df_wk['uri_wk'].astype(str)
df_bnf['uri_bnf']=df_bnf['uri_bnf'].astype(str)

df_wk['placeOfBirth_wk']=df_wk['placeOfBirth_wk'].astype(str)
df_bnf['placeOfBirth_bnf']=df_bnf['placeOfBirth_bnf'].astype(str)

df_wk['placeOfDeath_wk']=df_wk['placeOfDeath_wk'].astype(str)
df_bnf['placeOfDeath_bnf']=df_bnf['placeOfDeath_bnf'].astype(str)

df_bnf['deathDate_bnf']=df_bnf['deathDate_bnf'].astype(str)
df_wk['deathDate_wk']=df_wk['deathDate_wk'].astype(str)

df_bnf['birthDate_bnf']=df_bnf['birthDate_bnf'].astype(str)
df_wk['birthDate_wk']=df_wk['birthDate_wk'].astype(str)

df_bnf['bio_bnf']=df_bnf['bio_bnf'].astype(str)

# %%
# This makes it easy to compare matches 
df_wk['Wikidata_Name_Lookup'] = df_wk[[
   'name_wk', 'dateBirth_wk','dateDeath_wk','placeOfBirth_wk' ,'placeOfDeath_wk' 
]].apply(lambda x: '|'.join(x), axis=1)

BnF_Data['bnf_Name_Lookup'] = BnF_Data[[
   'name_bnf','dateBirth_bnf','dateDeath_bnf','placeOfBirth_bnf','placeOfDeath_bnf','bio_bnf' 
]].apply(lambda x: '|'.join(x), axis=1)

Wikidata_lookup = df_wk[['Wikidata_Name_Lookup']].reset_index()
BnF_Data_lookup = BnF_Data[['bnf_Name_Lookup']].reset_index()

# %%
Wikidata_merge = potential_matches.merge(Wikidata_lookup, how='left')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-78-a925c98ee7b7> in <module>
# ----> 1 Wikidata_merge = potential_matches.merge(Wikidata_lookup, how='left')
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8206             copy=copy,
#    8207             indicator=indicator,
# -> 8208             validate=validate,
#    8209         )
#    8210
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1282                 if len(common_cols) == 0:
#    1283                     raise MergeError(
# -> 1284                         "No common columns to perform merge on. "
#    1285                         f"Merge options: left_on={self.left_on}, "
#    1286                         f"right_on={self.right_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
final_wk_bnf_merge = Wikidata_merge.merge(BnF_Data_lookup, how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-52f9ca773f61> in <module>
# ----> 1 final_wk_bnf_merge = Wikidata_merge.merge(BnF_Data_lookup, how='left')
#
# NameError: name 'Wikidata_merge' is not defined

# %%
cols = ['id_bnf', 'id_wk', 'Score',
        'bnf_Name_Lookup', 'Wikidata_Name_Lookup']
final_wk_bnf_merge=final_wk_bnf_merge[cols].sort_values(by=[ 'Score'], ascending=True)
print(len(final_wk_bnf_merge))
final_wk_bnf_merge[:50]
# Out:
# 1016
#      id_bnf  id_wk  Score                                    bnf_Name_Lookup  \
# 507    5492  27548    2.0  Yvon Linant de Bellefonds|1904-08-27|1994-12-2...
# 520    5818  26807    2.0  Federico Patellani|1911-12-01|1977-02-10|Monza...
# 522    5887  30520    2.0  Charles Lyon-Caen|1843-12-25|1935-09-17|Paris ...
# 523    5889   2375    2.0  Charles-Frédéric Rau|1803-08-03|1877-04-10|Sav...
# 525    5897  10622    2.0  Robert Walter|1931-01-30|2010-12-25|nan|nan|Ju...
# 526    5899  26491    2.0  Salvatore Riccobono|1864-01-31|1958-04-05|San ...
# 527    5901  52871    2.0  Roman Herzog|1934-04-05|2017-01-10|Landshut (B...
# 518    5729     97    2.0  Hugo Sinzheimer|1875-04-12|1945-09-16|Worms (R...
# 528    5905   3888    2.0  Ottó Bihari|1921-01-11|1983-01-04|Timis̡oara (...
# 533    5976  41022    2.0     Otto Weissel|1875-08-31|1955|Vienne|nan|Avocat
# 534    5989  13808    2.0  Claude Beau|1948|2010-01-29|nan|nan|Magistrate...
# 541    6203  37386    2.0  Édouard Bonnier|1808-09-27|1877|Lille|nan|Juri...
# 542    6209   3039    2.0  Gejza Ferdinandy|1864-06-10|1924-03-15|Kassa (...
# 544    6234   9008    2.0  Paul Roth|1820-07-11|1892|nan|nan|Juriste. - S...
# 546    6279  12423    2.0  Jean Escarra|1885-04-10|1955-08-14|Paris|Paris...
# 531    5967   3535    2.0  Hans Hattenhauer|1931-09-08|2015-03-20|Gross M...
# 517    5715   2245    2.0  Arturo Capdevila|1889-03-14|1967-12-20|Cordoba...
# 516    5696  53587    2.0  Władysław Raczkiewicz|1885-01-28|1947|nan|nan|...
# 512    5619  35036    2.0  Emil Sobota|1892-05-17|1945-04-24|Beroun (Bohê...
# 486    4772   9959    2.0  János Zichy|1868-05-30|1944-01-06|Nagyláng (Ho...
# 487    4954   2683    2.0  Paul Spaak|1876-07-05|1936-05-08|Ixelles, Belg...
# 488    4967  43422    2.0  Théodore Homberg|1802-05-04|1885-11-29|Le Havr...
# 489    5006  24666    2.0  Márton Hegyesi|1846-07-10|1907-03-14|Nagybajom...
# 491    5228  27288    2.0  Louis Oustry|1822-02-09|1888-03-14|Rodez (Avey...
# 493    5295  13978    2.0  Clément de Royer|1844-11-04|19..|Paris (France...
# 494    5305  28384    2.0  János Csarada|1850-05-16|1923-04-04|Nyitra (Ni...
# 496    5316  13502    2.0  Léo Glaeser|1887-11|1944-06-29|Riga (Lettonie)...
# 497    5318  14362    2.0  Giacinto Auriti|1923-10-10|2006-08-11|nan|nan|...
# 499    5343  37076    2.0  Raoul Biville|1863-12-17|1909-05|Luneray (Sein...
# 501    5416  46463    2.0  Nicolas Haillant|1844-12-17|1919|Epinal (Vosge...
# 504    5457   4496    2.0  Emil Seckel|1864-01-10|1924-04-26|Neuhenheim, ...
# 508    5505  14305    2.0  Josep Maria Font i Rius|1915-04-12|2018-12-05|...
# 510    5589  52990    2.0  Arnold Borret|1848-10-28|1888-02-06|Maastricht...
# 511    5609  14547    2.0  Emmanuel Gounot|1885-06-18|1960-05-14|Connaux ...
# 549    6315  13476    2.0  Charles Giraud|1802-02-20|1881-07-13|Pernes (V...
# 551    6335  39710    2.0  Armand Bernard|1868-03-08|1935-08|Montbéliard ...
# 554    6359  11997    2.0  Paul Vinogradoff|1854-12-01|1925-12-19|Kostrom...
# 556    6390  35300    2.0  Louis Loriot|1883-10-21|1962-11-27|Pont-Audeme...
# 596    7059   5456    2.0  Alf Ross|1899-06-10|1979-08-17|nan|nan|Juriste...
# 599    7137  44095    2.0  Percy Ellwood Corbett|1892-12-20|1983-10-24|Ty...
# 601    7175  28116    2.0  Stanko Majcen|1888-10-26|1970-12-16|nan|nan|Dr...
# 602    7189  30223    2.0    Miodrag Jovičić|1925-01-07|1999|nan|nan|Juriste
# 604    7208  14527    2.0  Giovanni Abignente|1854-10-30|1916-02-24|Sarno...
# 605    7213  43606    2.0  Christophe Grzegorczyk|1946-05-08|2018-11-30|C...
# 606    7231   1298    2.0  Felix Liebermann|1851-07-20|1925-10-07|Berlin|...
# 607    7236  14925    2.0  Fernand Faure|1853-03-16|1929-11-06|nan|nan|Av...
# 611    7256  53686    2.0  Anton Friedrich Justus Thibaut|1772-01-04|1840...
# 612    7275  16241    2.0  Henry Solus|1892-06-09|1981-07-24|Vervins (Ais...
# 613    7282  11939    2.0  Tonio Bödiker|1843-06-05|1907-02-04|Hanovre (B...
# 614    7284  27772    2.0  Pierre Delaisi|1903-07-13|1983|Paris (France)|...
#
#                                   Wikidata_Name_Lookup
# 507  Yvon Linant de Bellefonds|1904-01-01|1994-12-2...
# 520  Federico Patellani|1911-12-01|1977-01-01|Monza...
# 522  Charles Lyon-Caen|1843-12-25|1935-12-17|Paris|...
# 523  Charles-Frédéric Rau|1803-08-03|1877-04-1|Boux...
# 525   Robert Walter|1931-01-3|2010-12-25|Vienna|Vienna
# 526  Salvatore Riccobono|1864-01-31|1958-04-12|San ...
# 527  Roman Herzog|1934-04-05|2017-01-1|Landshut|Bad...
# 518  Hugo Sinzheimer|1875-01-01|1945-09-16|Worms|Bl...
# 528   Ottó Bihari|1921-01-13|1983-01-04|Timișoara|Pécs
# 533   Otto Weissel|1875-08-31|1955-12-23|Vienna|Geneva
# 534      Claude Beau|1948-01-01|2010-01-29|Morocco|nan
# 541  Édouard Bonnier|1808-09-27|1877-09-01|Lille|Paris
# 542  Gejza Ferdinandy|1864-06-1|1924-03-15|Košice|B...
# 544   Paul Roth|1820-07-11|1892-03-29|Nuremberg|Munich
# 546  Jean Escarra|1885-04-1|1955-08-14|8th arrondis...
# 531   Hans Hattenhauer|1931-09-08|2015-03-2|nan|Speyer
# 517  Arturo Capdevila|1889-03-14|1967-12-2|Córdoba|...
# 516  Władysław Raczkiewicz|1885-01-28|1947-06-06|Ku...
# 512    Emil Sobota|1892-05-17|1945-04-14|Beroun|Prague
# 486  János Zichy|1868-05-3|1944-01-06|Zichy Mansion...
# 487  Paul Spaak|1871-07-05|1936-05-08|Ixelles - Els...
# 488  Théodore Homberg|1802-05-04|1885-11-28|Le Havr...
# 489  Márton Hegyesi|1846-07-1|1907-03-14|Nagybajom|...
# 491  Louis Oustry|1822-02-09|1883-03-14|Rodez|Chartres
# 493   Clément de Royer|1844-11-04|1912-09-27|Paris|nan
# 494  János Csarada|1850-05-15|1923-04-04|Nitra|Buda...
# 496    Léo Glaeser|1887-11-11|1944-06-29|Riga|Rillieux
# 497  Giacinto Auriti|1923-10-1|2006-08-11|Guardiagr...
# 499   Raoul Biville|1863-12-17|1909-05-07|Luneray|Caen
# 501  Nicolas Haillant|1844-12-17|1919-01-01|Uriméni...
# 504  Emil Seckel|1864-01-1|1924-04-26|Neuenheim|Tod...
# 508  Josep Maria Font i Rius|1915-04-12|2018-04-05|...
# 510  Arnold Borret|1848-10-28|1888-02-08|Maastricht...
# 511     Emmanuel Gounot|1885-06-18|1960-01-01|Gard|nan
# 549  Charles Giraud|1802-02-2|1881-07-13|Pernes-les...
# 551  Armand Bernard|1868-03-08|1935-08-01|Montbélia...
# 554  Paul Vinogradoff|1854-11-3|1925-12-19|Moscow|P...
# 556  Louis Loriot|1883-10-21|1962-11-28|Pont-Audeme...
# 596     Alf Ross|1899-06-1|1979-08-17|Copenhagen|Virum
# 599  Percy Ellwood Corbett|1892-12-2|1983-10-24|Tyn...
# 601  Stanko Majcen|1888-10-29|1970-12-16|Maribor|Ma...
# 602  Miodrag Jovičić|1925-01-07|1999-10-16|Jagodina...
# 604  Giovanni Abignente|1854-10-3|1916-02-24|Sarno|...
# 605  Christophe Grzegorczyk|1946-05-08|2018-11-3|Kr...
# 606  Felix Liebermann|1851-07-2|1925-10-07|Berlin|B...
# 607  Fernand Faure|1853-03-16|1929-03-06|Ribérac|Paris
# 611  Anton Friedrich Justus Thibaut|1772-01-04|1840...
# 612  Henry Solus|1892-06-09|1981-07-25|Vervins|Cout...
# 613  Tonio Bödiker|1843-03-06|1907-02-04|Meppen|Berlin
# 614  Pierre Delaisi|1903-07-13|1983-01-24|5th arron...

# %%
# We realize a merge between Wikidata and BnF Data using the BnF URIs in common
merged_final_bnf_wk = merged_bnf_wk.merge(final_wk_bnf_merge, on=['id_wk', 'id_bnf'], how='outer')
print("")
print("This method merge", len(merged_final_bnf_wk), "persons.")
print("")
print(len(merged_final_bnf_wk)-len(merged_bnf_wk), "persons have not a BnF URI in common on Wikidata.")
print("")
cols=["id_bnf","id_wk","uri_bnf","uri_wk", "name_bnf", "dateBirth_bnf","dateDeath_bnf","placeOfBirth_bnf","placeOfDeath_bnf","bio_bnf","name_wk","dateBirth_wk","dateDeath_wk","placeOfBirth_wk","placeOfDeath_wk"]
merged_final_bnf_wk[cols][:10]
# Out:
# This method merge 1597 persons.
#
# 39 persons have not a BnF URI in common on Wikidata.
#    id_bnf  id_wk                                          uri_bnf  \
# 0    1713   6505  http://data.bnf.fr/ark:/12148/cb10071436z#about
# 1    6594  28290  http://data.bnf.fr/ark:/12148/cb101827728#about
# 2    6600  44446  http://data.bnf.fr/ark:/12148/cb10190862z#about
# 3    6929   6082  http://data.bnf.fr/ark:/12148/cb102042826#about
# 4    6931  46637  http://data.bnf.fr/ark:/12148/cb10207440j#about
# 5    7694   2149  http://data.bnf.fr/ark:/12148/cb102101229#about
# 6    3976  28075  http://data.bnf.fr/ark:/12148/cb10217219c#about
# 7    1011  15408  http://data.bnf.fr/ark:/12148/cb102252805#about
# 8    7407  45126  http://data.bnf.fr/ark:/12148/cb10226211k#about
# 9   10383  29226  http://data.bnf.fr/ark:/12148/cb10226945t#about
#
#                                      uri_wk                    name_bnf  \
# 0   http://www.wikidata.org/entity/Q1360518                  Ernst Walz
# 1  http://www.wikidata.org/entity/Q15177628             Adrien Calmètes
# 2  http://www.wikidata.org/entity/Q56646471                    Béla Kun
# 3   http://www.wikidata.org/entity/Q1214240                   Imre Nagy
# 4  http://www.wikidata.org/entity/Q94851244  Wilhelm Gustav Karl Starke
# 5    http://www.wikidata.org/entity/Q343248                  Karel Baxa
# 6  http://www.wikidata.org/entity/Q15830136                  Jan Heller
# 7   http://www.wikidata.org/entity/Q3840074                  Luigi Rava
# 8  http://www.wikidata.org/entity/Q57202321                  André Roux
# 9  http://www.wikidata.org/entity/Q13411514                Arveds Švābe
#
#   dateBirth_bnf dateDeath_bnf  \
# 0    1859-07-18    1941-12-18
# 1    1800-09-19    1871-02-27
# 2    1861-04-24    1934-09-19
# 3    1822-07-01    1894-05-05
# 4    1824-02-26    1903-03-10
# 5    1863-06-23    1938-01-05
# 6    1848-11-13    1932-03-20
# 7    1860-12-01    1938-05-12
# 8    1893-10-10          19..
# 9    1888-05-25    1959-08-20
#
#                                     placeOfBirth_bnf  \
# 0            Heidelberg (Bade-Wurtemberg, Allemagne)
# 1                                 Figueras (Espagne)
# 2                          Sátoraljaújhelyi, Hongrie
# 3  Németkeresztúr, aujourd'hui Deutschkreutz, Aut...
# 4                Lubán (Prusse, aujourd'hui Pologne)
# 5                                                NaN
# 6              Vranov u Rokycan (République tchèque)
# 7                                    Ravenne, Italie
# 8                                   Privas (Ardèche)
# 9                                                NaN
#
#                           placeOfDeath_bnf  \
# 0  Heidelberg (Bade-Wurtemberg, Allemagne)
# 1                    Montpellier (Hérault)
# 2                        Budapest, Hongrie
# 3                                 Budapest
# 4                       Berlin (Allemagne)
# 5                                      NaN
# 6              Prague (République tchèque)
# 7                                     Rome
# 8                                      NaN
# 9                                      NaN
#
#                                              bio_bnf  \
# 0  Maire de Heidelberg, Allemagne (1886-). - A ét...
# 1  Magistrat. - Président de chambre à Montpellie...
# 2  Juriste. - Conseiller au Ministère de la Justi...
# 3                Historien. - Juriste. - Académicien
# 4                           Juriste. - Parlementaire
# 5  Docteur en droit. - Avocat. - Membre du parti ...
# 6  Juriste, publiciste. - Rédacteur de la revue j...
# 7  Juriste et historien, professeur de philosophi...
# 8  Magistrat. - A été avocat à Montpellier (1915-...
# 9                       Historien, juriste et auteur
#
#                       name_wk dateBirth_wk dateDeath_wk  placeOfBirth_wk  \
# 0                  Ernst Walz   1859-07-19   1941-12-18       Heidelberg
# 1             Adrien Calmètes   1800-09-19   1871-02-27         Figueres
# 2                    Kun Béla   1861-04-24   1934-09-19  Sátoraljaújhely
# 3                   Imre Nagy   1822-06-01   1894-05-05    Deutschkreutz
# 4  Wilhelm Gustav Karl Starke   1824-02-26   1903-03-09            Lubań
# 5                  Karel Baxa   1862-06-24   1938-01-05         Sedlčany
# 6                  Jan Heller   1848-11-13    1932-03-2              NaN
# 7                  Luigi Rava   1860-11-29   1938-05-12          Ravenna
# 8            André Louis Roux    1893-10-1          NaN           Privas
# 9                Arveds Švābe   1888-05-25    1959-08-2        Q16362410
#
#          placeOfDeath_wk
# 0             Heidelberg
# 1            Montpellier
# 2  Budapest District VII
# 3               Budapest
# 4                 Berlin
# 5                 Prague
# 6                 Prague
# 7                   Rome
# 8                    NaN
# 9              Stockholm

# %% [markdown]
# ## Match between BnF Data and DBpedia

# %% [markdown]
# indexer = recordlinkage.Index()
# indexer.full()

# %%
indexer = recordlinkage.Index()
indexer.block(left_on='name_bnf', right_on='name_dbp')
candidates = indexer.index(df_bnf, df_dbp)
print(len(candidates))
# Out:
# 28614

# %%
compare = recordlinkage.Compare()
compare.string('name_bnf',
            'name_dbp',
            method='jarowinkler',
            threshold=0.85,
            label='name_bnf_dbp')
compare.exact('birthDate_bnf',
            'birthDate_dbp',
            label='birthDate_bnf_dbp')
compare.exact('deathDate_bnf',
            'deathDate_dbp',
            label='deathDate_bnf_dbp')
features = compare.compute(candidates, df_bnf, df_dbp)

# %%
features
# Out:
#                name_bnf_dbp  birthDate_bnf_dbp  deathDate_bnf_dbp
# id_bnf id_dbp
# 20     2                1.0                  1                  1
# 47     5                0.0                  0                  0
#        6                0.0                  0                  0
#        32               0.0                  0                  0
#        33               0.0                  0                  0
# ...                     ...                ...                ...
# 10651  944              1.0                  1                  0
#        945              1.0                  1                  0
#        946              1.0                  1                  0
#        947              1.0                  1                  0
#        948              1.0                  1                  0
#
# [28614 rows x 3 columns]

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 3.0      269
# 2.0       73
# 1.0      104
# 0.0    28168
# dtype: int64

# %%
potential_matches = features[features.sum(axis=1) > 1].reset_index()
potential_matches['Score'] = potential_matches.loc[:, 'name_bnf_dbp':'deathDate_bnf_dbp'].sum(axis=1)
potential_matches
# Display the matches up to
# Out:
#      id_bnf  id_dbp  name_bnf_dbp  birthDate_bnf_dbp  deathDate_bnf_dbp  Score
# 0        20       2           1.0                  1                  1    3.0
# 1        85      10           1.0                  1                  1    3.0
# 2        85      11           1.0                  1                  1    3.0
# 3        85      12           1.0                  1                  1    3.0
# 4        85      13           1.0                  1                  1    3.0
# ..      ...     ...           ...                ...                ...    ...
# 337   10651     944           1.0                  1                  0    2.0
# 338   10651     945           1.0                  1                  0    2.0
# 339   10651     946           1.0                  1                  0    2.0
# 340   10651     947           1.0                  1                  0    2.0
# 341   10651     948           1.0                  1                  0    2.0
#
# [342 rows x 6 columns]

# %%
df_bnf.loc[85,:]
# Out:
# uri_bnf               http://data.bnf.fr/ark:/12148/cb123010784#about
# viaf_bnf                                 http://viaf.org/viaf/9914155
# name_bnf                                    Vittorio Emanuele Orlando
# Sname                                                             NaN
# birthDate_bnf                                              1860-05-19
# deathDate_bnf                                              1952-12-01
# placeOfBirth_bnf                                     Palerme (Italie)
# placeOfDeath_bnf                                                 Rome
# bio_bnf             Juriste, spécialiste de droit public. - Présid...
# Name: 85, dtype: object

# %%
df_dbp.loc[10,:]
# Out:
# uri_dbp             http://dbpedia.org/resource/Vittorio_Emanuele_...
# viaf_dbp                                 http://viaf.org/viaf/9914155
# name_dbp                                    Vittorio Emanuele Orlando
# birthDate_dbp                                              1860-05-19
# deathDate_dbp                                              1952-12-01
# placeOfBirth_dbp                          Kingdom of the Two Sicilies
# placeOfDeath_dbp                                                Italy
# Name: 10, dtype: object

# %%
bnf_merge = potential_matches.merge(df_bnf, how='left', on='id_bnf')

# %%
final_dbp_wk_merge = bnf_merge .merge(df_dbp, how='left', on='id_dbp')

# %%
BnF_merge = pd.merge(potential_matches,df_bnf, how='left', on="id_bnf")

# %%
final_bnf_dbp_merge = BnF_merge.merge(df_dbp, how='left', on='id_dbp')

# %%
cols = ["uri_dbp","name_dbp", "birthDate_dbp","deathDate_dbp","placeOfBirth_dbp","placeOfDeath_dbp"]
final_bnf_dbp_merge=final_bnf_dbp_merge[cols]
print(len(final_bnf_dbp_merge))
final_bnf_dbp_merge
# Out:
# 342
#                                                uri_dbp  \
# 0           http://dbpedia.org/resource/Anita_Augspurg
# 1    http://dbpedia.org/resource/Vittorio_Emanuele_...
# 2    http://dbpedia.org/resource/Vittorio_Emanuele_...
# 3    http://dbpedia.org/resource/Vittorio_Emanuele_...
# 4    http://dbpedia.org/resource/Vittorio_Emanuele_...
# ..                                                 ...
# 337     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 338     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 339     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 340     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 341     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
#
#                       name_dbp birthDate_dbp deathDate_dbp  \
# 0               Anita Augspurg    1857-09-22    1943-12-20
# 1    Vittorio Emanuele Orlando    1860-05-19    1952-12-01
# 2    Vittorio Emanuele Orlando    1860-05-19    1952-12-01
# 3    Vittorio Emanuele Orlando    1860-05-19    1952-12-01
# 4    Vittorio Emanuele Orlando    1860-05-19    1952-12-01
# ..                         ...           ...           ...
# 337         Laxmi Mall Singhvi    1931-11-09    2007-10-06
# 338         Laxmi Mall Singhvi    1931-11-09    2007-10-06
# 339         Laxmi Mall Singhvi    1931-11-09    2007-10-06
# 340         Laxmi Mall Singhvi    1931-11-09    2007-10-06
# 341         Laxmi Mall Singhvi    1931-11-09    2007-10-06
#
#                                 placeOfBirth_dbp placeOfDeath_dbp
# 0
# 1                    Kingdom of the Two Sicilies            Italy
# 2                                        Palermo            Italy
# 3                    Kingdom of the Two Sicilies             Rome
# 4                                        Palermo             Rome
# ..                                           ...              ...
# 337                                      Jodhpur            India
# 338                                Jodhpur State            India
# 339  Presidencies and provinces of British India        New Delhi
# 340                                      Jodhpur        New Delhi
# 341                                Jodhpur State        New Delhi
#
# [342 rows x 6 columns]

# %%
pd.concat([df_dbp,final_bnf_dbp_merge]).drop_duplicates(keep=False)
# Out:
#                                                uri_dbp  \
# 0    http://dbpedia.org/resource/António_de_Almeida...
# 1         http://dbpedia.org/resource/Carlos_Carvalhas
# 2           http://dbpedia.org/resource/Anita_Augspurg
# 3             http://dbpedia.org/resource/Paulo_Portas
# 4             http://dbpedia.org/resource/Paulo_Portas
# ..                                                 ...
# 337     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 338     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 339     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 340     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
# 341     http://dbpedia.org/resource/Laxmi_Mall_Singhvi
#
#                           viaf_dbp                   name_dbp birthDate_dbp  \
# 0    http://viaf.org/viaf/99921066  António de Almeida Santos    1926-02-15
# 1    http://viaf.org/viaf/99826658           Carlos Carvalhas    1941-11-09
# 2     http://viaf.org/viaf/9976800             Anita Augspurg    1857-09-22
# 3    http://viaf.org/viaf/99455673               Paulo Portas    1962-09-12
# 4    http://viaf.org/viaf/99455673               Paulo Portas    1962-09-12
# ..                             ...                        ...           ...
# 337                            NaN         Laxmi Mall Singhvi    1931-11-09
# 338                            NaN         Laxmi Mall Singhvi    1931-11-09
# 339                            NaN         Laxmi Mall Singhvi    1931-11-09
# 340                            NaN         Laxmi Mall Singhvi    1931-11-09
# 341                            NaN         Laxmi Mall Singhvi    1931-11-09
#
#     deathDate_dbp                             placeOfBirth_dbp  \
# 0      2016-01-18
# 1                                   São Pedro do Sul, Portugal
# 2      1943-12-20
# 3                                                       Lisbon
# 4                                                     Portugal
# ..            ...                                          ...
# 337    2007-10-06                                      Jodhpur
# 338    2007-10-06                                Jodhpur State
# 339    2007-10-06  Presidencies and provinces of British India
# 340    2007-10-06                                      Jodhpur
# 341    2007-10-06                                Jodhpur State
#
#     placeOfDeath_dbp
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 337            India
# 338            India
# 339        New Delhi
# 340        New Delhi
# 341        New Delhi
#
# [10089 rows x 7 columns]

# %%
# We realize a merge between Wikidata, BnF Data and DBpedia using the BnF URIs in common
merged_final_bnf_wk_dbp = merged_final_bnf_wk.merge(final_bnf_dbp_merge, on=['id_bnf'], how="inner")
print("")
print("This method merge", len(merged_final_bnf_wk_dbp), "persons.")
print("")
cols=["id_bnf","id_wk",'id_dbp',"uri_bnf_x","uri_wk", "name_bnf_x", "dateBirth_bnf_x","dateDeath_bnf_x","placeOfBirth_bnf_x","placeOfDeath_bnf_x","bio_bnf","name_wk","dateBirth_wk","dateDeath_wk","placeOfBirth_wk","placeOfDeath_wk","name_dbp", "birthDate_dbp","deathDate_dbp","placeOfBirth_dbp","placeOfDeath_dbp"]
merged_final_bnf_wk_dbp[cols][50:100]
# Out:
# This method merge 39 persons.
# Empty DataFrame
# Columns: [id_bnf, uri_bnf, viaf_x, name_bnf, Sname, dateBirth_bnf, dateDeath_bnf, placeOfBirth_bnf, placeOfDeath_bnf, bio_bnf, id_wk, uri_wk, name_wk, dateBirth_wk, dateDeath_wk, placeOfBirth_wk, placeOfDeath_wk, viaf_y, Score, bnf_Name_Lookup, Wikidata_Name_Lookup, id_dbp, uri_dbp, name_dbp, birthDate_dbp, deathDate_dbp, placeOfBirth_dbp, placeOfDeath_dbp]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# #### Match between DBpedia and Wikidata

# %%
import recordlinkage

# %%
indexer = recordlinkage.Index()
indexer.sortedneighbourhood(left_on='deathDate_wk', right_on='deathDate_dbp')
candidates = indexer.index(df_wk, df_dbp)
print(len(candidates))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f682da53bb7e> in <module>
#       1 indexer = recordlinkage.Index()
#       2 indexer.sortedneighbourhood(left_on='deathDate_wk', right_on='deathDate_dbp')
# ----> 3 candidates = indexer.index(df_wk, df_dbp)
#       4 print(len(candidates))
#
# NameError: name 'df_wk' is not defined

# %% [markdown]
# indexer = recordlinkage.Index()
# indexer.block(left_on=['name_bnf', 'uri_bnf'],
#               right_on=['name_dbp', 'uri_dbp'])
# pairs = indexer.index(df_bnf, df_dbp)

# %% [markdown]
# candidates = indexer.index(BnF_Data, DBpedia)
# print(len(candidates))

# %%
compare = recordlinkage.Compare()
compare.string('name_wk',
            'name_dbp',
            threshold=0.85,
            label='name_wk_dbp')
compare.exact('dateDeath_wk',
            'deathDate_dbp',
            label='deathDate_wk_dbp')
compare.exact('dateBirth_wk',
            'birthDate_dbp',
            label='birthDate_wk_dbp')
features = compare.compute(candidates, Wikidata, DBpedia)
# !!!! see if use https://recordlinkage.readthedocs.io/en/latest/ref-compare.html#recordlinkage.Compare.add works to add method like compare 'exact' on 'name'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5477907df51d> in <module>
# ----> 1 compare = recordlinkage.Compare()
#       2 compare.string('name_wk',
#       3             'name_dbp',
#       4             threshold=0.85,
#       5             label='name_wk_dbp')
#
# NameError: name 'recordlinkage' is not defined

# %%
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 3.0     409
# 2.0     234
# 1.0    1110
# 0.0    8797
# dtype: int64

# %%
features
# Out:
#               name_wk_dbp  deathDate_wk_dbp  birthDate_wk_dbp
# id_wk id_dbp
# 37    7331            0.0                 0                 0
# 51    1800            1.0                 0                 1
# 10006 1800            0.0                 0                 0
# 58    6668            0.0                 0                 0
# 24839 6668            0.0                 0                 0
# ...                   ...               ...               ...
# 56294 9738            0.0                 0                 0
# 56314 7415            0.0                 0                 0
# 56347 687             0.0                 0                 0
# 56413 7486            0.0                 0                 0
# 56466 2902            0.0                 0                 0
#
# [10550 rows x 3 columns]

# %%
potential_matches = features[features.sum(axis=1) > 1].reset_index()
potential_matches['Score'] = potential_matches.loc[:, 'name_wk_dbp':'birthDate_wk_dbp'].sum(axis=1)
potential_matches
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name_wk_dbp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-492-a8b2fe82908e> in <module>
#       1 potential_matches = features[features.sum(axis=1) > 1].reset_index()
# ----> 2 potential_matches['Score'] = potential_matches.loc[:, 'name_wk_dbp':'birthDate_wk_dbp'].sum(axis=1)
#       3 potential_matches
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1100         if isinstance(key, slice):
#    1101             self._validate_key(key, axis)
# -> 1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
#    1104             return self._getbool_axis(key, axis=axis)
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1135         labels = obj._get_axis(axis)
#    1136         indexer = labels.slice_indexer(
# -> 1137             slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1138         )
#    1139
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5275         slice(1, 3, None)
#    5276         """
# -> 5277         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5278
#    5279         # return a slice
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5474         start_slice = None
#    5475         if start is not None:
# -> 5476             start_slice = self.get_slice_bound(start, "left", kind)
#    5477         if start_slice is None:
#    5478             start_slice = 0
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5394             except ValueError:
#    5395                 # raise the original KeyError
# -> 5396                 raise err
#    5397
#    5398         if isinstance(slc, np.ndarray):
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5388         # we need to look up the label
#    5389         try:
# -> 5390             slc = self.get_loc(label)
#    5391         except KeyError as err:
#    5392             try:
#
# ~/anaconda3/envs/Merge/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'name_wk_dbp'

# %%
Wikidata.loc[2255,:]
# Out:
# uri_wk             http://www.wikidata.org/entity/Q350384
# name_wk                                       Milan Jelić
# dateBirth_wk                                   1956-03-26
# dateDeath_wk                                    2007-09-3
# placeOfBirth_wk                         Koprivna, Modriča
# placeOfDeath_wk                                   Modriča
# viaf                                                  NaN
# uri_bnf                                               NaN
# Name: 2255, dtype: object

# %%
DBpedia.loc[156,:]
# Out:
# uri_dbp                    http://dbpedia.org/resource/Boris_Fyodorov
# viaf                                    http://viaf.org/viaf/91429025
# name_dbp                                               Boris Fyodorov
# birthDate_dbp                                              1958-02-13
# deathDate_dbp                                              2008-11-20
# placeOfBirth_dbp                                         Soviet Union
# placeOfDeath_dbp                                               London
# dbp_Name_Lookup     Boris Fyodorov|1958-02-13|2008-11-20|Soviet Un...
# Name: 156, dtype: object

# %%
Wikidata['name_wk']=Wikidata['name_wk'].astype(str)
DBpedia['name_dbp']=DBpedia['name_dbp'].astype(str)

Wikidata['viaf']=Wikidata['viaf'].astype(str)
DBpedia['viaf']=DBpedia['viaf'].astype(str)

Wikidata['uri_wk']=Wikidata['uri_wk'].astype(str)
DBpedia['uri_dbp']=DBpedia['uri_dbp'].astype(str)

Wikidata['placeOfBirth_wk']=Wikidata['placeOfBirth_wk'].astype(str)
DBpedia['placeOfBirth_dbp']=DBpedia['placeOfBirth_dbp'].astype(str)

Wikidata['placeOfDeath_wk']=Wikidata['placeOfDeath_wk'].astype(str)
DBpedia['placeOfDeath_dbp']=DBpedia['placeOfDeath_dbp'].astype(str)

Wikidata['dateDeath_wk']=Wikidata['dateDeath_wk'].astype(str)
DBpedia['deathDate_dbp']=DBpedia['deathDate_dbp'].astype(str)

Wikidata['dateBirth_wk']=Wikidata['dateBirth_wk'].astype(str)
DBpedia['birthDate_dbp']=DBpedia['birthDate_dbp'].astype(str)

# %%
Wikidata['Wikidata_Name_Lookup'] = Wikidata[[
   'name_wk', 'dateBirth_wk','dateDeath_wk','placeOfBirth_wk' ,'placeOfDeath_wk' 
]].apply(lambda x: '|'.join(x), axis=1)

DBpedia['dbp_Name_Lookup'] = DBpedia[[
   'name_dbp', 'birthDate_dbp', 'deathDate_dbp','placeOfBirth_dbp', 'placeOfDeath_dbp'
]].apply(lambda x: '|'.join(x), axis=1)

Wikidata_lookup = Wikidata[['Wikidata_Name_Lookup']].reset_index()
DBpedia_lookup = DBpedia[['dbp_Name_Lookup']].reset_index()

# %%
Wikidata_merge = potential_matches.merge(Wikidata_lookup, how='left')

# %%
final_dbp_wk_merge = Wikidata_merge.merge(DBpedia_lookup, how='left')

# %%
cols = ['id_wk', 'id_dbp', 'Score',
        'Wikidata_Name_Lookup', 'dbp_Name_Lookup']
final_dbp_wk_merge=final_dbp_wk_merge[cols].sort_values(by=[ 'Score'], ascending=True)
print(len(final))
final[:20]
# Out:
# 117
#      id_bnf  id_dbp  Score                                    BnF_Name_Lookup  \
# 0      2110    9566    2.0  Mihai A. Antonescu|1907-11-18|1946-06-01|Nucet...
# 84     9181    3201    2.0  Vilfredo Pareto|1848-07-15|1923-08-20|Paris|Cé...
# 34     3014    8313    2.0  Gisèle Halimi|1927-07-27|2020-07-28|La Goulett...
# 33     2607    1493    2.0  William Martin Geldart|1870-06-07|1922-02-12|n...
# 44     3539    8182    2.0  Camille Blaisot|1881-01-19|1945|Valognes (Manc...
# 89     9336    4306    2.0  Jacob Marschak|1898|1977-07-27|nan|nan|Economi...
# 45     3560    1976    2.0  Gyula Wlassics|1852-03-17|1937-04-30|Zalaegers...
# 25     1870    1054    2.0  David Josiah Brewer|1837-06-20|1910-03-27|nan|...
# 93     9470    1808    2.0  Gustav Cassel|1866-10-20|1945-01-15|Stockholm|...
# 48     3669    5796    2.0  Vincenzo Caianiello|1932-10-02|2002-04-26|Aver...
# 96     9489     576    2.0  Federico Caffè|1914-01-06|1987-04|Pescara, Ita...
# 51     3717    2066    2.0  Antonio Cassese|1937|2011-10-21|nan|nan|Profes...
# 52     3783    2132    2.0  Roland Freisler|1893-12-30|1945-02-03|nan|nan|...
# 72     6635    8693    2.0  Jeff Davis|1862-05-06|1913-03-01|Little River ...
# 98     9571    1317    2.0  Emmanuel Farhi|1978-09-08|2020-07-23|Paris (Fr...
# 104    9687    1785    2.0  Luigi Luzzatti|1841-03-01|1927-03-29|Venise, I...
# 1      5555    8405    2.0  John James Bennett|1894-03-02|1967-10|Brooklyn...
# 112   10651     943    2.0  Laxmi Mall Singhvi|1931-11-09|2007-10-13|nan|n...
# 5      9907    6562    2.0  Rafael Núñez|1825-09-28|1894-09-18|Carthagène ...
# 103    9682     289    2.0  Masahiko Aoki|1938-01-04|2015-07-15|nan|nan|Éc...
#
#                                        dbp_Name_Lookup
# 0    Mihai Antonescu|1904-11-18|1946-06-01|Kingdom ...
# 84       Vilfredo Pareto|1848-07-15|1923-08-19|nan|nan
# 34   Gisèle Halimi|1927-07-28|2020-07-28|French pro...
# 33   William Martin Geldart|1870-06-07|--02-12|nan|nan
# 44   Camille Blaisot|1881-01-19|1945-01-24|Valognes...
# 89   Jacob Marschak|1898-07-23|1977-07-27|Russian E...
# 45   Gyula Wlassics|1852-03-17|1937-03-30|Kingdom o...
# 25   David Josiah Brewer|1837-06-20|1910-03-28|İzmi...
# 93   Gustav Cassel|1866-10-20|1945-01-14|Stockholm|...
# 48   Vincenzo Caianiello|1932-10-02|2002-04-06|Case...
# 96             Federico Caffè|1914-01-06|nan|Italy|nan
# 51   Antonio Cassese|1937-01-01|2011-10-21|nan|Flor...
# 52   Roland Freisler|1893-10-30|1945-02-03|Lower Sa...
# 72            Jeff Davis|1862-05-06|1913-01-03|nan|nan
# 98            Emmanuel Farhi|1978-09-08|nan|France|nan
# 104    Luigi Luzzatti|1841-03-11|1927-03-29|Venice|nan
# 1    John James Bennett, Jr.|1894-03-02|1967-10-04|...
# 112  Laxmi Mall Singhvi|1931-11-09|2007-10-06|Presi...
# 5    Rafael Núñez Moledo|1825-09-25|1894-09-18|Magd...
# 103  Masahiko Aoki|1938-04-01|2015-07-15|Japan|Unit...

# %% [markdown]
# ## VIAF method

# %% [markdown]
# ### Between Wikidata and DBpedia

# %%
Wikidata[:10]
# Out:
#                                       uri_wk                       name_wk  \
# id_wk
# 0      http://www.wikidata.org/entity/Q77404            Ingeborg Schwenzer
# 1      http://www.wikidata.org/entity/Q77341                   Hans Globke
# 2      http://www.wikidata.org/entity/Q77390             Christoph Ahlhaus
# 3      http://www.wikidata.org/entity/Q89299            Emil Schlagintweit
# 4      http://www.wikidata.org/entity/Q72628  Alfred von Kiderlen-Waechter
# 5      http://www.wikidata.org/entity/Q65539                Peter Altmaier
# 6      http://www.wikidata.org/entity/Q89439               Adolf Damaschke
# 7      http://www.wikidata.org/entity/Q72654              Magnus von Braun
# 10     http://www.wikidata.org/entity/Q65561                     Hans Apel
# 11     http://www.wikidata.org/entity/Q89493                 Marianne Beth
#
#       dateBirth_wk dateDeath_wk placeOfBirth_wk placeOfDeath_wk  \
# id_wk
# 0       1951-10-25          NaN       Stuttgart             NaN
# 1        1898-09-1   1973-02-13      Düsseldorf   Bad Godesberg
# 2       1969-08-28          NaN      Heidelberg             NaN
# 3       1835-07-07   1904-10-29          Munich     Zweibrücken
# 4        1852-07-1    1912-12-3       Stuttgart       Stuttgart
# 5       1958-06-18          NaN         Ensdorf             NaN
# 6       1865-11-24    1935-07-3          Berlin          Berlin
# 7       1878-02-07   1972-08-29   Bagrationovsk      Oberaudorf
# 10      1932-02-25   2011-09-06         Hamburg         Hamburg
# 11      1890-03-06   1984-08-19          Vienna   New York City
#
#                                  viaf  \
# id_wk
# 0       http://viaf.org/viaf/91748910
# 1       http://viaf.org/viaf/54939901
# 2      http://viaf.org/viaf/171463495
# 3       http://viaf.org/viaf/74008741
# 4       http://viaf.org/viaf/54958174
# 5        http://viaf.org/viaf/4137633
# 6       http://viaf.org/viaf/54949744
# 7      http://viaf.org/viaf/262459734
# 10     http://viaf.org/viaf/232142151
# 11     http://viaf.org/viaf/220617724
#
#                                                uri_bnf
# id_wk
# 0      http://data.bnf.fr/ark:/12148/cb15067859n#about
# 1      http://data.bnf.fr/ark:/12148/cb15597313f#about
# 2                                                  NaN
# 3      http://data.bnf.fr/ark:/12148/cb13519131c#about
# 4      http://data.bnf.fr/ark:/12148/cb135097503#about
# 5                                                  NaN
# 6      http://data.bnf.fr/ark:/12148/cb130056891#about
# 7                                                  NaN
# 10     http://data.bnf.fr/ark:/12148/cb121740063#about
# 11                                                 NaN

# %%
DBpedia[:10]
# Out:
#    id_dbp                                            uri_dbp  \
# 0       0  http://dbpedia.org/resource/António_de_Almeida...
# 1       1       http://dbpedia.org/resource/Carlos_Carvalhas
# 2       2         http://dbpedia.org/resource/Anita_Augspurg
# 3       3           http://dbpedia.org/resource/Paulo_Portas
# 4       5             http://dbpedia.org/resource/Pedro_Aspe
# 5       7  http://dbpedia.org/resource/Fernando_Teixeira_...
# 6       9           http://dbpedia.org/resource/Xavier_Vives
# 7      10  http://dbpedia.org/resource/Vittorio_Emanuele_...
# 8      14       http://dbpedia.org/resource/James_M._Poterba
# 9      15            http://dbpedia.org/resource/Claus_Roxin
#
#                             viaf                      name_dbp birthDate_dbp  \
# 0  http://viaf.org/viaf/99921066     António de Almeida Santos    1926-02-15
# 1  http://viaf.org/viaf/99826658              Carlos Carvalhas    1941-11-09
# 2   http://viaf.org/viaf/9976800                Anita Augspurg    1857-09-22
# 3  http://viaf.org/viaf/99455673                  Paulo Portas    1962-09-12
# 4   http://viaf.org/viaf/9928165                           NaN    1950-07-07
# 5  http://viaf.org/viaf/99275725  Fernando Teixeira dos Santos    1951-09-13
# 6   http://viaf.org/viaf/9920331                  Xavier Vives    1955-01-23
# 7   http://viaf.org/viaf/9914155     Vittorio Emanuele Orlando    1860-05-19
# 8   http://viaf.org/viaf/9910825              James M. Poterba    1958-07-13
# 9   http://viaf.org/viaf/9910548                   Claus Roxin    1931-05-15
#
#   deathDate_dbp             placeOfBirth_dbp placeOfDeath_dbp
# 0    2016-01-18                          NaN              NaN
# 1           NaN   São Pedro do Sul, Portugal              NaN
# 2    1943-12-20                          NaN              NaN
# 3           NaN                       Lisbon              NaN
# 4           NaN                  Mexico City              NaN
# 5           NaN               Maia, Portugal              NaN
# 6           NaN                          NaN              NaN
# 7    1952-12-01  Kingdom of the Two Sicilies            Italy
# 8           NaN                          NaN              NaN
# 9           NaN                          NaN              NaN

# %%
df_merged_Wiki_DB = Wikidata.merge( DBpedia , on='viaf', how='inner', sort='viaf')
df_merged_Wiki_DB[:10]

# %%
print("the number of merged data from DBpedia and Wikidata is ",len(merged_df_wk_dbp), "rows.")
print("")
print("The proportion of the number of merged data from DBpedia with Wikidata is ",((len(merged_df_wk_dbp))/(len(DBpedia))*100),"%")
print("")
print("proportion of the number of merged data from Wikidata with DBpedia is ",((len(merged_df_wk_dbp))/(len(Wikidata))*100),"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-205ce328a30d> in <module>
# ----> 1 print("the number of merged data from DBpedia and Wikidata is ",len(merged_df_wk_dbp), "rows.")
#       2 print("")
#       3 print("The proportion of the number of merged data from DBpedia with Wikidata is ",((len(merged_df_wk_dbp))/(len(DBpedia))*100),"%")
#       4 print("")
#       5 print("proportion of the number of merged data from Wikidata with DBpedia is ",((len(merged_df_wk_dbp))/(len(Wikidata))*100),"%")
#
# NameError: name 'merged_df_wk_dbp' is not defined

# %% [markdown]
# ### Between Wikidata and BnF Data

# %%
merged_df_2 = pd.merge( Wikidata, BnF_Data , on='viaf', how='inner', sort='viaf')
print(len(merged_df_2))
merged_df_2[:10]

# %%
print("The number of merged data from BnF Data and Wikidata is ",len(merged_df_2), "rows.")

print("")

print("The proportion of the number of merged data from BnF Data with Wikidata is ",((len(merged_df_2))/(len(df_bnf))*100),"%")

print("")

print("The proportion of the number of merged data from Wikidata with Wikidata is ",((len(merged_df_2))/(len(df_wk))*100),"%")
# Out:
# The number of merged data from BnF Data and Wikidata is  112 rows.
#
# The proportion of the number of merged data from BnF Data with Wikidata is  1.224445173280857 %
#
# The proportion of the number of merged data from Wikidata with Wikidata is  0.5179669796050502 %

# %% [markdown]
# ### Between DBpedia and BnF Data

# %%
merged_df_3 = pd.merge( df_bnf, df_dbp , on='viaf', how='inner', sort='viaf')
print(len(merged_df_3))
merged_df_3[:10]
# Out:
# 88
#                                            uri_bnf  \
# 0  http://data.bnf.fr/ark:/12148/cb122145877#about
# 1  http://data.bnf.fr/ark:/12148/cb12327654n#about
# 2  http://data.bnf.fr/ark:/12148/cb122775427#about
# 3  http://data.bnf.fr/ark:/12148/cb11927239j#about
# 4  http://data.bnf.fr/ark:/12148/cb120906270#about
# 5  http://data.bnf.fr/ark:/12148/cb119084288#about
# 6  http://data.bnf.fr/ark:/12148/cb128832222#about
# 7  http://data.bnf.fr/ark:/12148/cb12299375j#about
# 8  http://data.bnf.fr/ark:/12148/cb118935370#about
# 9  http://data.bnf.fr/ark:/12148/cb12328362p#about
#
#                              viaf                    name_bnf sName year_bnf  \
# 0  http://viaf.org/viaf/100966624               John Humphrey           1905
# 1  http://viaf.org/viaf/107536763               Louis Renault           1843
# 2  http://viaf.org/viaf/108173876        Ronald Myles Dworkin           1931
# 3  http://viaf.org/viaf/108188941              Gordon Tullock           1922
# 4  http://viaf.org/viaf/108565309         Paul Abraham Freund           1908
# 5  http://viaf.org/viaf/108587991            Alexis Jacquemin           1938
# 6  http://viaf.org/viaf/108624624  Muḥammad Ẓafr Allāh H̱ān           1893
# 7  http://viaf.org/viaf/108794549                Karl Engisch           1899
# 8  http://viaf.org/viaf/111389197            Georges Bousquet           1846
# 9   http://viaf.org/viaf/11396531           John Paul Stevens           1920
#
#                                              bio_bnf  \
# 0  Juriste. - A été professeur de droit internati...
# 1  Juriste. - Professeur de droit international à...
# 2  Juriste. - Professeur de jurisprudence à la Ya...
# 3  Docteur en droit (University of Chicago, Ill.,...
# 4          Professeur de droit, "Harvard Law School"
# 5  Juriste et économiste. - Professeur à l'Univer...
# 6              Juriste, diplomate et homme politique
# 7  Juriste. - Spécialiste de philosophie du droit...
# 8  Avocat au Barreau de Paris (en 1866). - Engagé...
# 9                                  Juriste américain
#
#                                              uri_dbp  \
# 0   http://dbpedia.org/resource/John_Peters_Humphrey
# 1  http://dbpedia.org/resource/Louis_Renault_(jur...
# 2         http://dbpedia.org/resource/Ronald_Dworkin
# 3         http://dbpedia.org/resource/Gordon_Tullock
# 4         http://dbpedia.org/resource/Paul_A._Freund
# 5       http://dbpedia.org/resource/Alexis_Jacquemin
# 6  http://dbpedia.org/resource/Muhammad_Zafarulla...
# 7           http://dbpedia.org/resource/Karl_Engisch
# 8  http://dbpedia.org/resource/Georges_Hilaire_Bo...
# 9      http://dbpedia.org/resource/John_Paul_Stevens
#
#                       name_dbp year_dbp
# 0         John Peters Humphrey     1905
# 1                Louis Renault     1843
# 2                                  1931
# 3               Gordon Tullock     1922
# 4          Paul Abraham Freund     1908
# 5             Alexis Jacquemin     1938
# 6  CH Muhammad Zafarullah Khan     1893
# 7                 Karl Engisch     1899
# 8     Georges Hilaire Bousquet     1845
# 9            John Paul Stevens     1920

# %%
print("The number of merged data from BnF Data and Wikidata is ",len(merged_df_3), "rows.")

print("")

print("The proportion of the number of merged data from BnF Data with DBpedia is ",((len(merged_df_3))/(len(df_dbp))*100),"%")

print("")

print("The proportion of the number of merged data from DBpedia with BnF Data is ",((len(merged_df_3))/(len(df_bnf))*100),"%")
# Out:
# The number of merged data from BnF Data and Wikidata is  88 rows.
#
# The proportion of the number of merged data from BnF Data with DBpedia is  5.333333333333334 %
#
# The proportion of the number of merged data from DBpedia with BnF Data is  0.9620640647206734 %

# %% [markdown]
# ### Between Wikidata, BnF Data and DBpedia

# %%
merged_df = pd.merge( merged_df_1, df_bnf , on='viaf', how='inner', sort='viaf')
merged_df[:10]
# Out:
#                                     uri_wk                            viaf  \
# 0   http://www.wikidata.org/entity/Q518859  http://viaf.org/viaf/108188941
# 1   http://www.wikidata.org/entity/Q652154  http://viaf.org/viaf/108587991
# 2  http://www.wikidata.org/entity/Q3085838   http://viaf.org/viaf/32062931
# 3    http://www.wikidata.org/entity/Q61956   http://viaf.org/viaf/44308789
# 4   http://www.wikidata.org/entity/Q231690   http://viaf.org/viaf/44331988
# 5   http://www.wikidata.org/entity/Q215961   http://viaf.org/viaf/50021033
# 6  http://www.wikidata.org/entity/Q4893263   http://viaf.org/viaf/69263532
# 7  http://www.wikidata.org/entity/Q7836141   http://viaf.org/viaf/73921034
#
#                            name_wk year_wk  \
# 0                   Gordon Tullock    1922
# 1                 Alexis Jacquemin    1938
# 2                 François Simiand    1873
# 3                 Lorenz von Stein    1815
# 4                   B. R. Ambedkar    1891
# 5  Franz Hermann Schulze-Delitzsch    1808
# 6              Joan Sardà i Dexeus    1910
# 7                    Travers Twiss    1809
#
#                                              uri_dbp  \
# 0         http://dbpedia.org/resource/Gordon_Tullock
# 1       http://dbpedia.org/resource/Alexis_Jacquemin
# 2       http://dbpedia.org/resource/François_Simiand
# 3       http://dbpedia.org/resource/Lorenz_von_Stein
# 4         http://dbpedia.org/resource/B._R._Ambedkar
# 5  http://dbpedia.org/resource/Franz_Hermann_Schu...
# 6    http://dbpedia.org/resource/Joan_Sardà_i_Dexeus
# 7          http://dbpedia.org/resource/Travers_Twiss
#
#                     name_dbp year_dbp  \
# 0             Gordon Tullock     1922
# 1           Alexis Jacquemin     1938
# 2           François Simiand     1873
# 3           Lorenz von Stein     1815
# 4     Bhimrao Ramji Ambedkar     1891
# 5  Hermann Schulze-Delitzsch     1808
# 6        Joan Sardà i Dexeus     1910
# 7              Travers Twiss     1809
#
#                                            uri_bnf                   name_bnf  \
# 0  http://data.bnf.fr/ark:/12148/cb11927239j#about             Gordon Tullock
# 1  http://data.bnf.fr/ark:/12148/cb119084288#about           Alexis Jacquemin
# 2  http://data.bnf.fr/ark:/12148/cb12301152q#about           François Simiand
# 3  http://data.bnf.fr/ark:/12148/cb12001622n#about           Lorenz von Stein
# 4  http://data.bnf.fr/ark:/12148/cb12126992f#about     Bhimrao Ramji Ambedkar
# 5  http://data.bnf.fr/ark:/12148/cb12088660j#about  Hermann Schulze-Delitzsch
# 6  http://data.bnf.fr/ark:/12148/cb158098327#about          Juan Sardá Dexeus
# 7  http://data.bnf.fr/ark:/12148/cb12314495r#about              Travers Twiss
#
#   sName year_bnf                                            bio_bnf
# 0           1922  Docteur en droit (University of Chicago, Ill.,...
# 1           1938  Juriste et économiste. - Professeur à l'Univer...
# 2           1873  Philosophe. - Agrégé de philosophie. - Docteur...
# 3           1815  Juriste et économiste. - Professeur à Kiel, Al...
# 4           1891  Homme politique d'origine harijan mahar. - Étu...
# 5           1808  Juriste, homme politique et économiste alleman...
# 6           1910                     Docteur en droit. - Économiste
# 7           1809      Juriste. - Spécialiste de droit international

# %%
print("The number of merged data from DBpedia, Wikidata and BnF Data is",len(merged_df),"rows.")
print("")
print("The proportion of the number of merged data from DBpedia, Wikidata and BnF Data is ",(len(merged_df))/(len(df_bnf))*100,"%" )
# Out:
# The number of merged data from DBpedia, Wikidata and BnF Data is 8 rows.
#
# The proportion of the number of merged data from DBpedia, Wikidata and BnF Data is  0.08746036952006123 %

# %%
df1 = pd.DataFrame({'user_id': ['id001', 'id002', 'id003', 'id004', 'id005', 'id006', 'id007'],
                    'first_name': ['Rivi', 'Wynnie', 'Kristos', 'Madalyn', 'Tobe', 'Regan', 'Kristin'],
                    'last_name': ['Valti', 'McMurty', 'Ivanets', 'Max', 'Riddich', 'Huyghe', 'Illis'],
                    'email': ['rvalti0@example.com', 'wmcmurty1@example.com', 'kivanets2@example.com',
                              'mmax3@example.com', 'triddich4@example.com', 'rhuyghe@example.com', 'killis4@example.com']
                    })

# %%
df2 = pd.DataFrame({'user_id': ['id001', 'id002', 'id003', 'id004', 'id005'],
                    'image_url': ['http://example.com/img/id001.png', 'http://example.com/img/id002.jpg',
                                  'http://example.com/img/id003.bmp', 'http://example.com/img/id004.jpg',
                                  'http://example.com/img/id005.png']
                    })

# %%
df3_merged = pd.merge(df1, df2)
df3_merged
# Out:
#   user_id first_name last_name                  email  \
# 0   id001       Rivi     Valti    rvalti0@example.com
# 1   id002     Wynnie   McMurty  wmcmurty1@example.com
# 2   id003    Kristos   Ivanets  kivanets2@example.com
# 3   id004    Madalyn       Max      mmax3@example.com
# 4   id005       Tobe   Riddich  triddich4@example.com
#
#                           image_url
# 0  http://example.com/img/id001.png
# 1  http://example.com/img/id002.jpg
# 2  http://example.com/img/id003.bmp
# 3  http://example.com/img/id004.jpg
# 4  http://example.com/img/id005.png
